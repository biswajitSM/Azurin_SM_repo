# %%
# toogle view
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %% [markdown]
# # Meta

# %% [markdown]
# ## Directories

# %%
#directories
import os
try:
    parentdir
except NameError:
    parentdir=os.getcwd()
else:
    parentdir = parentdir
# homedir=r'/home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/data/201702_S101toS104/S101d14Feb17_60.5_635_A2_CuAzu655';#data directory
print('The working directory is parentdir: %s' %parentdir)
# print('The data directory is homedir: %s' %homedir)
# Out:
# The working directory is parentdir: /home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/Azurin_SM_repo/Manuscript/Figure_AT647N

# %%
#list of folders and their directories CuAZUATTO655
Analysis_dir = '/home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/Azurin_SM_repo/Analysis'
data_dir = '/home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/data'#GIVE the PATH of this FOLDER.

# rest automatically created
S129d28Feb18_590p_A1 = os.path.join(data_dir, 'AzurinATTO647N/S129d28Feb18_590p_A1')
S129d28Feb18_590p_A2 = os.path.join(data_dir, 'AzurinATTO647N/S129d28Feb18_590p_A2')
S129d29Feb18_590p_A3 = os.path.join(data_dir, 'AzurinATTO647N/S129d29Feb18_590p_A3')
S129d29Feb18_590p_A4 = os.path.join(data_dir, 'AzurinATTO647N/S129d29Feb18_590p_A4')
S129d29Feb18_590p_A5 = os.path.join(data_dir, 'AzurinATTO647N/S129d29Feb18_590p_A5')
S130d02MAr18_590p_A1 = os.path.join(data_dir, 'AzurinATTO647N/S130d02MAr18_590p_A1')
S130d02MAr18_590p_A1_2nd = os.path.join(data_dir, 'AzurinATTO647N/S130d02MAr18_590p_A1_2nd')
S130d02MAr18_590p_A1_3rd = os.path.join(data_dir, 'AzurinATTO647N/S130d02MAr18_590p_A1_3rd')
S130d02MAr18_590p_A1_4th = os.path.join(data_dir, 'AzurinATTO647N/S130d02MAr18_590p_A1_4th')
# Long time traces
S125d26Feb18_longtime = os.path.join(data_dir, 'AzurinATTO647N/20180223_longtime')
S130d02MAr18_590p_A2_150mV_longtimes = os.path.join(data_dir, 'AzurinATTO647N/S130d02MAr18_590p_A2_150mV_longtimes')
S130d02MAr18_590p_A3_100mV_longtimes = os.path.join(data_dir, 'AzurinATTO647N/S130d02MAr18_590p_A3_100mV_longtimes')

allfolders = [
             S129d28Feb18_590p_A1, S129d28Feb18_590p_A2, S129d29Feb18_590p_A3,
             S129d29Feb18_590p_A4, S129d29Feb18_590p_A5,
             S130d02MAr18_590p_A1, S130d02MAr18_590p_A1_2nd, S130d02MAr18_590p_A1_3rd, S130d02MAr18_590p_A1_4th,
             S125d26Feb18_longtime, S130d02MAr18_590p_A2_150mV_longtimes, S130d02MAr18_590p_A3_100mV_longtimes,
             ]
S130d02MAr18_A1_all = [S130d02MAr18_590p_A1, S130d02MAr18_590p_A1_2nd, S130d02MAr18_590p_A1_3rd, S130d02MAr18_590p_A1_4th]
S130d02MAr18_all = [S130d02MAr18_590p_A1, S130d02MAr18_590p_A1_2nd, S130d02MAr18_590p_A1_3rd, S130d02MAr18_590p_A1_4th,
                S125d26Feb18_longtime, S130d02MAr18_590p_A2_150mV_longtimes, S130d02MAr18_590p_A3_100mV_longtimes]

# %% [markdown]
# ***Figures and temporarily created data files will be stored in temp_dir***

# %%
# Checking or creating temp_dir
temp_dir = 'temp'
temp_dir = os.path.join(temp_dir)
if os.path.isdir(temp_dir):
    print('temp_dir exists')
else:
    os.makedirs(temp_dir)
    print('temp_dir created')
# Out:
# temp_dir exists

# %% [markdown]
# ## Modules and run .py files

# %%
os.chdir(Analysis_dir)
# %run simulation.py
# %run Analysis.py
# %run changepoint_process.py
# %run longtrace_stat.py
os.chdir(parentdir)

# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Figure Parameters

# %%
matplotlib.rcParams['svg.fonttype'] = 'none'
mpl.rcParams["font.family"] = "sans-serif"
mpl.rcParams["font.size"] = "10"
rc('axes', linewidth=1)
# plt.savefig('/home/biswajit/Downloads/test.svg', format='svg', transparent=True)

# %% [markdown]
# # Set_up Schematic Figure

# %% [markdown]
# # Dark-bright histogram: 100mV

# %%
# dark-bright histogram
t_ons, t_offs = on_off_all_folder(folderlist= S130d02MAr18_all, input_potential=[100], pointnumbers=range(100), pars=(1, 0.1, 0.9, 2))
t_ons = t_ons[t_ons < 10]
t_ons = t_ons[t_ons > 0]
t_offs = t_offs[t_offs < 10]
t_offs = t_offs[t_offs > 0]

plt.close('all')
fig = plt.figure(figsize=(10, 3))
nrows=1;ncols=2;
ax00 = plt.subplot2grid((nrows, ncols),(0,0))
ax01 = plt.subplot2grid((nrows, ncols),(0,1))
waitime_hist_inset(t_ons[1:], ax00, bins=200, binrange=[0,1], insetrange=[0, 0.1],
                   fit_func=streched_exp,xlabel='t_ons');
waitime_hist_inset(t_offs, ax01, bins=200, binrange=[0,10], insetrange=[0, 0.1],
                   fit_func=streched_exp,xlabel='t_offs');
ax00.set_xlabel('bright time/s')
ax00.set_ylabel('#')
ax01.set_xlabel('dark time/s')
ax01.set_ylabel('#')
plt.savefig(os.path.join(temp_dir, 'bright_dark_hist_100mV.svg'), format='svg', dpi=300, transparent=True)
# Out:
# k1:104.462022823
# [  1.04462023e+02   3.95192902e-01   1.65812671e+03]
# k1:13.6047410961
# [  1.36047411e+01   4.60797193e-01   2.66229579e+03]

# %% [markdown]
# # Durations vs Potential: many single-molecule

# %%
#hist all rates
def risetime_fit(t, k1, k2, A):
    return ((A*k1*k2/(k2-k1)) * (exp(-k1*t) - exp(-k2*t)))
def mono_exp(t, k1, A):
    return A*exp(-k1*t)
def hist_fit_rates(potential_list=[100, 90], folderlist=allfolders):
    pot_update = []; tonav_update=[]; toffav_update = [];tonstd_update = [];toffstd_update = []
    for i in range(len(potential_list)):
        potential=[potential_list[i]]
        t_ons, t_offs = on_off_all_folder(folderlist= folderlist, input_potential=potential, 
                                          pointnumbers=range(100), pars=(1, 0.1, 0.9, 2))
        t_ons = t_ons[t_ons < 10]
        t_ons = t_ons[t_ons > 0]
        t_offs = t_offs[t_offs < 10]
        t_offs = t_offs[t_offs > 0]
        pot_update.append(potential[0])
        tonav_update.append(np.average(t_ons))
        toffav_update.append(np.average(t_offs))
        tonstd_update.append(np.std(t_ons))
        toffstd_update.append(np.std(t_offs))
    return pot_update, tonav_update, toffav_update, tonstd_update, toffstd_update
potential_list = [200, 175, 150, 125, 100, 75, 50, 0]
out = hist_fit_rates(potential_list=potential_list, folderlist=S130d02MAr18_all)
[pot_update, tonav_update, toffav_update, tonstd_update, toffstd_update] = out

# %%
df = pd.DataFrame()
df['Potential'] = pot_update
df['average bright time'] = tonav_update
df['std bright time'] = tonstd_update
df['avergae dark time'] = toffav_update
df['std dark time'] = toffstd_update
writer = pd.ExcelWriter(os.path.join(temp_dir, 'Potential_vs_durations.xlsx'))
df.to_excel(writer,'Sheet1', index=False)
writer.save()
df.to_csv(os.path.join(temp_dir, 'Potential_vs_durations'), sep='\t', encoding='utf-8', index=False)

# %%
plt.close('all')
fig = plt.figure(figsize=(10, 5))
nrows=1;ncols=2;
ax00 = plt.subplot2grid((nrows, ncols),(0,0))
ax01 = plt.subplot2grid((nrows, ncols),(0,1))
ax00.errorbar(pot_update, tonav_update, yerr=tonstd_update,
              fmt='-o', capsize=5, label='Bright times')#plot raw outputs
ax00.set_yscale('log')
ax00.set_xlabel('Potential/mV')
ax00.set_ylabel('Duration/s')
# ax00.plot(pot_update, tonav_update, '-*',  label='average ontimes')
ax01.errorbar(pot_update, toffav_update, yerr=toffstd_update,
              fmt='-o', capsize=5, label='Dark times')#plot raw outputs
# ax01.plot(pot_update, toffav_update, '-*', label='average offtimes')
ax01.set_yscale('log')
ax01.set_xlabel('Potential/mV')
ax01.set_ylabel('Duration/s')
ax00.legend()
ax01.legend()
plt.savefig(os.path.join(temp_dir, 'durations_vs_V_many_SM.svg'), format='svg', dpi=300, transparent=True)

# %% [markdown]
# # Time trace vs Potential

# %%
fig = timetraceplot_potentials(foldername=S130d02MAr18_590p_A1_4th, input_potential=[0, 100, 200],
                             pointnumbers=[22], x_lim_min=0, x_lim_max=10,
                             y_lim_min=0, y_lim_max=8, bintime=5e-3,
                             show_changepoint=True, figsize=(10, 6))
plt.savefig(os.path.join(temp_dir, 'timetrace_vs_V_az647N.svg'), format='svg', dpi=300, transparent=True)

# %% [markdown]
# # t_ratio vs Potential: different molecules

# %%
E0_list, E0_m_list = Mid_potentials_slopem_lmfit(folderpath=S130d02MAr18_590p_A1_4th,
                                                 pointnumbers=[4, 22, 23],
                                                 process='cp', plotting=True,
                                                 min_pot=50, max_pot=200, min_pot_num=1)
plt.savefig(os.path.join(temp_dir, 't_ratio_vs_V_az647N.svg'), format='svg', dpi=300, transparent=True)

# %% [markdown]
# ## Save data to excel

# %%
timetrace_output = cp_outputs_folderwise(folderpath=S130d02MAr18_590p_A1_4th, pointnumbers=range(50), potentialist=range(-100, 210))

# %%
timetrace_output
# Out:
#     Point_1                                                       \
#   Potential       t_onav    t_onaverr      t_offav    t_offaverr
# 0       0.0  0.257999584  0.230750605  9.732938322  13.753795865
# 1       NaN          NaN          NaN          NaN           NaN
# 2       NaN          NaN          NaN          NaN           NaN
# 3       NaN          NaN          NaN          NaN           NaN
# 4       NaN          NaN          NaN          NaN           NaN
# 5       NaN          NaN          NaN          NaN           NaN
# 6       NaN          NaN          NaN          NaN           NaN
# 7       NaN          NaN          NaN          NaN           NaN
# 8       NaN          NaN          NaN          NaN           NaN
#
#                                 Point_2                            \
#         t_ratio    t_ratioerr Potential       t_onav    t_onaverr
# 0  37.724627987  63.089589725       0.0  0.708318536  0.703272199
# 1           NaN           NaN     200.0  0.232339905  0.057645471
# 2           NaN           NaN       NaN          NaN          NaN
# 3           NaN           NaN       NaN          NaN          NaN
# 4           NaN           NaN       NaN          NaN          NaN
# 5           NaN           NaN       NaN          NaN          NaN
# 6           NaN           NaN       NaN          NaN          NaN
# 7           NaN           NaN       NaN          NaN          NaN
# 8           NaN           NaN       NaN          NaN          NaN
#
#        ...           Point_26                                Point_29  \
#        ...         t_offaverr        t_ratio     t_ratioerr Potential
# 0      ...        3.298448695    4.455891559   18.492830173     175.0
# 1      ...        0.237144068    2.295074431    3.689800461       NaN
# 2      ...        0.266995220   10.851195108   15.895597776       NaN
# 3      ...        0.531214676   43.132671129   62.135949479       NaN
# 4      ...        8.790262251  503.622444242  581.317833084       NaN
# 5      ...                NaN            NaN            NaN       NaN
# 6      ...                NaN            NaN            NaN       NaN
# 7      ...                NaN            NaN            NaN       NaN
# 8      ...                NaN            NaN            NaN       NaN
#
#                                                                     \
#         t_onav   t_onaverr      t_offav   t_offaverr       t_ratio
# 0  0.034215404  0.04334303  2.681425773  3.445108295  78.368964489
# 1          NaN         NaN          NaN          NaN           NaN
# 2          NaN         NaN          NaN          NaN           NaN
# 3          NaN         NaN          NaN          NaN           NaN
# 4          NaN         NaN          NaN          NaN           NaN
# 5          NaN         NaN          NaN          NaN           NaN
# 6          NaN         NaN          NaN          NaN           NaN
# 7          NaN         NaN          NaN          NaN           NaN
# 8          NaN         NaN          NaN          NaN           NaN
#
#
#       t_ratioerr
# 0  141.399590772
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
#
# [9 rows x 70 columns]

# %%
writer = pd.ExcelWriter(os.path.join(temp_dir, 'durations_pointwise.xlsx'))
timetrace_output.to_excel(writer,'Sheet1', index=False)
writer.save()
timetrace_output.to_csv(os.path.join(temp_dir, 'Potential_vs_durations'), sep='\t', encoding='utf-8', index=False)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-8-db41ece69c9e> in <module>()
#       1 writer = pd.ExcelWriter(os.path.join(temp_dir, 'durations_pointwise.xlsx'))
# ----> 2 timetrace_output.to_excel(writer,'Sheet1', index=False)
#       3 writer.save()
#       4 timetrace_output.to_csv(os.path.join(temp_dir, 'Potential_vs_durations'), sep='\t', encoding='utf-8', index=False)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    1543         formatter.write(excel_writer, sheet_name=sheet_name, startrow=startrow,
#    1544                         startcol=startcol, freeze_panes=freeze_panes,
# -> 1545                         engine=engine)
#    1546
#    1547     def to_stata(self, fname, convert_dates=None, write_index=True,
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/formats/excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     647         writer.write_cells(formatted_cells, sheet_name,
#     648                            startrow=startrow, startcol=startcol,
# --> 649                            freeze_panes=freeze_panes)
#     650         if need_save:
#     651             writer.save()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/excel.py in write_cells(self, cells, sheet_name, startrow, startcol, freeze_panes)
#    1618             wks.freeze_panes(*(freeze_panes))
#    1619
# -> 1620         for cell in cells:
#    1621             val = _conv_value(cell.val)
#    1622
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/formats/excel.py in get_formatted_cells(self)
#     612     def get_formatted_cells(self):
#     613         for cell in itertools.chain(self._format_header(),
# --> 614                                     self._format_body()):
#     615             cell.val = self._format_value(cell.val)
#     616             yield cell
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/formats/excel.py in _format_header_mi(self)
#     396         if self.columns.nlevels > 1:
#     397             if not self.index:
# --> 398                 raise NotImplementedError("Writing to Excel with MultiIndex"
#     399                                           " columns and no index "
#     400                                           "('index'=False) is not yet "
#
# NotImplementedError: Writing to Excel with MultiIndex columns and no index ('index'=False) is not yet implemented.

# %% [markdown]
# # Histogram Midpoint potential

# %%
#Calculate midpoint potential of all points in all folders
E0_array = pd.DataFrame(index=None, columns=['Point number', 'E0_fit', 'E0_err'])
E0_m_array = pd.DataFrame(index=None, columns=['Point number', 'E0_fit', 'E0_err', 'slope', 'slope_error'])
for folder in allfolders:
    E0_list, E0_m_list = Mid_potentials_slopem_lmfit(folderpath=folder, pointnumbers=range(50),
                              process='cp', plotting=False,
                              min_pot=25, max_pot=200, min_pot_num=1)    
    E0_array = E0_array.append(E0_list, ignore_index=True)
    E0_m_array = E0_m_array.append(E0_m_list, ignore_index=True)

# %%
#MIDPOTENTIAL HISTGRAM FITTING
def plot_midpoint_hist(E0_array, ax, min_range = 0, max_range = 0.175):  
    range_fit = [min_range, max_range]
    bins = 30
    bin_centers_on = linspace(range_fit[0], range_fit[1], bins)
    x=linspace(range_fit[0], range_fit[1], 100)# for a smooth fitting plot include more points

    from scipy.interpolate import interp1d
    from lmfit.models import GaussianModel
    mod = GaussianModel()
    n,bins_on1,patches = ax00.hist(E0_array['E0_fit'], bins = bins, range=range_fit, color='b', label='Change Point')#E0_list from running all folder
    y=n; x=bin_centers_on;
    result1 = mod.fit(y, center=0.01, amplitude=10, sigma=0.02, x=x)
    temp =result1.best_values
    FWHM = 2*temp['sigma']*1000 #V
    cent = temp['center']*1000#eV
    amp = temp['amplitude']

    ax.plot(x, result1.best_fit, '-ko', lw=4, label='Center: %.3f mV \n FWHM: %.2f mV' %(cent, FWHM))
    amp = temp['amplitude']
    height = 0.3989423*amp/max(1.e-15, temp['sigma'])
    ax.plot([cent*0.001, cent*0.001], [0, height+0.2*height], '--ok', lw=4)

    ax.set_xlim(0, 0.2)
    ax.set_ylim(0,height+0.2*height)
    ax.set_ylabel('P', fontsize=16)
    ax.set_xlabel('Potential[V]', fontsize=16)
    ax.legend(fontsize=16)
    return()
# Figure parameters
fig = plt.figure(figsize=(10, 5))
nrows=1; ncols=1;
ax00 = plt.subplot2grid((nrows, ncols), (0,0))
mpl.rcParams["font.family"] = "sans-serif"
mpl.rcParams["font.size"] = "14"
# Single azurin midpoint potential
plot_midpoint_hist(E0_array, ax00)
# Electro chemistry
f_CuAzu = os.path.join(data_dir,'misc/cyclic_voltametry/CV 120 uM azurin in hepes ph 7 10 mV_s.xlsx');
os.path.isfile(f_CuAzu)
f = pd.read_excel(f_CuAzu)
left_n = 10000;right_n=-16000
V_corr = 0
V = f['Potential applied (V)'][left_n:right_n]-V_corr;
I = f['WE(1).Current (A)'][left_n:right_n];
Id_max = I.idxmax(); Id_min = I.idxmin()
V_max = V[Id_max]; V_min = V[Id_min]
E0_CuAzu = round((V_max+V_min)/2, 3);
ax00_r = twinx(ax00);
ax00_r.plot(V, I/max(I),'r', label='CuAzurin: '+str(E0_CuAzu)+' V')
ax00_r.axvline(x=E0_CuAzu, color='r', lw=4)
ax00_r.set_ylabel('Current', color='r')
ax00_r.tick_params('y', colors='r')
# Ensemble Fluorescence voltametry
f_int_CuAzu647 = os.path.join(data_dir,'misc/bulk_switching/201803003_titration.xlsx');
df = pd.read_excel(f_int_CuAzu647, sheet_name=1,header=None, skiprows=1)
ax00.plot(1e-3*df[0], 17*df[1]/max(df[1]), '-*g')
ax00.set_xlim(-0.1, 0.3)
#save figire
plt.savefig(os.path.join(temp_dir, 'E0_ENS_SM_CV.svg'), format='svg', dpi=300, transparent=True)

# %% [markdown]
# # Same molecule at different times

# %%
def Mid_potentials_pointwise(ax, folderpath, pointnumbers=range(5),
                          process='cp', plotting=True,
                          min_pot=40, max_pot=150, min_pot_num=1, color='b'):
    '''
    Argument: 
    process: 'fcs' or 'cp'
    '''
    if process == 'cp':
        out = cp_outputs_folderwise(folderpath=folderpath,
                                    pointnumbers=pointnumbers,
                                    potentialist=potentialist)
    if process == 'fcs':
        out = fcs_outputs_folderwise(folderpath=folderpath,
                                     pointnumbers=pointnumbers,
                                     potentialist=potentialist)
    # Nernst Equation definition        
    def nernst(x, a):
        '''x is potential
        a: E0/midpoint potential(parameter)
        returns ratio(t_oxd/t_red)'''
        return(10**((x-a) / 0.059))
    nernst_mod = Model(nernst)
    params_nernst = nernst_mod.make_params(a=0.02)
    def nernst_slopem(x, a, m):
        return(10**((x-a) / m))
    nernst_slopem_mod = Model(nernst_slopem)
    params_ner_slop = nernst_slopem_mod.make_params(a=0.02, m=0.059)
    columns_E0 = ['Point number', 'E0_fit', 'E0_err']
    columns_E0_m = ['Point number', 'E0_fit', 'E0_err', 'slope', 'slope_error']
    E0_list = pd.DataFrame(index=None, columns=columns_E0)
    E0_m_list = pd.DataFrame(index=None, columns=columns_E0_m)
    #--figure initiation----
    for i in range(len(out.columns.levels[0])):
        point = out.columns.levels[0][i]
        point_output_tot = out[point].dropna()
        point_output = point_output_tot[point_output_tot['Potential'] >= min_pot] #select a potential threshold
        point_output = point_output_tot[point_output_tot['Potential'] <= max_pot] #select a potential threshold
        point_output.reset_index(drop=True, inplace=True)
        if len(point_output)>min_pot_num:
            potential = point_output['Potential']
            t_onav = point_output['t_onav']
            t_onaverr = point_output['t_onaverr']
            t_offav = point_output['t_offav']
            t_offaverr = point_output['t_offaverr']
            t_ratio = point_output['t_ratio']
            t_ratioerr = point_output['t_ratioerr']
            E = potential*0.001 #converting to mV
            #--------fitting nernst----------------
            res_nernst = nernst_mod.fit(t_ratio, params_nernst, x=E)
            out_params = str((res_nernst.params['a'],'value'));
            E0 = res_nernst.best_values['a']
            E0_err = float(out_params.split('+/- ')[1].split(', bounds')[0]);
            #---------append to list---------
            E0_list_temp = pd.DataFrame([[point, E0, E0_err]], columns=columns_E0)
            E0_list=E0_list.append(E0_list_temp, ignore_index=True)
            #--------fitting nernst_slopem------
            res_nernst_slop = nernst_slopem_mod.fit(t_ratio, params_ner_slop, x=E)
            E0_m = res_nernst_slop.best_values['a']
            out_params = str((res_nernst_slop.params['a'],'value'));
            E0_m_err = float(out_params.split('+/- ')[1].split(', bounds')[0]);
            slope_m = res_nernst_slop.best_values['m']
            out_params_m = str((res_nernst_slop.params['m'],'value'));
            slope_m_err = float(out_params_m.split('+/- ')[1].split(', bounds')[0]);
            E0_m_list_temp = pd.DataFrame([[point, E0_m, E0_m_err, slope_m, slope_m_err]], columns=columns_E0_m)
            E0_m_list = E0_m_list.append(E0_m_list_temp, ignore_index=True)
            #-----plot------
            if plotting == True:
                # ax.errorbar(point_output_tot['Potential'], point_output_tot['t_ratio'],
                #          yerr=point_output_tot['t_ratioerr'], fmt='o', color=color, label=point)#plot raw outputs
                ax.plot(point_output_tot['Potential'], point_output_tot['t_ratio'],'o', color=color)#plot raw outputs                
                ax.plot(linspace(min(potential)-10, max(potential)+10), nernst(0.001*linspace(min(potential)-10, max(potential)+10), E0), linewidth=2.0, color=color)#color
                #plot(E*1000, nernst(E, *E0_fit), color=color, linewidth=2.0)
                ax.set_yscale('log')
                ax.set_xlabel('$Potential [V]$')
                ax.set_ylabel('$t_{dark}/t_{bright}$')
                ax.tick_params(axis='both', which='major')
                ax.set_title(r'$E=E_0 + 0.059log(\frac{t_{off}}{t_{on}})$')
                tight_layout()
    return(E0_list, E0_m_list)

# %%
# Point 22
plt.close('all')
fig = plt.figure(figsize=(4, 4))
nrows=1;ncols=1;
ax00 = plt.subplot2grid((nrows, ncols),(0,0))

E0_list, E0_m_list = Mid_potentials_pointwise(ax=ax00, folderpath=S130d02MAr18_590p_A1,
                                                 pointnumbers=[22],
                                                 process='cp', plotting=True,
                                                 min_pot=0, max_pot=200, min_pot_num=1, color='b')
E0_list, E0_m_list = Mid_potentials_pointwise(ax=ax00, folderpath=S130d02MAr18_590p_A1_2nd,
                                                 pointnumbers=[22],
                                                 process='cp', plotting=True,
                                                 min_pot=0, max_pot=200, min_pot_num=1, color='r')
E0_list, E0_m_list = Mid_potentials_pointwise(ax=ax00, folderpath=S130d02MAr18_590p_A1_3rd,
                                                 pointnumbers=[22],
                                                 process='cp', plotting=True,
                                                 min_pot=0, max_pot=200, min_pot_num=1, color='g')
E0_list, E0_m_list = Mid_potentials_pointwise(ax=ax00, folderpath=S130d02MAr18_590p_A1_4th,
                                                 pointnumbers=[22],
                                                 process='cp', plotting=True,
                                                 min_pot=0, max_pot=200, min_pot_num=1, color='k')

ax00.legend(['0 hours', '',
             '1 hours', '',
             '2 hour', '',
             '3 hour', ''], fontsize=8)
ax00.set_xlim(90, 200)
ax00.set_ylim(1e-1, 1e2)
plt.savefig(os.path.join(temp_dir, 't_ratio_vs_V_diff_time.svg'), format='svg', dpi=300, transparent=True)

# %% [markdown]
# # Long time trace: Single-molecule

# %%
file_path_hdf5 = '/home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/data/AzurinATTO647N/S130d02MAr18_590p_A3_100mV_longtimes/data/S103_550p_A3_100mV(35)_9.hdf5'
# file_path_hdf5 = '/home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/data/AzurinATTO647N/20180223_longtime/data/Point_611p_N42CCuAzuATTO647N_A2_0100mV(29)_x.hdf5';
# file_path_hdf5 = '/home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/data/AzurinATTO647N/20180223_longtime/data/Point_611p_N42CCuAzuATTO647N_A2_0100mV(27)_42.hdf5';
# file_path_hdf5 = '/home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/data/AzurinATTO647N/S130d02MAr18_590p_A2_150mV_longtimes/data/S103_550p_A2_150mV(30)_2.hdf5'
# file_path_hdf5 = '/home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/data/AzurinATTO647N/S130d02MAr18_590p_A2_150mV_longtimes/data/S103_550p_A2_150mV(32)_6.hdf5'
# file_path_hdf5 = '/home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/data/AzurinATTO647N/S130d02MAr18_590p_A2_150mV_longtimes/data/S103_550p_A2_150mV(32)_7.hdf5'
# file_path_hdf5 = '/home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/data/AzurinATTO647N/S129d29Feb18_590p_A6_longtimes/data/Point_A6_longtime_0100mV(47)_1.hdf5'
# file_path_hdf5 = '/home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/data/AzurinATTO647N/S129d29Feb18_590p_A6_longtimes/data/Point_A6_longtime_0100mV(47)_2.hdf5'

# %%
# file_path_hdf5 = os.path.join(data_dir,'AzurinATTO647N/20180223_longtime/data/Point_611p_N42CCuAzuATTO647N_A2_0100mV(29)_x.hdf5');
if os.path.isfile(file_path_hdf5):
    print('"file_path_hdf5" found')
fig1, fig2 = histogram_on_off_1mol(file_path_hdf5, time_lim = [0, 2.5e3], input_potential=100,
                          bins_on=50, range_on=[0, 0.2], 
                          bins_off=50, range_off=[0, 0.5], 
                          E0range = [0, 100], sum_points=10,
                          G_lim=[0, 0.5], tlag_lim=[0, 500])
fig1.savefig(os.path.join(temp_dir, 'longtrace_dynamic_het.svg'), format='svg', dpi=300, transparent=True)
# Out:
# "file_path_hdf5" found
# k1:4229.56899449
# [ 4229.56899449    14.15409647     6.00077123]
# k1:2692.11393425
# [ 2692.11393425     6.52662288     8.84698225]
# k1:4229.56899449
# [ 4229.56899449    14.15409647     6.00077123]
# k1:2692.11393425
# [ 2692.11393425     6.52662288     8.84698225]

# %%
#Electerochemistry
os.chdir('/home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/data/misc/cyclic_voltametry')
f_FeCN = '20180227_1_cv_200umferro.txt';
f_ZnAT655 = 'CV 20 uM Dye-Zn azurin 2.xlsx';
f_CuAzu = 'CV 120 uM azurin in hepes ph 7 10 mV_s.xlsx';

V_corr = 0;
figure(figsize=(6.3, 4))###FIGSIZE#####
#Fe(CN)6
f = pd.read_csv(f_FeCN, header=None, skiprows=79)
f = f.apply(pd.to_numeric, errors='coerce')
f = f.dropna()
V = f[0][800:]-V_corr;
I = f[1][800:];
Id_max = I.idxmax(); Id_min = I.idxmin()
V_max = V[Id_max]; V_min = V[Id_min]
E0_FeCN = round((V_max+V_min)/2, 3);
plt.plot(V, -1*I/max(I), 'r', label='Fe3(CN)6: '+str(E0_FeCN)+' V')
plt.axvline(E0_FeCN, color='r')
#CuAzurin
f = pd.read_excel(f_CuAzu)
left_n = 10000;right_n=-16000
V = f['Potential applied (V)'][left_n:right_n]-V_corr;
I = f['WE(1).Current (A)'][left_n:right_n];
Id_max = I.idxmax(); Id_min = I.idxmin()
V_max = V[Id_max]; V_min = V[Id_min]
E0_CuAzu = round((V_max+V_min)/2, 3);
plt.plot(V, I/max(I),'g', label='CuAzurin: '+str(E0_CuAzu)+' V')
plt.axvline(E0_CuAzu, color='g')

ylabel('Current')
xlabel('Voltage/V')
ylim(-1.2, 1.2)
xlim(-0.1, 0.5)
yticks([])
legend(loc=4, framealpha=0.2)
os.chdir(parentdir)
os.chdir(temp_dir)
savefig('cyclic_voltametry.svg', dpi=300, transparent=True)

# %%
def substrate_conc(E0, E, M, n=1):
    '''All potential values are in mV'''
    #E = E + 240; E0=E0+240;
    Ecorr = 10**((E-E0)*n/59) # DUBIOUS formula
    S_oxd = (M*Ecorr)/(1+Ecorr)
    S_red = M/(1+Ecorr)
    return E, S_oxd, S_red #E-240
E=np.arange(0, 200)
M_FeCN = 200;
E, FeCN_oxd, FeCN_red = substrate_conc(E0=180, E=E, M=M_FeCN)
M_asc = 100;
E, asc_oxd, asc_red = substrate_conc(E0=30, E=E, M=M_asc, n=1)
#----------------wrapping vlaues to dataframe------------
def wrap_values():
    df = pd.DataFrame()
    df['E'] = E;
    df['FeCN_oxd'] = FeCN_oxd;
    df['asc_oxd'] = asc_oxd;
    df['FeCN_oxd+asc_oxd'] = FeCN_oxd + asc_oxd;
    df['FeCN_red'] = FeCN_red;
    df['asc_red'] = asc_red;
    df['FeCN_red+asc_red'] = FeCN_red+asc_red;
    return(df)
df=wrap_values()
#--------------Plotting simulated values---------------
def plot_substrate_conc():
    fig, axes = plt.subplots(figsize=(5, 5))
    # FeCN oxd
    ax1 = axes
    ax1.plot(E, FeCN_oxd, 'b', label='$[Fe^{3+}]$')
    ax1.set_ylabel('$[uM]$', color='b')
    ax1.tick_params('y', colors='b')
    ax1.set_xlabel('$Potential[mV]$')

    # reductant
    ax2 = axes
    ax2.plot(E, FeCN_red, 'r', label='$[Fe^{2+}]$')
    ax2.set_xlabel('$Potential[mV]$')

    ax1.legend(loc=4)
    fig.tight_layout()
    plt.show()
    return(fig)
fig=plot_substrate_conc()
os.chdir(parentdir)
os.chdir(temp_dir)
fig.savefig('substrate_conc.svg', dpi=300, transparent=True)

# %%
E = np.arange(-100, 250)
M_FeCN = 200;
E, FeCN_oxd, FeCN_red = substrate_conc(E0=180, E=E, M=M_FeCN)
df = pd.DataFrame()
df['Potential'] = E
df['Fe3+'] = FeCN_oxd
df['Fe2+'] = FeCN_red
writer = pd.ExcelWriter(os.path.join(temp_dir, 'Ferricyanide_conc.xlsx'))
df.to_excel(writer)
writer.save()
plt.plot(E, FeCN_oxd)
