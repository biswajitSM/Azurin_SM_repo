# %%
# toogle view
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %% [markdown]
# # Meta

# %% [markdown]
# ## Directories

# %%
#directories
import os
try:
    parentdir
except NameError:
    parentdir=os.getcwd()
else:
    parentdir = parentdir
# homedir=r'/home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/data/201702_S101toS104/S101d14Feb17_60.5_635_A2_CuAzu655';#data directory
print('The working directory is parentdir: %s' %parentdir)
# print('The data directory is homedir: %s' %homedir)
# Out:
# The working directory is parentdir: /home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/Azurin_SM_repo/Manuscript/Figure_AT647N

# %%
#list of folders and their directories CuAZUATTO655
Analysis_dir = '/home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/Azurin_SM_repo/Analysis'
data_dir = '/home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/data'#GIVE the PATH of this FOLDER.

# rest automatically created
S129d28Feb18_590p_A1 = os.path.join(data_dir, 'AzurinATTO647N/S129d28Feb18_590p_A1')
S129d28Feb18_590p_A2 = os.path.join(data_dir, 'AzurinATTO647N/S129d28Feb18_590p_A2')
S129d29Feb18_590p_A3 = os.path.join(data_dir, 'AzurinATTO647N/S129d29Feb18_590p_A3')
S129d29Feb18_590p_A4 = os.path.join(data_dir, 'AzurinATTO647N/S129d29Feb18_590p_A4')
S129d29Feb18_590p_A5 = os.path.join(data_dir, 'AzurinATTO647N/S129d29Feb18_590p_A5')
S130d02MAr18_590p_A1 = os.path.join(data_dir, 'AzurinATTO647N/S130d02MAr18_590p_A1')
S130d02MAr18_590p_A1_2nd = os.path.join(data_dir, 'AzurinATTO647N/S130d02MAr18_590p_A1_2nd')
S130d02MAr18_590p_A1_3rd = os.path.join(data_dir, 'AzurinATTO647N/S130d02MAr18_590p_A1_3rd')
S130d02MAr18_590p_A1_4th = os.path.join(data_dir, 'AzurinATTO647N/S130d02MAr18_590p_A1_4th')
# Long time traces
S125d26Feb18_longtime = os.path.join(data_dir, 'AzurinATTO647N/20180223_longtime')
S130d02MAr18_590p_A2_150mV_longtimes = os.path.join(data_dir, 'AzurinATTO647N/S130d02MAr18_590p_A2_150mV_longtimes')
S130d02MAr18_590p_A3_100mV_longtimes = os.path.join(data_dir, 'AzurinATTO647N/S130d02MAr18_590p_A3_100mV_longtimes')

allfolders = [
             S129d28Feb18_590p_A1, S129d28Feb18_590p_A2, S129d29Feb18_590p_A3,
             S129d29Feb18_590p_A4, S129d29Feb18_590p_A5,
             S130d02MAr18_590p_A1, S130d02MAr18_590p_A1_2nd, S130d02MAr18_590p_A1_3rd, S130d02MAr18_590p_A1_4th,
             S125d26Feb18_longtime, S130d02MAr18_590p_A2_150mV_longtimes, S130d02MAr18_590p_A3_100mV_longtimes,
             ]
S130d02MAr18_A1_all = [S130d02MAr18_590p_A1, S130d02MAr18_590p_A1_2nd, S130d02MAr18_590p_A1_3rd, S130d02MAr18_590p_A1_4th]
S130d02MAr18_all = [S130d02MAr18_590p_A1, S130d02MAr18_590p_A1_2nd, S130d02MAr18_590p_A1_3rd, S130d02MAr18_590p_A1_4th,
                    S130d02MAr18_590p_A2_150mV_longtimes, S130d02MAr18_590p_A3_100mV_longtimes]

# %% [markdown]
# ***Figures and temporarily created data files will be stored in temp_dir***

# %%
# Checking or creating temp_dir
temp_dir = 'temp'
temp_dir = os.path.join(parentdir, temp_dir)
if os.path.isdir(temp_dir):
    print('temp_dir exists')
else:
    os.makedirs(temp_dir)
    print('temp_dir created')
# Out:
# temp_dir exists

# %% [markdown]
# ## Modules and run .py files

# %%
# import modules
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append(Analysis_dir)
from LongTraceAnalysis import LongTraceClass
from simulation import *
from Analysis import *
from ChangePointProcess import *

import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Figure Parameters

# %%
from pylab import *
matplotlib.rcParams['svg.fonttype'] = 'none'
mpl.rcParams["font.family"] = "sans-serif"
mpl.rcParams["font.size"] = "10"
rc('axes', linewidth=1)
# plt.savefig('/home/biswajit/Downloads/test.svg', format='svg', transparent=True)

# %% [markdown]
# ## Check list of points

# %%
df_datn_emplot = ListsPt3Hdf5(S130d02MAr18_590p_A1_4th)
# df_datn_emplot.head(5)
df_datn_emplot.head()
# Out:
#   PointNumber Potential                                       FileName  \
# 0          19       125  S130_Point_590p_A1_4th_0125mV(24)_19.pt3.hdf5
# 1          22        50  S130_Point_590p_A1_4th_0050mV(23)_22.pt3.hdf5
# 2           2       200   S130_Point_590p_A1_4th_0200mV(26)_2.pt3.hdf5
# 3          13        50  S130_Point_590p_A1_4th_0050mV(23)_13.pt3.hdf5
# 4          23       200  S130_Point_590p_A1_4th_0200mV(26)_23.pt3.hdf5
#
#                                         FilePathHdf5
# 0  /home/biswajit/Research/Reports_ppt/reports/Az...
# 1  /home/biswajit/Research/Reports_ppt/reports/Az...
# 2  /home/biswajit/Research/Reports_ppt/reports/Az...
# 3  /home/biswajit/Research/Reports_ppt/reports/Az...
# 4  /home/biswajit/Research/Reports_ppt/reports/Az...

# %% [markdown]
# # Set_up Schematic Figure

# %%
f200mV = os.path.join(data_dir, 'misc/image/S81d7Sept16_200mV(22)_A2_again.dat')
fn50mV = os.path.join(data_dir, 'misc/image/S81d7Sept16_-50mV(23)_A2_again.dat')
df_200mV = pd.read_csv(f200mV, header=None, skiprows=8, sep='\s+')
df_n50mV = pd.read_csv(fn50mV, header=None, skiprows=8, sep='\s+')

fig = plt.figure(figsize=(2.5, 5))
nrows = 2
ncols = 1
ax00 = plt.subplot2grid((nrows, ncols), (0,0))
ax10 = plt.subplot2grid((nrows, ncols), (1,0))
ax00.imshow(df_200mV, cmap=mpl.cm.Greys_r, vmin=0.2, vmax=5)
m = ax10.imshow(df_n50mV, cmap=mpl.cm.Greys_r, vmin=0.2, vmax=5)

ax00.tick_params(
    axis='both',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False,
    left=False,
    labelleft=False) # labels along the bottom edge are off
ax10.tick_params(
    axis='both',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False,
    left=False,
    labelleft=False) # labels along the bottom edge are off
plt.savefig(os.path.join(temp_dir, 'ImageHighLowPotentials.svg'), format='svg', dpi=300, transparent=True)

# %% [markdown]
# # Dark-bright histogram: 100mV

# %% [markdown]
# # Conc Vs Potential

# %%
# functions
def substrate_conc(E0, E, M, n=1):
    '''All potential values are in mV'''
    #E = E + 240; E0=E0+240;
    Ecorr = 10**((E-E0)*n/59) # DUBIOUS formula
    S_oxd = (M*Ecorr)/(1+Ecorr)
    S_red = M/(1+Ecorr)
    return E, S_oxd, S_red #E-240
E=np.arange(0, 200)
M_FeCN = 200;
E, FeCN_oxd, FeCN_red = substrate_conc(E0=180, E=E, M=M_FeCN)
M_asc = 100;
E, asc_oxd, asc_red = substrate_conc(E0=30, E=E, M=M_asc, n=1)
#----------------wrapping vlaues to dataframe------------
def wrap_values():
    df = pd.DataFrame()
    df['E'] = E;
    df['FeCN_oxd'] = FeCN_oxd;
    df['asc_oxd'] = asc_oxd;
    df['FeCN_oxd+asc_oxd'] = FeCN_oxd + asc_oxd;
    df['FeCN_red'] = FeCN_red;
    df['asc_red'] = asc_red;
    df['FeCN_red+asc_red'] = FeCN_red+asc_red;
    return(df)
df=wrap_values()
#--------------Plotting simulated values---------------
def plot_substrate_conc():
    fig, axes = plt.subplots(figsize=(5, 5))
    # FeCN oxd
    ax1 = axes
    ax1.plot(E, FeCN_oxd, 'b', label='$[Fe^{3+}]$')
    ax1.set_ylabel('$[uM]$', color='b')
    ax1.tick_params('y', colors='b')
    ax1.set_xlabel('$Potential[mV]$')

    # reductant
    ax2 = axes
    ax2.plot(E, FeCN_red, 'r', label='$[Fe^{2+}]$')
    ax2.set_xlabel('$Potential[mV]$')

    ax1.legend(loc=4)
    fig.tight_layout()
    plt.show()
    return(fig)
fig=plot_substrate_conc()
os.chdir(parentdir)
os.chdir(temp_dir)
fig.savefig('substrate_conc.svg', dpi=300, transparent=True)

# %% [markdown]
# # Durations vs Potential: many single-molecule

# %%
#Bright dark values
def BrightDarkValuesAll(potential_list=np.array([0, 50, 75, 100, 125, 150, 175, 200]),
                        folderlist=S130d02MAr18_all,
                        pars = (1, 0.01, 0.99, 2),
                        FileToSave = 'S130d02MAr18_all_0.01_0.99.xlsx',
                        Rewrite=False):
    if not os.path.isfile(FileToSave) or Rewrite:
        pot_update = np.array([])
        tonav_update=np.array([])
        toffav_update = np.array([])
        tonstd_update = np.array([])
        toffstd_update = np.array([])
        df_bright = dict()
        df_dark = dict()
        for i in range(len(potential_list)):
            potential=[potential_list[i]]
            t_ons, t_offs = on_off_all_folder(folderlist= folderlist, input_potential=potential, 
                                              pointnumbers=range(100), pars=pars)
            t_ons = t_ons[t_ons < 10]
            t_ons = t_ons[t_ons > 0]
            t_offs = t_offs[t_offs < 10]
            t_offs = t_offs[t_offs > 0]
            df_bright[str(potential[0])+'mV'] = t_ons
            df_dark[str(potential[0])+'mV'] = t_offs

            pot_update = np.append(pot_update, potential[0])
            # average ontime calc
            tonav = np.average(t_ons)
            lambda_ton = 1/tonav;
            lambda_ton_low = lambda_ton * (1-(1.96/np.sqrt(len(t_ons))))
            lambda_ton_upp = lambda_ton * (1+(1.96/np.sqrt(len(t_ons))))
            tonav_err = (1/lambda_ton_low) - (1/lambda_ton_upp);
            tonav_err = np.round(tonav_err, 4)
            # average offtime calc
            toffav = np.average(t_offs);# also converts to millisecond
            lambda_toff = 1/toffav;
            lambda_toff_low = lambda_toff * (1-(1.96/np.sqrt(len(t_offs))))
            lambda_toff_upp = lambda_toff * (1+(1.96/np.sqrt(len(t_offs))))
            toffav_err = (1/lambda_toff_low) - (1/lambda_toff_upp);
            toffav_err = np.round(toffav_err, 4)

            tonav_update = np.append(tonav_update, tonav)
            toffav_update = np.append(toffav_update, toffav)

            tonstd_update = np.append(tonstd_update, tonav_err)
            toffstd_update = np.append(toffstd_update, toffav_err)
        df_avg = pd.DataFrame()
        df_avg['Potential'] = pot_update
        df_avg['average bright time'] = tonav_update
        df_avg['std bright time'] = tonstd_update
        df_avg['avergae dark time'] = toffav_update
        df_avg['std dark time'] = toffstd_update
        #
        df_dark = pd.DataFrame.from_dict(df_dark, orient='index')
        df_dark = df_dark.transpose()
        df_bright = pd.DataFrame.from_dict(df_bright, orient='index')
        df_bright = df_bright.transpose()
        
        E, FeCN_oxd, FeCN_red = substrate_conc(E0=180, E=potential_list, M=200e-6)
        df_avg['FeCN_oxd'] = FeCN_oxd
        df_avg['FeCN_red'] = FeCN_red
        # save to file
        writer = pd.ExcelWriter(FileToSave)
        df_avg.to_excel(writer,'Average', index=False)
        df_bright.to_excel(writer, 'BrightTimes', index=False)
        df_dark.to_excel(writer, 'DarkTimes', index=False)
        writer.save()        
    return FileToSave

# %%
os.chdir(parentdir)
file_save = BrightDarkValuesAll(folderlist=S130d02MAr18_all, pars = (1, 0.01, 0.99, 2), FileToSave = 'S130d02MAr18_all_0.01_0.99.xlsx', Rewrite=False)
# file_save = BrightDarkValuesAll(folderlist=S130d02MAr18_all, pars = (1, 0.1, 0.9, 2), FileToSave = 'S130d02MAr18_all_0.1_0.9.xlsx', Rewrite=False)
# file_save = BrightDarkValuesAll(folderlist=allfolders, pars = (1, 0.01, 0.99, 2), FileToSave = 'allfolders_0.01_0.99.xlsx', Rewrite=False)
# file_save = BrightDarkValuesAll(folderlist=allfolders, pars = (1, 0.1, 0.9, 2), FileToSave = 'allfolders_0.1_0.9.xlsx', Rewrite=False)
# file_save = BrightDarkValuesAll(folderlist=S130d02MAr18_A1_all, pars = (1, 0.01, 0.99, 2), FileToSave = 'S130d02MAr18_A1_0.01_0.99.xlsx', Rewrite=False)

df_avg = pd.read_excel(file_save, sheet_name='Average')
potential_list = df_avg['Potential'].values
tonav_update = df_avg['average bright time'].values
tonstd_update = df_avg['std bright time'].values
# toffav_update = df_avg['avergae dark time'].values
# toffstd_update = df_avg['std dark time'].values
FeCN_oxd = df_avg['FeCN_oxd'].values
FeCN_red = df_avg['FeCN_red'].values
# # bright and dark times histogram
df_bright = pd.read_excel(file_save, sheet_name='BrightTimes')
df_dark = pd.read_excel(file_save, sheet_name='DarkTimes')
ontimes = df_bright['100mV'].dropna().values
# offtimes = df_dark['100mV'].dropna().values
# df_avg

file_save = BrightDarkValuesAll(folderlist=S130d02MAr18_all, pars = (1, 0.1, 0.9, 2), FileToSave = 'S130d02MAr18_all_0.1_0.9.xlsx', Rewrite=False)
# file_save = BrightDarkValuesAll(folderlist=S130d02MAr18_A1_all, pars = (1, 0.1, 0.9, 2), FileToSave = 'S130d02MAr18_A1_0.1_0.9.xlsx', Rewrite=False)

df_avg = pd.read_excel(file_save, sheet_name='Average')
potential_list = df_avg['Potential'].values
# tonav_update = df_avg['average bright time'].values
# tonstd_update = df_avg['std bright time'].values
toffav_update = df_avg['avergae dark time'].values
toffstd_update = df_avg['std dark time'].values
FeCN_oxd = df_avg['FeCN_oxd'].values
FeCN_red = df_avg['FeCN_red'].values
# # bright and dark times histogram
df_bright = pd.read_excel(file_save, sheet_name='BrightTimes')
df_dark = pd.read_excel(file_save, sheet_name='DarkTimes')
# ontimes = df_bright['100mV'].dropna().values
offtimes = df_dark['100mV'].dropna().values
df_avg
# Out:
#    Potential  average bright time  std bright time  avergae dark time  \
# 0          0          0.813867220           0.3050        0.279892549
# 1         50          0.297214427           0.0783        0.266455323
# 2         75          0.250284632           0.0621        0.320882235
# 3        100          0.119375761           0.0048        0.628719088
# 4        125          0.074473645           0.0150        0.266948977
# 5        150          0.049483239           0.0016        0.486418198
# 6        175          0.032167323           0.0019        0.428399644
# 7        200          0.018410973           0.0052        0.698697750
#
#    std dark time     FeCN_oxd     FeCN_red
# 0         0.1074  0.000000178  0.000199822
# 1         0.0700  0.000001244  0.000198756
# 2         0.0792  0.000003267  0.000196733
# 3         0.0252  0.000008441  0.000191559
# 4         0.0537  0.000020932  0.000179068
# 5         0.0160  0.000047342  0.000152658
# ...

# %% [markdown]
# ## Dark-bright histogram: 100mV

# %%
from LongTraceAnalysis import waitime_hist_inset, streched_exp
# bright and dark times histogram
potential = 100
df_bright = pd.read_excel(file_save, sheet_name='BrightTimes')
ontimes = df_bright[str(potential)+'mV'].dropna().values
offtimes = df_dark[str(potential)+'mV'].dropna().values

plt.close('all')
fig = plt.figure(figsize=(10, 3))
nrows=1;ncols=2;
ax00 = plt.subplot2grid((nrows, ncols),(0,0))
ax01 = plt.subplot2grid((nrows, ncols),(0,1))
waitime_hist_inset(ontimes[1:], ax00, bins=100, binrange=[0.01,2], insetrange=[0, 0.1],
                   fit_func=streched_exp,PlotInset=False);
waitime_hist_inset(offtimes, ax01, bins=100, binrange=[0.01,10], insetrange=[0, 0.1],
                   fit_func=streched_exp,PlotInset=False);
ax00.set_xlabel('bright time/s')
ax00.set_ylabel('#')
ax01.set_xlabel('dark time/s')
ax01.set_ylabel('#')
plt.savefig(os.path.join(temp_dir, 'bright_dark_hist_100mV.svg'), format='svg', dpi=300, transparent=True)
# Out:
# k1:20.3543156628
# [  2.03543157e+01   6.64664630e-01   2.33601886e+03]
# k1:19.1500907118
# [  1.91500907e+01   4.17863804e-01   4.78867237e+03]

# %% [markdown]
# ## Dark-Bright time vs Potential

# %%
plt.close('all')
fig = plt.figure(figsize=(10, 5))
nrows=1;ncols=2;
ax00 = plt.subplot2grid((nrows, ncols),(0,0))
ax01 = plt.subplot2grid((nrows, ncols),(0,1))
ax00.errorbar(potential_list, tonav_update, yerr=tonstd_update,
              fmt='-o', capsize=5, label='Bright times')#plot raw outputs
ax00.set_yscale('log')
ax00.set_xlabel('Potential/mV')
ax00.set_ylabel('Duration/s')
# ax00.plot(pot_update, tonav_update, '-*',  label='average ontimes')
ax01.errorbar(potential_list, toffav_update, yerr=toffstd_update,
              fmt='-o', capsize=5, label='Dark times')#plot raw outputs
# ax01.plot(pot_update, toffav_update, '-*', label='average offtimes')
ax01.set_yscale('log')
ax01.set_xlabel('Potential/mV')
ax01.set_ylabel('Duration/s')
ax00.legend()
ax01.legend()
plt.savefig(os.path.join(temp_dir, 'durations_vs_V_many_SM.svg'), format='svg', dpi=300, transparent=True)

# %% [markdown]
# ## Dark-bright fit with conc

# %%
# fit of rates
def rate_conc_fit(x, k3, K):
    return (1/k3)+(x*K)
# def rate_conc_fit(x, k3, k10, kn1):
#     return (1/k3)+((1+(kn1/k3))/(k10*x))
plt.close('all')
fig = plt.figure(figsize=(12, 4))
nrows=1;ncols=2;
ax00 = plt.subplot2grid((nrows, ncols),(0,0))
ax01 = plt.subplot2grid((nrows, ncols),(0,1))
# bright times
rate_mod = Model(rate_conc_fit)
params = Parameters()
params.add('k3', value=30, min=0)
params.add('K', value=1e-6, min=0)
result = rate_mod.fit(tonav_update[2:], params, x=1/FeCN_oxd[2:])
result.plot_fit(ax00)
# ax00.plot(FeCN_oxd, rate_conc_fit(FeCN_oxd, *fit))
ax00.errorbar(1/FeCN_oxd[2:], tonav_update[2:], yerr=tonstd_update[2:],
              fmt='-', capsize=5, label='Bright times')#plot raw outputs
# ax00.set_yscale('log')
ax00.set_xlabel('1/[Oxd]')
ax00.set_ylabel('Duration/s')
ax00.legend()
# xticss = ax00.get_xticks().tolist()
# xticss[:] = np.round(FeCN_oxd*1e6)
# ax00.set_xticklabels([])
# ax00.set_xticklabels(xticss)
ax00.set_xlim(0, 4e5)
ax00.set_ylim(0, 0.4)
print('Bright time: ', result.best_values)
# ax00.text(5e-6, 1e-1, result.best_values)
# text(x, y, s, fontsize=12)
# Dark times
# fit, pcov = curve_fit(rate_conc_fit, xdata=FeCN_red, ydata=toffav_update, p0=[10, 1], bounds=(-np.inf, np.inf))
rate_mod = Model(rate_conc_fit)
params = Parameters()
params.add('k3', value=4, min=0)
params.add('K', value=4e-5, min=0)
result = rate_mod.fit(toffav_update[2:], params, x=1/FeCN_red[2:])
result.plot_fit(ax01)
ax01.errorbar(1/FeCN_red, toffav_update, yerr=toffstd_update,
              fmt='-', capsize=5, label='Dark times')#plot raw outputs
# ax01.set_yscale('log')
ax01.set_xlabel('1/[Red]')
ax01.set_ylabel('Duration/s')
ax01.legend()
ax01.set_xlim(0,)
ax01.set_ylim(0,)
# xticss = ax01.get_xticks().tolist()
# xticss[:] = np.round(FeCN_red*1e6)
# ax01.set_xticklabels([])
# ax01.set_xticklabels(xticss)
print('Dark time: ', result.best_values)
plt.savefig(os.path.join(temp_dir, 'durations_vs_V_many_SM_conc.svg'), format='svg', dpi=300, transparent=True)
# Out:
# Bright time:  {'k3': 18.816418905305596, 'K': 8.4799088684306412e-07}
# Dark time:  {'k3': 3.7674516152237834, 'K': 2.5751111464078491e-05}

# %% [markdown]
# ## Ensemble Int, SM artes Vs Potential

# %%
#
fig = plt.figure(figsize=(5, 4))
nrows=1; ncols=1;
ax00 = plt.subplot2grid((nrows, ncols), (0,0))

sum_ontimes = np.array([])
sum_offtimes = np.array([])
# for potential in potential_list:
#     df_bright = pd.read_excel(file_save, sheet_name='BrightTimes')
#     ontimes = df_bright[str(potential)+'mV'].dropna().values
#     offtimes = df_dark[str(potential)+'mV'].dropna().values
#     sum_ontimes = np.append(sum_ontimes, sum(ontimes))
#     sum_offtimes = np.append(sum_offtimes, sum(offtimes))
# sum_ratio = sum_offtimes/sum_ontimes
# ax00.plot(potential_list, sum_ratio, '-b', label='time ratio of sums: Many single molecule')
ratio = tonav_update/toffav_update
ratio = ratio/(1+ratio)
ax00.plot(potential_list, ratio, '-*b', label='ratio/(1+ratio)')
# ax00.errorbar(potential_list, ratio, yerr=np.std(ratio), fmt='--')

# ax00.axhline(1, linestyle='--')
# ax00.axvline(60, linestyle='--')
# ax00.set_yscale('log')
# ax00.set_ylim(0.5, )
ax00.set_xlabel('Potential/mV')
# ax00.set_ylabel('ratio/(1+ratio)', color='b')
# ax00.tick_params('y', colors='b')
# ax00.legend()


# ax00_r = plt.twinx(ax00)
f_int_CuAzu647 = os.path.join(data_dir,'misc/bulk_switching/201803003_titration.xlsx');
df = pd.read_excel(f_int_CuAzu647, sheet_name=1,header=None, skiprows=1)
intensities = df[1] - 0.1*max(df[1])
intensities = intensities/max(intensities)
ax00.plot(df[0], intensities, '-*r', label = 'Ensemble intensity')
ax00.legend()#loc='lower center'

ax00.set_xlim(-100, 210)
plt.savefig(os.path.join(temp_dir, 'IntensityAndRatioVsPotential.svg'), format='svg', dpi=300, transparent=True)

# %%
#
fig = plt.figure(figsize=(5, 5))
nrows=1; ncols=1;
ax00 = plt.subplot2grid((nrows, ncols), (0,0))

# sum_ontimes = np.array([])
# sum_offtimes = np.array([])
# for potential in potential_list:
#     df_bright = pd.read_excel(file_save, sheet_name='BrightTimes')
#     ontimes = df_bright[str(potential)+'mV'].dropna().values
#     offtimes = df_dark[str(potential)+'mV'].dropna().values
#     sum_ontimes = np.append(sum_ontimes, sum(ontimes))
#     sum_offtimes = np.append(sum_offtimes, sum(offtimes))
# sum_ratio = sum_offtimes/sum_ontimes
# ax00.plot(potential_list[2:], sum_ratio[2:], '-*b', label='time ratio: Many single molecule')
# ax00.axhline(1, linestyle='--')
# ax00.axvline(60, linestyle='--')
# ax00.set_yscale('log')
# ax00.set_ylim(0.5, )
# ax00.set_xlabel('Potential/mV')
# ax00.set_ylabel('sum_offtimes/sum_ontimes')
# ax00.legend()


ax00_r = plt.twiny(ax00)
f_int_CuAzu647 = os.path.join(data_dir,'misc/bulk_switching/201803003_titration.xlsx');
df = pd.read_excel(f_int_CuAzu647, sheet_name=1,header=None, skiprows=1)

E, FeCN_oxd, FeCN_red = substrate_conc(E0=180, E=df[0].values, M=200e-6)
# ax00.plot(FeCN_oxd, df[1]/max(df[1]), '-*b', label = 'Intensity Vs [FeCN_oxd]')
# ax00.plot(FeCN_red, df[1]/max(df[1]), '-*r', label = 'Intensity Vs [FeCN_red]')
ax00.plot(FeCN_oxd/FeCN_red, df[1]/max(df[1]), '-*b',
          label = 'Intensity Vs [FeCN_red]/[FeCN_oxd]')
ax00.set_xlabel('FeCN_oxd/FeCN_red', color='b')
ax00.tick_params('x', colors='b')

# ax00.set_yscale('log')
ax00.set_xscale('log')
# ax00.set_xlabel('Conc/uM')
ax00.legend(loc='center right')

ax00_r.plot(df[0], df[1]/max(df[1]), '*g', label = 'Ensemble intensity Vs V')
ax00_r.set_ylabel('Intensity', color='g')
ax00_r.set_xlabel('Potential', color='g')
ax00_r.tick_params('x', colors='g')
ax00_r.legend()

# ax00.set_xlim(-100, 210)

# %%
k3 = 1/0.1
# K1 = kn1/k1
# K2 = kn2/k2
K1 = 2
K2 = 0.2
kn3 = 1/0.025
E, x, r = substrate_conc(E0=180, E=np.arange(-200, 200, 10), M=200e-6)
I = (kn3/k3)*(1+(K1/r))/(1+(K2/x))
I = I/max(I)
plt.plot(x/r, (1-I)/I)
plt.xscale('log')

# %% [markdown]
# # Time trace vs Potential

# %%
fig = timetraceplot_potentials(foldername=S130d02MAr18_590p_A1_4th, input_potential=[0, 100, 200],
                             pointnumbers=[22], x_lim_min=0, x_lim_max=10,
                             y_lim_min=0, y_lim_max=8, bintime=5e-3,
                             show_changepoint=True, figsize=(10, 6))
plt.savefig(os.path.join(temp_dir, 'timetrace_vs_V_az647N.svg'), format='svg', dpi=300, transparent=True)

# %% [markdown]
# # Midpoint (E0) variation

# %%
#MIDPOTENTIAL HISTGRAM FITTING
def plot_midpoint_hist(E0Values, ax, min_range = 0, max_range = 0.175, bins = 20):  
    range_fit = [min_range, max_range]
    bin_centers_on = linspace(range_fit[0], range_fit[1], bins)
    x=linspace(range_fit[0], range_fit[1], 100)# for a smooth fitting plot include more points

    from scipy.interpolate import interp1d
    from lmfit.models import GaussianModel
    mod = GaussianModel()
    n,bins_on1,patches = ax.hist(E0Values,
                                   bins = bins, range=range_fit,
                                   color='b', label='')#E0_list from running all folder
    y=n; x=bin_centers_on;
    result1 = mod.fit(y, center=0.01, amplitude=10, sigma=0.02, x=x)
    temp =result1.best_values
    FWHM = 2*temp['sigma']*1000 #V
    cent = temp['center']*1000#eV
    amp = temp['amplitude']

    ax.plot(x, result1.best_fit, '-k', label='Center: %.3f mV \n FWHM: %.2f mV' %(cent, FWHM))
    amp = temp['amplitude']
    height = 0.3989423*amp/max(1.e-15, temp['sigma'])
    ax.plot([cent*0.001, cent*0.001], [0, height+0.2*height], '--ok')

    ax.set_xlim(0, 0.2)
    ax.set_ylim(0,height+0.2*height)
    ax.set_ylabel('P')
    ax.set_xlabel('E0/V')
    ax.legend()
    return()

# %%
def Mid_potentials_pointwise(ax, folderpath, pointnumbers=range(5),
                             potentialist=range(-100, 210, 1),
                             process='cp', plotting=True,
                             min_pot=40, max_pot=150, min_pot_num=1,
                             color='b', marker='o'):
    '''
    Argument: 
    process: 'fcs' or 'cp'
    '''
    if process == 'cp':
        out = cp_outputs_folderwise(folderpath=folderpath,
                                    pointnumbers=pointnumbers,
                                    potentialist=potentialist)
    if process == 'fcs':
        out = fcs_outputs_folderwise(folderpath=folderpath,
                                     pointnumbers=pointnumbers,
                                     potentialist=potentialist)
    # Nernst Equation definition        
    def nernst(x, a):
        '''x is potential
        a: E0/midpoint potential(parameter)
        returns ratio(t_oxd/t_red)'''
        return(10**((x-a) / 0.059))
    nernst_mod = Model(nernst)
    params_nernst = nernst_mod.make_params(a=0.02)
    def nernst_slopem(x, a, m):
        return(10**((x-a) / m))
    nernst_slopem_mod = Model(nernst_slopem)
    params_ner_slop = nernst_slopem_mod.make_params(a=0.02, m=0.059)
    columns_E0 = ['Point number', 'E0_fit', 'E0_err']
    columns_E0_m = ['Point number', 'E0_fit', 'E0_err', 'slope', 'slope_error']
    E0_list = pd.DataFrame(index=None, columns=columns_E0)
    E0_m_list = pd.DataFrame(index=None, columns=columns_E0_m)
    #--figure initiation----
    for i in range(len(out.columns.levels[0])):
        point = out.columns.levels[0][i]
        point_output_tot = out[point].dropna()
        point_output = point_output_tot[point_output_tot['Potential'] >= min_pot] #select a potential threshold
        point_output = point_output[point_output['Potential'] <= max_pot] #select a potential threshold
        point_output.reset_index(drop=True, inplace=True)
        if len(point_output) > min_pot_num:
            potential = point_output['Potential']
            t_onav = point_output['t_onav']
            t_onaverr = point_output['t_onaverr']
            t_offav = point_output['t_offav']
            t_offaverr = point_output['t_offaverr']
            t_ratio = point_output['t_ratio']
            t_ratioerr = point_output['t_ratioerr']
            E = potential*0.001 #converting to mV
            #--------fitting nernst----------------
            res_nernst = nernst_mod.fit(t_ratio, params_nernst, x=E)
            out_params = str((res_nernst.params['a'],'value'));
            E0 = res_nernst.best_values['a']
            E0_err = float(out_params.split('+/- ')[1].split(', bounds')[0]);
            #---------append to list---------
            E0_list_temp = pd.DataFrame([[point, E0, E0_err]], columns=columns_E0)
            E0_list=E0_list.append(E0_list_temp, ignore_index=True)
            #--------fitting nernst_slopem------
            res_nernst_slop = nernst_slopem_mod.fit(t_ratio, params_ner_slop, x=E)
            E0_m = res_nernst_slop.best_values['a']
            out_params = str((res_nernst_slop.params['a'],'value'));
            E0_m_err = float(out_params.split('+/- ')[1].split(', bounds')[0]);
            slope_m = res_nernst_slop.best_values['m']
            out_params_m = str((res_nernst_slop.params['m'],'value'));
            slope_m_err = float(out_params_m.split('+/- ')[1].split(', bounds')[0]);
            E0_m_list_temp = pd.DataFrame([[point, E0_m, E0_m_err, slope_m, slope_m_err]], columns=columns_E0_m)
            E0_m_list = E0_m_list.append(E0_m_list_temp, ignore_index=True)
            #-----plot------
            if plotting == True:
                # ax.errorbar(point_output_tot['Potential'], point_output_tot['t_ratio'],
                #          yerr=point_output_tot['t_ratioerr'], fmt='o', color=color, label=point)#plot raw outputs
                ax.plot(point_output_tot['Potential'], point_output_tot['t_ratio'],marker, color=color)#plot raw outputs                
                ax.plot(linspace(min(potential)-10, max(potential)+10), nernst(0.001*linspace(min(potential)-10, max(potential)+10), E0), linewidth=2.0, color=color)#color
                #plot(E*1000, nernst(E, *E0_fit), color=color, linewidth=2.0)
                ax.set_yscale('log')
                ax.set_xlabel('$Potential [V]$')
                ax.set_ylabel('$t_{dark}/t_{bright}$')
                ax.tick_params(axis='both', which='major')
                tight_layout()
    return(E0_list, E0_m_list)

# %% [markdown]
# ## Different molecules

# %% [markdown]
# ### Ratio of times

# %%
plt.close('all')
fig = plt.figure(figsize=(3, 3))
nrows=1;ncols=1;
ax00 = plt.subplot2grid((nrows, ncols),(0,0))
E0_list, E0_m_list = Mid_potentials_pointwise(ax=ax00, folderpath=S130d02MAr18_590p_A1_4th,
                                              pointnumbers=[4],
                                              process='cp', plotting=True,
                                              min_pot=100, max_pot=200, min_pot_num=1,
                                              color='b', marker='o')
E0_list, E0_m_list = Mid_potentials_pointwise(ax=ax00, folderpath=S130d02MAr18_590p_A1_4th,
                                              pointnumbers=[22],
                                              process='cp', plotting=True,
                                              min_pot=100, max_pot=200, min_pot_num=1,
                                              color='r', marker='*')
E0_list, E0_m_list = Mid_potentials_pointwise(ax=ax00, folderpath=S130d02MAr18_590p_A1_4th,
                                              pointnumbers=[23],
                                              process='cp', plotting=True,
                                              min_pot=100, max_pot=200, min_pot_num=1,
                                              color='k', marker='x')

ax00.set_xlim(80, 210)
ax00.set_ylim(1e-1, 5e2)
ax00.legend(['Molecule 1', '',
             'Molecule 2', '',
             'Molecule 3', '',
            ], frameon=False, l)
plt.savefig(os.path.join(temp_dir, 't_ratio_vs_V_az647N.svg'), format='svg', dpi=300, transparent=True)

# %% [markdown]
# ### Histogram Midpoint potential

# %%
#Calculate midpoint potential of all points in all folders
E0_array = pd.DataFrame(index=None, columns=['Point number', 'E0_fit', 'E0_err'])
E0_m_array = pd.DataFrame(index=None, columns=['Point number', 'E0_fit', 'E0_err', 'slope', 'slope_error'])
for folder in allfolders:
    E0_list, E0_m_list = Mid_potentials_slopem_lmfit(folderpath=folder, pointnumbers=range(50),
                              process='cp', plotting=False,
                              min_pot=25, max_pot=200, min_pot_num=1)    
    E0_array = E0_array.append(E0_list, ignore_index=True)
    E0_m_array = E0_m_array.append(E0_m_list, ignore_index=True)
# Out:
# /home/biswajit/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:1110: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /home/biswajit/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/Azurin_SM_repo/Analysis/changepoint_process.py:438: RuntimeWarning: divide by zero encountered in double_scalars
#   lambda_toff_low = lambda_toff * (1-(1.96/np.sqrt(len(offtimes))))
# /home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/Azurin_SM_repo/Analysis/changepoint_process.py:439: RuntimeWarning: divide by zero encountered in double_scalars
#   lambda_toff_upp = lambda_toff * (1+(1.96/np.sqrt(len(offtimes))))

# %%
# Figure parameters
fig = plt.figure(figsize=(4, 3))
nrows=1; ncols=1;
ax00 = plt.subplot2grid((nrows, ncols), (0,0))
mpl.rcParams["font.family"] = "sans-serif"
mpl.rcParams["font.size"] = "12"
# Single azurin midpoint potential
plot_midpoint_hist(E0_array['E0_fit'], ax00)
plt.savefig(os.path.join(temp_dir, 'E0_ENS_SM_CV.svg'), format='svg', dpi=300, transparent=True)

# %% [markdown]
# ## Same molecule at different times

# %% [markdown]
# ### Ratio at different time

# %%
# Point 22
plt.close('all')
fig = plt.figure(figsize=(4, 4))
nrows=1;ncols=1;
ax00 = plt.subplot2grid((nrows, ncols),(0,0))

E0_list, E0_m_list = Mid_potentials_pointwise(ax=ax00, folderpath=S130d02MAr18_590p_A1,
                                                 pointnumbers=[22],
                                                 process='cp', plotting=True,
                                                 min_pot=100, max_pot=200, min_pot_num=1,
                                              color='b', marker='*')
E0_list, E0_m_list = Mid_potentials_pointwise(ax=ax00, folderpath=S130d02MAr18_590p_A1_2nd,
                                                 pointnumbers=[22],
                                                 process='cp', plotting=True,
                                                 min_pot=100, max_pot=200, min_pot_num=1,
                                              color='r', marker='*')
E0_list, E0_m_list = Mid_potentials_pointwise(ax=ax00, folderpath=S130d02MAr18_590p_A1_3rd,
                                                 pointnumbers=[22],
                                                 process='cp', plotting=True,
                                                 min_pot=100, max_pot=200, min_pot_num=1,
                                              color='g', marker='*')
E0_list, E0_m_list = Mid_potentials_pointwise(ax=ax00, folderpath=S130d02MAr18_590p_A1_4th,
                                                 pointnumbers=[22],
                                                 process='cp', plotting=True,
                                                 min_pot=100, max_pot=200, min_pot_num=1,
                                              color='k', marker='*')

ax00.legend(['0 hours', '',
             '1 hours', '',
             '2 hour', '',
             '3 hour', ''], fontsize=8)
ax00.set_xlim(90, 200)
ax00.set_ylim(1e-1, 5e2)
plt.savefig(os.path.join(temp_dir, 't_ratio_vs_V_diff_time.svg'), format='svg', dpi=300, transparent=True)

# %%
out = GetSpecificPoints(foldername=S130d02MAr18_590p_A1_2nd, input_potential=[100], pointnumbers=[22])
FilePathHdf5 = out['FilePathHdf5'][...][0]
h5 = h5py.File(FilePathHdf5, 'r')
print(h5['provenance']['creation_time'][...])
h5.close()
# Out:
# b'2018-03-02 22:15:24'

# %% [markdown]
# ### Distributions

# %%
E0Listfolders = {}
for folder in S130d02MAr18_A1_all:
    folderName = os.path.basename(folder)
    E0_list, E0_m_list = Mid_potentials_slopem_lmfit(folderpath=folder,
                                                     pointnumbers=range(50),
                                                     process='cp', plotting=False,
                                                     min_pot=90, max_pot=200, min_pot_num=1)
    E0_list['Point number'] = E0_list['Point number'].astype('int')
    E0_list = E0_list.sort_values(by=['Point number'])
    E0Listfolders[folderName] = E0_list
# Out:
# /home/biswajit/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:1110: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /home/biswajit/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/Azurin_SM_repo/Analysis/ChangePointProcess.py:441: RuntimeWarning: divide by zero encountered in double_scalars
#   lambda_toff_low = lambda_toff * (1-(1.96/np.sqrt(len(offtimes))))
# /home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/Azurin_SM_repo/Analysis/ChangePointProcess.py:442: RuntimeWarning: divide by zero encountered in double_scalars
#   lambda_toff_upp = lambda_toff * (1+(1.96/np.sqrt(len(offtimes))))

# %%
E0ListfoldersCompact = pd.DataFrame()
# print(E0Listfolders.keys())
for key in E0Listfolders.keys():
    E0ListfoldersCompact = E0ListfoldersCompact.append(E0Listfolders[key], ignore_index=True)
E0ListfoldersCompact = E0ListfoldersCompact.sort_values(by=['Point number'])
E0ListfoldersCompact = E0ListfoldersCompact.reset_index(drop=True)
E0ListfoldersCompact.head()
# Out:
#    Point number       E0_fit   E0_err
# 0             1  0.110287892  0.00312
# 1             1  0.122981485  0.00992
# 2             1  0.116027332  0.03640
# 3             2  0.108634247  0.01510
# 4             2  0.108934682  0.00462

# %%
DeltaE0 = E0ListfoldersCompact.diff().dropna()
DeltaE0 = DeltaE0[DeltaE0['Point number']==0]
# plt.hist(DeltaE0['E0_fit'], bins=20);

fig = plt.figure(figsize=(4, 3))
nrows=1; ncols=1;
ax00 = plt.subplot2grid((nrows, ncols), (0,0))
plot_midpoint_hist(DeltaE0['E0_fit'], ax00, 
                   min_range = -0.05, max_range = 0.05,
                   bins = 15)
ax00.set_xlim(-0.05, 0.05)
ax00.legend(frameon=False)
plt.savefig(os.path.join(temp_dir, 'Delta_E0_differenttimes.svg'),
            format='svg', dpi=300,transparent=True)

# %% [markdown]
# ## Save data to excel

# %%
timetrace_output = cp_outputs_folderwise(folderpath=S130d02MAr18_590p_A1_4th, pointnumbers=range(50), potentialist=range(-100, 210))

# %%
timetrace_output
# Out:
#     Point_1                                                                \
#   Potential       t_onav t_onaverr       t_offav t_offaverr       t_ratio
# 0       0.0  0.793598483   -1.0948  29.183742635   -40.2591  36.773939546
# 1       NaN          NaN       NaN           NaN        NaN           NaN
# 2       NaN          NaN       NaN           NaN        NaN           NaN
# 3       NaN          NaN       NaN           NaN        NaN           NaN
# 4       NaN          NaN       NaN           NaN        NaN           NaN
# 5       NaN          NaN       NaN           NaN        NaN           NaN
# 6       NaN          NaN       NaN           NaN        NaN           NaN
# 7       NaN          NaN       NaN           NaN        NaN           NaN
# 8       NaN          NaN       NaN           NaN        NaN           NaN
#
#                   Point_2                             ...         Point_26  \
#      t_ratioerr Potential       t_onav t_onaverr      ...       t_offaverr
# ...

# %%
writer = pd.ExcelWriter(os.path.join(temp_dir, 'durations_pointwise.xlsx'))
timetrace_output.to_excel(writer,'Sheet1')
writer.save()
# timetrace_output.to_csv(os.path.join(temp_dir, 'Potential_vs_durations'), sep='\t', encoding='utf-8', index=False)

# %%
print(timetrace_output.columns.levels)
df_point = timetrace_output['Point_19']

# Figure parameters
fig = plt.figure(figsize=(10, 5))
nrows=1; ncols=2;
ax00 = plt.subplot2grid((nrows, ncols), (0,0))
ax01 = plt.subplot2grid((nrows, ncols), (0,1))
df_point
for levels in timetrace_output.columns.levels[0]:
    df_point = timetrace_output[levels]
    ax00.plot(df_point['Potential'], df_point['t_onav'], '-*')
    ax01.plot(df_point['Potential'], df_point['t_offav'], '-*')
ax00.set_xlabel('Potential/mV')
ax00.set_ylabel('Bright time/ sec')
ax00.set_yscale('log')
ax00.legend(timetrace_output.columns.levels[0])
ax01.set_xlabel('Potential/mV')
ax01.set_ylabel('Bright time/ sec')
ax01.set_yscale('log')
# Out:
# [['Point_1', 'Point_13', 'Point_19', 'Point_2', 'Point_22', 'Point_23', 'Point_26', 'Point_29', 'Point_4', 'Point_6'], ['Potential', 't_offav', 't_offaverr', 't_onav', 't_onaverr', 't_ratio', 't_ratioerr']]
# /home/biswajit/anaconda3/lib/python3.6/site-packages/matplotlib/scale.py:111: RuntimeWarning: invalid value encountered in less_equal
#   out[a <= 0] = -1000

# %% [markdown]
# # Long time trace: Single-molecule

# %% [markdown]
# Select one of the following time trace:

# %%
# paths for the longazurin molecule
# 100 mV
file_path_hdf5_1 = os.path.join(data_dir, 'AzurinATTO647N/S130d02MAr18_590p_A3_100mV_longtimes/S103_550p_A3_100mV(35)_9.pt3.hdf5')
file_path_hdf5_2 = os.path.join(data_dir, 'AzurinATTO647N/20180223_longtime/data/Point_611p_N42CCuAzuATTO647N_A2_0100mV(29)_x.hdf5')
file_path_hdf5_3 = os.path.join(data_dir, 'AzurinATTO647N/20180223_longtime/data/Point_611p_N42CCuAzuATTO647N_A2_0100mV(27)_42.hdf5');
file_path_hdf5_4 = os.path.join(data_dir, 'AzurinATTO647N/S129d29Feb18_590p_A6_longtimes/data/Point_A6_longtime_0100mV(47)_1.hdf5')
file_path_hdf5_5 = os.path.join(data_dir, 'AzurinATTO647N/S129d29Feb18_590p_A6_longtimes/data/Point_A6_longtime_0100mV(47)_2.hdf5')
file_path_hdf5_6 = os.path.join(data_dir, 'AzurinATTO647N/S130d02MAr18_590p_A3_100mV_longtimes/data/S103_550p_A3_100mV(35)_11.hdf5')
file_path_hdf5_7 = os.path.join(data_dir, 'AzurinATTO647N/S130d02MAr18_590p_A3_100mV_longtimes/data/S103_550p_A3_100mV(35)_12.hdf5')
file_path_hdf5_8 = os.path.join(data_dir, 'AzurinATTO647N/S130d02MAr18_590p_A3_100mV_longtimes/data/S103_550p_A3_100mV(38)_16.hdf5')
# 150 mV
file_path_hdf5_9 = os.path.join(data_dir, 'AzurinATTO647N/S130d02MAr18_590p_A2_150mV_longtimes/data/S103_550p_A2_150mV(30)_2.hdf5')
file_path_hdf5_10 = os.path.join(data_dir, 'AzurinATTO647N/S130d02MAr18_590p_A2_150mV_longtimes/data/S103_550p_A2_150mV(31)_3.hdf5')
file_path_hdf5_11 = os.path.join(data_dir, 'AzurinATTO647N/S130d02MAr18_590p_A2_150mV_longtimes/data/S103_550p_A2_150mV(32)_5.hdf5')
file_path_hdf5_12 = os.path.join(data_dir, 'AzurinATTO647N/S130d02MAr18_590p_A2_150mV_longtimes/data/S103_550p_A2_150mV(32)_6.hdf5')
file_path_hdf5_13 = os.path.join(data_dir, 'AzurinATTO647N/S130d02MAr18_590p_A2_150mV_longtimes/data/S103_550p_A2_150mV(32)_7.hdf5')
# ZnAzurin
file_path_hdf5_Zn = os.path.join(data_dir, 'AzurinATTO655/ZnAzurin_Data/S107d1May17_635_ZnAzu655_longtime/S107d19May17_60.5_635_A5_ZnAzu655_000mV(30)/data/Point_A5_000mV(30)_60.5_240s_18.hdf5')
# Simulated
simulated_hdf5 = os.path.join(data_dir, 'SimulatedData/20180423_1618_ton0.1toff0.5timelen3600bg150sig1500.hdf5')
if os.path.isfile(file_path_hdf5_1):
    print('"file_path_hdf5" file found')
if os.path.isfile(simulated_hdf5):
    print('"simulated_hdf5" also file found')
# Out:
# "file_path_hdf5" file found
# "simulated_hdf5" also file found

# %% [markdown]
# ## Simulated Object

# %%
# Simulated data
ObjLongTraceSimulated = LongTraceClass(simulated_hdf5, Simulation=True)
ObjLongTraceSimulated.TimeLimit = [0, 3000]
# ObjSim.onoff_values();
ObjLongTraceSimulated.LongTraceByParts(TimeWindow=2e2,TimePeriod=2e2);
ObjLongTraceSimulated.PlotLongTraceByParts()
ObjLongTraceSimulated.FigureByParts.savefig(
    os.path.join(temp_dir, 'FigureByPartsSimulated.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# Input file is 20180423_1618_ton0.1toff0.5timelen3600bg150sig1500.hdf5
# looking for df_ts 82809

# %% [markdown]
# ## Measured Object

# %%
ObjLongTraceMeasured = LongTraceClass(file_path_hdf5_1)
# ObjLongTraceMeasured.TimeLimit = [0, 1200]
ObjLongTraceMeasured.PlotTimeTrace(figsize=(10, 4))
# Out:
# Input file is S103_550p_A3_100mV(35)_9.pt3.hdf5

# %% [markdown]
# ## By parts

# %%
ObjLongTraceMeasured.TimeLimit = [0, 2500]
ObjLongTraceMeasured.BintimeForIntTrace = 5e-3
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=1e2,TimePeriod=1e2);
ObjLongTraceMeasured.PlotLongTraceByParts()
ObjLongTraceMeasured.FigureByParts.savefig(
    os.path.join(temp_dir, 'FigureByPartsCuAzuATTO647N.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# looking for df_ts 40812

# %% [markdown]
# ## Duration Vs Time

# %%
ObjLongTraceMeasured.TimeLimit = (0, 2600)
ObjLongTraceMeasured.onoff_values();
ObjLongTraceMeasured.df_durations.head()
# Out:
#     abstime_on      ontimes  abstime_off     offtimes
# 0  1.567041959  0.286946015  0.797508601  1.378600714
# 1  4.610788048  0.159340715  3.033458591  2.811869274
# 2  4.937606473  0.045225746  4.796671421  0.217815636
# 3  6.335073111  0.270918466  5.604637053  1.220328703
# 4  7.974567507  0.145775131  7.158011149  1.422812833

# %%
ObjLongTraceMeasured.InsetRangeBrightHist = [0, 0.2]
ObjLongTraceMeasured.InsetRangeDarkHist = [0,2]
ObjLongTraceMeasured.LagTimeLimitCorrelation = [0, 10e2]
ObjLongTraceMeasured.ContrastLimitCorrelation = [-0.1, 0.3]

ObjLongTraceMeasured.PlotDurationsVsTime()
ObjLongTraceMeasured.axis32.set_ylim(-0.1, 0.3)
ObjLongTraceMeasured.FigureDuration.savefig(
    os.path.join(temp_dir, 'longtrace_dynamic_het_temp.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# k1:6.58237178374
# [   6.58237178    0.96225539  193.28945553]
# k1:0.878869428317
# [   0.87886943    0.88213255  248.71566931]

# %% [markdown]
# ## Histogram FCS

# %%
# Real data
# ObjLongTraceMeasured.TimeLimit = [0, 2700]
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=1e2, TimePeriod=1e2);
ObjLongTraceMeasured.StatsLongTraceByParts()

# Simulated data
# ObjSim.TimeLimit = [0, 2700]
ObjLongTraceSimulated.LongTraceByParts(TimeWindow=1e2, TimePeriod=1e2);
ObjLongTraceSimulated.StatsLongTraceByParts()
# Out:
# looking for df_ts 40812
# looking for df_ts 42681

# %%
from LongTraceAnalysis import FCSCorrTimeAmp2D
FCSCorrTimeAmp2D(ObjLongTraceMeasured, ObjLongTraceSimulated,
                 RangeCorrTime = [0, .4],
                 RangeCorrAmplitude = [1.5, 3.5])
plt.savefig(
    os.path.join(temp_dir, 'FigureStatsByPartsColorBar.svg'),
    format='svg', dpi=300, transparent=True)

# %%
# plt.hist(ob.df_lt_fit['tau2'])
plt.figure(figsize=(4,4))
plt.scatter(ob.df_lt_fit['ampl1'],
           ob.df_lt_fit['ampl2'])
plt.scatter(ObjSim.df_lt_fit['ampl1'],
           ObjSim.df_lt_fit['ampl2'])
plt.xlim(0.05, 0.95)
plt.ylim(0.05, 0.95)
# Out:
# (0.05, 0.95)

# %% [markdown]
# ## 2D Histogram: Bright times

# %%
# Real data
ob = LongTraceClass(file_path_hdf5_1)
ob.TimeLimit = [0, 2600]
ob.onoff_values();
# Out:
# Input file is S103_550p_A3_100mV(35)_9.pt3.hdf5
# Input file is 20180423_1618_ton0.1toff0.5timelen3600bg150sig1500.hdf5

# %%
def Plot2Ddurations(axis, df_durations, RollMean = True,
                    NumPointsForAveraging = 10,
                    shift_range = range(1, 10, 1),
                    ontimes = True):
    rangee = [0,0.8]
    if RollMean:
        df_roll_mean = df_durations.rolling(
            NumPointsForAveraging).mean().dropna().reset_index(drop=True)        
        df_select = df_roll_mean
    else:
        df_mean = df_durations.groupby(np.arange(len(df_durations))//
            NumPointsForAveraging).mean().dropna().reset_index(drop=True)
        df_select = df_mean
    T=np.array([]); T_shift = np.array([])
    for i in shift_range:
        shift = i  
        if ontimes:
            T = np.append(T, df_select['ontimes'][shift:].values)
            T_shift = np.append(T_shift, df_select['ontimes'][:-shift].values)
        else:
            T = np.append(T, df_select['offtimes'][shift:].values)
            T_shift = np.append(T_shift, df_select['offtimes'][:-shift].values)            
        
    axis.hist2d(T, T_shift,
               bins=40, range=([rangee, rangee]),
               norm=mpl.colors.LogNorm());
    axis.set_xlabel('t(n)')
    axis.set_ylabel('t(n+{})'.format(i))
    ax01.text(0.1, 0.6, 'No. of points for averaging:{}'.format(NumPointsForAveraging))    
    return axis
fig = plt.figure(figsize=(12,5))
nrows=1;ncols=2
ax00 = plt.subplot2grid((nrows,ncols), (0,0))
ax01 = plt.subplot2grid((nrows,ncols), (0,1))

Plot2Ddurations(ax00, ob.df_durations, RollMean=False,
                NumPointsForAveraging=10, shift_range=[1])
ax00.set_title('CuAzurin ATTO647N')

Plot2Ddurations(ax01, ObjSim.df_durations, RollMean=False,
                NumPointsForAveraging=10, shift_range=[1])
ax01.set_title('Simulated: No heterogeneity');

# %%
fig = plt.figure(figsize=(12,5))
nrows=1;ncols=2
ax00 = plt.subplot2grid((nrows,ncols), (0,0))
ax01 = plt.subplot2grid((nrows,ncols), (0,1))

Plot2Ddurations(ax00, ob.df_durations, RollMean=False,
                NumPointsForAveraging=10, shift_range=range(1, 5, 1))

Plot2Ddurations(ax01, ObjSim.df_durations, RollMean=False,
                NumPointsForAveraging=10, shift_range=range(1, 5, 1))
plt.savefig(
    os.path.join(temp_dir, 'Figure2Dhist.svg'),
    format='svg', dpi=300, transparent=True)
