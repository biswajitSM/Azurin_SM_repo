# %%
# toogle view
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %% [markdown]
# # Directories and modules

# %%
#list of folders and their directories CuAZUATTO647N % ZnAzuATTO647N
import os
Analysis_dir = '/home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/Azurin_SM_repo/Analysis'
data_dir = '/home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/data'#GIVE the PATH of this FOLDER.
# Checking or creating temp_dir
temp_dir = 'temp'
temp_dir = os.path.join(temp_dir)
if os.path.isdir(temp_dir):
    print('temp_dir exists')
else:
    os.makedirs(temp_dir)
    print('temp_dir created')
# Out:
# temp_dir exists

# %%
# import modules
import sys
sys.path.append(Analysis_dir)
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import numpy as np
from LongTraceAnalysis import LongTraceClass, FCSCorrTimeAmp2D
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from pylab import *
matplotlib.rcParams['svg.fonttype'] = 'none'
mpl.rcParams["font.family"] = "sans-serif"
mpl.rcParams["font.size"] = "10"
rc('axes', linewidth=1)
# plt.savefig('/home/biswajit/Downloads/test.svg', format='svg', transparent=True)

# %% [markdown]
# # Simulated Data

# %% [markdown]
# ### Trace By Parts

# %%
# Simulated data
simulated_hdf5 = os.path.join(data_dir, 'SimulatedData/20180125_2239_ton0.016toff0.25timelen1000bg200sig3000.hdf5')    
if os.path.isfile(simulated_hdf5):
    print('"simulated_hdf5" also file found')
ObjLongTraceSimulated = LongTraceClass(simulated_hdf5, Simulation=True)
# ObjLongTraceSimulated.TimeLimit = [0, 2700]
ObjLongTraceSimulated.LongTraceByParts(TimeWindow=1e2,TimePeriod=1e2);
ObjLongTraceSimulated.PlotLongTraceByParts()
ObjLongTraceSimulated.axis11.set_ylim(5e-2, 1.1)
ObjLongTraceSimulated.axis11.set_xlim(4,)
ObjLongTraceSimulated.axis21.set_ylim(0, 3.5)
# ObjLongTraceSimulated.axis10.set_xlim(100, 125)
# Out:
# "simulated_hdf5" also file found
# Input file is 20180125_2239_ton0.016toff0.25timelen1000bg200sig3000.hdf5
# looking for df_ts 41181
# (0, 3.5)

# %% [markdown]
# ### 2D FCS Time Vs G(0)

# %%
ObjLongTraceSimulated.LongTraceByParts(TimeWindow=2e2, TimePeriod=1e1);
ObjLongTraceSimulated.StatsLongTraceByParts()# To be used for comparision with Measured data
# Out:
# looking for df_ts 79149

# %%
FCSCorrTimeAmp2D(ObjLongTraceSimulated, ObjLongTraceSimulated,
                 RangeCorrTime = [0, .03],
                 RangeCorrAmplitude = [2, 5])

# %% [markdown]
# ### Bright-Dark trace-corr

# %%
ObjLongTraceSimulated.onoff_values();

# %%
ObjLongTraceSimulated.InsetRangeBrightHist = [0, 0.2]
ObjLongTraceSimulated.InsetRangeDarkHist = [0,2]
ObjLongTraceSimulated.AppliedPotential = 100
ObjLongTraceSimulated.PlotDurationsVsTime()

filename = os.path.basename(ObjLongTraceSimulated.file_path_hdf5)
ObjLongTraceSimulated.FigureDuration.savefig(
    os.path.join(temp_dir, filename[:-5]+'BrightDarkHist.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# k1:46.7337037192
# [  4.67337037e+01   1.08376314e+00   1.90643584e+03]
# k1:3.30130464297
# [  3.30130464e+00   1.03920523e+00   1.51597777e+03]

# %% [markdown]
# # CuAzurin ATTO647N

# %% [markdown]
# ### List of Molecules

# %%
# paths for the longazurin molecule
# 100 mV
FilePathHdf5_1 = os.path.join(data_dir, 'AzurinATTO655/CuAzuATTO655/S106d18May17_longtime/100mV/Point_A9_100mV(18)_60.5_750s_24.pt3.hdf5')
FilePathHdf5_2 = os.path.join(data_dir, 'AzurinATTO655/CuAzuATTO655/S106d18May17_longtime/100mV/Point_A9_100mV(18)_60.5_1600s_26.pt3.hdf5')
FilePathHdf5_3 = os.path.join(data_dir, 'AzurinATTO655/CuAzuATTO655/S106d18May17_longtime/100mV/Point_A9_100mV(18)_60.5_900s_27.pt3.hdf5')
FilePathHdf5_4 = os.path.join(data_dir, 'AzurinATTO655/CuAzuATTO655/S105d15May17_longtime/100mV/Point_A1_100mV(10)_60.5_1200s_24.pt3.hdf5')
# 75 mV
FilePathHdf5_5 = os.path.join(data_dir, 'AzurinATTO655/CuAzuATTO655/S105d15May17_longtime/75mV/Point_A1_075mV(9)_60.5_180s_19.pt3.hdf5')
FilePathHdf5_6 = os.path.join(data_dir, 'AzurinATTO655/CuAzuATTO655/S105d15May17_longtime/75mV/Point_A1_075mV(9)_60.5_900s_20.pt3.hdf5')
FilePathHdf5_7 = os.path.join(data_dir, 'AzurinATTO655/CuAzuATTO655/S105d15May17_longtime/75mV/Point_A1_075mV(9)_60.5_900sSpecialReactivation_21.pt3.hdf5')
FilePathHdf5_8 = os.path.join(data_dir, 'AzurinATTO655/CuAzuATTO655/S105d15May17_longtime/75mV/Point_A1_075mV(9)_60.5_900s_22.pt3.hdf5')
FilePathHdf5_9 = os.path.join(data_dir, 'AzurinATTO655/CuAzuATTO655/S105d15May17_longtime/75mV/Point_A1_075mV(9)_60.5_360s_23.pt3.hdf5')

FilePathHdf5_10 = os.path.join(data_dir, 'AzurinATTO655/CuAzuATTO655/S106d18May17_longtime/75mV/Point_A7_075mV(12)_60.5_420s_12.pt3.hdf5')
FilePathHdf5_11 = os.path.join(data_dir, 'AzurinATTO655/CuAzuATTO655/S106d18May17_longtime/75mV/Point_A7_075mV(12)_60.5_360s_13.pt3.hdf5')
FilePathHdf5_12 = os.path.join(data_dir, 'AzurinATTO655/CuAzuATTO655/S106d18May17_longtime/75mV/Point_A7_075mV(12)_60.5_1160s_15.pt3.hdf5')
# 50 mV
FilePathHdf5_13 = os.path.join(data_dir, 'AzurinATTO655/CuAzuATTO655/S105d15May17_longtime/50mV/Point_A1_050mV(7)_60.5_1920s_16.pt3.hdf5')

FilePathHdf5_14 = os.path.join(data_dir, 'AzurinATTO655/CuAzuATTO655/S106d18May17_longtime/50mV/Point_A8_050mV(15)_60.5_700s_23.pt3.hdf5')
FilePathHdf5_15 = os.path.join(data_dir, 'AzurinATTO655/CuAzuATTO655/S106d18May17_longtime/50mV/Point_A8_050mV(15)_60.5_1980s_22.pt3.hdf5')
# ZnAzurin
FilePathHdf5_Zn = os.path.join(data_dir, 'AzurinATTO655/ZnAzurin_Data/S107d1May17_635_ZnAzu655_longtime/S107d19May17_60.5_635_A5_ZnAzu655_000mV(30)/Point_A5_000mV(30)_60.5_240s_18.pt3.hdf5')
# Simulated
if os.path.isfile(FilePathHdf5_1):
    print('"FilePathHdf5" file found')
# Out:
# "FilePathHdf5" file found

# %% [markdown]
# ## Molecule-1

# %% [markdown]
# ### Trace By Parts

# %%
ObjLongTraceMeasured = LongTraceClass(FilePathHdf5_1)
# ObjLongTraceMeasured.TimeLimit = [0, 2800]
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=1e2,TimePeriod=1e2);
ObjLongTraceMeasured.PlotLongTraceByParts()
ObjLongTraceMeasured.axis11.set_xlim(4, )
ObjLongTraceMeasured.axis11.set_ylim(5e-2, 1.1)
ObjLongTraceMeasured.axis21.set_ylim(0, 1.5)
# ObjLongTraceMeasured.axis10.set_xlim(100, 125)
ObjLongTraceMeasured.FigureByParts.savefig(
    os.path.join(temp_dir, os.path.basename(FilePathHdf5_1)[:-5]+'.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# Input file is Point_A9_100mV(18)_60.5_750s_24.pt3.hdf5
# looking for df_ts 25491

# %% [markdown]
# ### 2D FCS Time Vs G(0)

# %%
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=2e2, TimePeriod=1e1);
ObjLongTraceMeasured.StatsLongTraceByParts()
# Out:
# looking for df_ts 85818

# %%
FCSCorrTimeAmp2D(ObjLongTraceMeasured, ObjLongTraceSimulated,
                 RangeCorrTime = [0, .06],
                 RangeCorrAmplitude = [0, 3.5])

# %% [markdown]
# ### Bright-Dark trace-corr

# %%
ObjLongTraceMeasured.onoff_values();

# %%
ObjLongTraceMeasured.TimeLimit = [0, 700]
ObjLongTraceMeasured.InsetRangeBrightHist = [0, 0.1]
ObjLongTraceMeasured.InsetRangeDarkHist = [0,2]
ObjLongTraceMeasured.RangeForMidPotentialHist = [-60, 50]

ObjLongTraceMeasured.PlotDurationsVsTime()
ObjLongTraceMeasured.axis01.set_ylim(0, 0.05)
ObjLongTraceMeasured.FigureDuration.savefig(
    os.path.join(temp_dir, 'longtrace_dynamic_het_temp.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# k1:4733.94418958
# [  4.73394419e+03   2.54992941e-01   7.92399807e+02]
# k1:3.46277168184
# [   3.46277168    0.53313783  269.54199955]

# %% [markdown]
# ## Molecule-2

# %% [markdown]
# ###  Trace By Parts

# %%
ObjLongTraceMeasured = LongTraceClass(FilePathHdf5_2)
# ObjLongTraceMeasured.TimeLimit = [0, 2800]
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=2e2,TimePeriod=2e2);
ObjLongTraceMeasured.PlotLongTraceByParts()

ObjLongTraceMeasured.axis11.set_ylim(7e-2,)
ObjLongTraceMeasured.axis21.set_ylim(0, 2)
# ObjLongTraceMeasured.axis10.set_xlim(100, 125)
ObjLongTraceMeasured.FigureByParts.savefig(
    os.path.join(temp_dir, os.path.basename(FilePathHdf5_1)[:-5]+'.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# Input file is Point_A9_100mV(18)_60.5_1600s_26.pt3.hdf5
# looking for df_ts 62539

# %% [markdown]
# ### 2D FCS Time Vs G(0)

# %%
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=2e2, TimePeriod=2e1);
ObjLongTraceMeasured.StatsLongTraceByParts()
# Out:
# looking for df_ts 63790

# %%
FCSCorrTimeAmp2D(ObjLongTraceMeasured, ObjLongTraceSimulated,
                 RangeCorrTime = [0, .05],
                 RangeCorrAmplitude = [0, 3.5])

# %% [markdown]
# ### Bright-Dark trace-corr

# %%
ObjLongTraceMeasured.onoff_values();

# %%
# ObjLongTraceMeasured.TimeLimit = [0, 1200]
ObjLongTraceMeasured.RangeForBrightHist = [0, 0.1]
ObjLongTraceMeasured.InsetRangeBrightHist = [0, 0.05]
ObjLongTraceMeasured.RangeForDarkHist = [0, 5]
ObjLongTraceMeasured.InsetRangeDarkHist = [0,2]
ObjLongTraceMeasured.RangeForMidPotentialHist = [-60, 50]
ObjLongTraceMeasured.Range2DHistBright = [0, 0.05]

ObjLongTraceMeasured.PlotDurationsVsTime()
ObjLongTraceMeasured.axis01.set_ylim(0, 0.03)
ObjLongTraceMeasured.FigureDuration.savefig(
    os.path.join(temp_dir, 'longtrace_dynamic_het_temp.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# k1:86.497348284
# [  86.49734828    2.28738551  448.37716549]
# k1:2.12846503753
# [   2.12846504    1.15213816  534.74377241]

# %% [markdown]
# ## Molecule-3

# %% [markdown]
# ### Trace By Parts

# %%
ObjLongTraceMeasured = LongTraceClass(FilePathHdf5_3)
# ObjLongTraceMeasured.TimeLimit = [0, 2800]
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=1e2,TimePeriod=1e2);
ObjLongTraceMeasured.PlotLongTraceByParts()
ObjLongTraceMeasured.axis21.set_ylim(0, 2)
# ObjLongTraceMeasured.axis10.set_xlim(100, 125)
ObjLongTraceMeasured.FigureByParts.savefig(
    os.path.join(temp_dir, os.path.basename(FilePathHdf5_1)[:-5]+'.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# Input file is Point_A9_100mV(18)_60.5_900s_27.pt3.hdf5
# looking for df_ts 24295

# %% [markdown]
# ### 2D FCS Time Vs G(0)

# %%
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=2e2, TimePeriod=2e1);
ObjLongTraceMeasured.StatsLongTraceByParts()
# Out:
# looking for df_ts 48340

# %%
FCSCorrTimeAmp2D(ObjLongTraceMeasured, ObjLongTraceSimulated,
                 RangeCorrTime = [0, .03],
                 RangeCorrAmplitude = [0, 3.5])

# %% [markdown]
# ### Bright-Dark trace-corr

# %%
ObjLongTraceMeasured.onoff_values();

# %%
# ObjLongTraceMeasured.TimeLimit = [0, 1200]
ObjLongTraceMeasured.RangeForBrightHist = [0, 0.1]
ObjLongTraceMeasured.InsetRangeBrightHist = [0, 0.05]
ObjLongTraceMeasured.RangeForDarkHist = [0, 5]
ObjLongTraceMeasured.InsetRangeDarkHist = [0,2]
ObjLongTraceMeasured.RangeForMidPotentialHist = [-60, 50]
ObjLongTraceMeasured.Range2DHistBright = [0, 0.05]

ObjLongTraceMeasured.PlotDurationsVsTime()
ObjLongTraceMeasured.axis01.set_ylim(0, 0.03)
ObjLongTraceMeasured.axis32.set_ylim(0, 0.3)
ObjLongTraceMeasured.FigureDuration.savefig(
    os.path.join(temp_dir, 'longtrace_dynamic_het_temp.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# k1:61.6526143998
# [ 61.6526144    2.13023621  80.08817717]
# k1:0.89779953998
# [  0.89779954   1.29170345  60.0229395 ]

# %% [markdown]
# ## Molecule-4

# %% [markdown]
# ### Trace By Parts

# %%
ObjLongTraceMeasured = LongTraceClass(FilePathHdf5_4)
ObjLongTraceMeasured.TimeLimit = [0, 810]
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=1e2,TimePeriod=1e2);
ObjLongTraceMeasured.PlotLongTraceByParts()

ObjLongTraceMeasured.axis11.set_ylim(3e-2,)
ObjLongTraceMeasured.axis21.set_xlim(1e-5, 1e1)
ObjLongTraceMeasured.axis21.set_ylim(0, 2)
# ObjLongTraceMeasured.axis10.set_xlim(100, 125)
ObjLongTraceMeasured.FigureByParts.savefig(
    os.path.join(temp_dir, os.path.basename(FilePathHdf5_1)[:-5]+'.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# Input file is Point_A1_100mV(10)_60.5_1200s_24.pt3.hdf5
# looking for df_ts 35766

# %% [markdown]
# ### 2D FCS Time Vs G(0)

# %%
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=2e2, TimePeriod=2e1);
ObjLongTraceMeasured.StatsLongTraceByParts()
# Out:
# looking for df_ts 68852

# %%
FCSCorrTimeAmp2D(ObjLongTraceMeasured, ObjLongTraceSimulated,
                 RangeCorrTime = [0, 0.03],
                 RangeCorrAmplitude = [0, 4])

# %% [markdown]
# ### Bright-Dark trace-corr

# %%
ObjLongTraceMeasured.onoff_values();

# %%
# ObjLongTraceMeasured.TimeLimit = [0, 1200]
ObjLongTraceMeasured.RangeForBrightHist = [0, 0.2]
ObjLongTraceMeasured.InsetRangeBrightHist = [0, 0.05]
ObjLongTraceMeasured.RangeForDarkHist = [0, 5]
ObjLongTraceMeasured.InsetRangeDarkHist = [0,2]
ObjLongTraceMeasured.RangeForMidPotentialHist = [-100, 50]
ObjLongTraceMeasured.Range2DHistBright = [0, 0.05]

ObjLongTraceMeasured.PlotDurationsVsTime()
ObjLongTraceMeasured.axis01.set_ylim(0, 0.03)
ObjLongTraceMeasured.axis32.set_ylim(-0.1, 0.5)
ObjLongTraceMeasured.FigureDuration.savefig(
    os.path.join(temp_dir, 'longtrace_dynamic_het_temp.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# k1:302.241929955
# [ 302.24192995    1.35282073  780.0584044 ]
# k1:1.12873254309
# [   1.12873254    1.21816722  115.27483739]

# %% [markdown]
# ## Molecule-5

# %% [markdown]
# ### Trace By Parts

# %%
ObjLongTraceMeasured = LongTraceClass(FilePathHdf5_5)
# ObjLongTraceMeasured.TimeLimit = [0, 2800]
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=5e1,TimePeriod=5e1);
ObjLongTraceMeasured.PlotLongTraceByParts()
ObjLongTraceMeasured.axis21.set_ylim(0, 2)
# ObjLongTraceMeasured.axis10.set_xlim(100, 125)
ObjLongTraceMeasured.FigureByParts.savefig(
    os.path.join(temp_dir, os.path.basename(FilePathHdf5_1)[:-5]+'.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# Input file is Point_A1_075mV(9)_60.5_180s_19.pt3.hdf5
# looking for df_ts 24207

# %% [markdown]
# ### 2D FCS Time Vs G(0)

# %%
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=1e2, TimePeriod=2e1);
ObjLongTraceMeasured.StatsLongTraceByParts()
# Out:
# looking for df_ts 43325

# %%
FCSCorrTimeAmp2D(ObjLongTraceMeasured, ObjLongTraceSimulated,
                 RangeCorrTime = [0, 0.3],
                 RangeCorrAmplitude = [1, 7])

# %% [markdown]
# ### Bright-Dark trace-corr

# %%
ObjLongTraceMeasured.onoff_values();

# %%
# ObjLongTraceMeasured.TimeLimit = [0, 1200]
ObjLongTraceMeasured.RangeForBrightHist = [0, 0.2]
ObjLongTraceMeasured.InsetRangeBrightHist = [0, 0.05]
ObjLongTraceMeasured.RangeForDarkHist = [0, 5]
ObjLongTraceMeasured.InsetRangeDarkHist = [0,2]
ObjLongTraceMeasured.RangeForMidPotentialHist = [-60, 50]
ObjLongTraceMeasured.Range2DHistBright = [0, 0.1]

ObjLongTraceMeasured.PlotDurationsVsTime()
ObjLongTraceMeasured.axis01.set_ylim(0, 0.1)
ObjLongTraceMeasured.FigureDuration.savefig(
    os.path.join(temp_dir, 'longtrace_dynamic_het_temp.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# k1:16.5734026243
# [ 16.57340262   1.6763631   26.04710337]
# k1:4.29836444795
# [   4.29836445    0.68137916  110.47376066]

# %% [markdown]
# ## Molecule-6

# %% [markdown]
# ### Trace By Parts

# %%
ObjLongTraceMeasured = LongTraceClass(FilePathHdf5_6)
# ObjLongTraceMeasured.TimeLimit = [0, 600]
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=1e2,TimePeriod=1e2);
ObjLongTraceMeasured.PlotLongTraceByParts()
ObjLongTraceMeasured.axis21.set_ylim(0, 3.5)
# ObjLongTraceMeasured.axis10.set_xlim(100, 125)
ObjLongTraceMeasured.FigureByParts.savefig(
    os.path.join(temp_dir, os.path.basename(FilePathHdf5_1)[:-5]+'.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# Input file is Point_A1_075mV(9)_60.5_900s_20.pt3.hdf5
# looking for df_ts 44019

# %% [markdown]
# ### 2D FCS Time Vs G(0)

# %%
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=2e2, TimePeriod=2e1);
ObjLongTraceMeasured.StatsLongTraceByParts()
# Out:
# looking for df_ts 86769

# %%
FCSCorrTimeAmp2D(ObjLongTraceMeasured, ObjLongTraceSimulated,
                 RangeCorrTime = [0, .03],
                 RangeCorrAmplitude = [2, 4])

# %% [markdown]
# ### Bright-Dark trace-corr

# %%
ObjLongTraceMeasured.onoff_values();

# %%
# ObjLongTraceMeasured.TimeLimit = [0, 1200]
ObjLongTraceMeasured.RangeForBrightHist = [0, 0.1]
ObjLongTraceMeasured.InsetRangeBrightHist = [0, 0.05]
ObjLongTraceMeasured.RangeForDarkHist = [0, 5]
ObjLongTraceMeasured.InsetRangeDarkHist = [0,2]
ObjLongTraceMeasured.RangeForMidPotentialHist = [-60, 50]
ObjLongTraceMeasured.Range2DHistBright = [0, 0.05]

ObjLongTraceMeasured.PlotDurationsVsTime()
ObjLongTraceMeasured.axis01.set_ylim(0, 0.1)
ObjLongTraceMeasured.axis32.set_ylim(0, 0.2)
ObjLongTraceMeasured.FigureDuration.savefig(
    os.path.join(temp_dir, 'longtrace_dynamic_het_temp.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# k1:80.3575637403
# [  80.35756374    1.75239726  408.87168299]
# k1:3.4319691904
# [   3.43196919    0.96375537  764.04518463]

# %% [markdown]
# ## Molecule-7
# ### Trace By Parts

# %%
ObjLongTraceMeasured = LongTraceClass(FilePathHdf5_7)
# ObjLongTraceMeasured.TimeLimit = [0, 2800]
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=5e1,TimePeriod=5e1);
ObjLongTraceMeasured.PlotLongTraceByParts()
ObjLongTraceMeasured.axis21.set_ylim(0, 2.5)
# ObjLongTraceMeasured.axis10.set_xlim(100, 125)
ObjLongTraceMeasured.FigureByParts.savefig(
    os.path.join(temp_dir, os.path.basename(FilePathHdf5_1)[:-5]+'.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# Input file is Point_A1_075mV(9)_60.5_900sSpecialReactivation_21.pt3.hdf5
# looking for df_ts 22639

# %% [markdown]
# ### 2D FCS Time Vs G(0)

# %%
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=1e2, TimePeriod=1e1);
ObjLongTraceMeasured.StatsLongTraceByParts()
# Out:
# looking for df_ts 130472

# %%
FCSCorrTimeAmp2D(ObjLongTraceMeasured, ObjLongTraceSimulated,
                 RangeCorrTime = [0, .03],
                 RangeCorrAmplitude = [0.5, 5])

# %% [markdown]
# ### Bright-Dark trace-corr

# %%
ObjLongTraceMeasured.onoff_values();

# %%
ObjLongTraceMeasured.TimeLimit = [0, 440]
ObjLongTraceMeasured.RangeForBrightHist = [0, 0.1]
ObjLongTraceMeasured.InsetRangeBrightHist = [0, 0.05]
ObjLongTraceMeasured.RangeForDarkHist = [0, 5]
ObjLongTraceMeasured.InsetRangeDarkHist = [0,2]
ObjLongTraceMeasured.RangeForMidPotentialHist = [-60, 50]
ObjLongTraceMeasured.Range2DHistBright = [0, 0.05]

ObjLongTraceMeasured.PlotDurationsVsTime()
ObjLongTraceMeasured.axis01.set_ylim(0, 0.03)
ObjLongTraceMeasured.axis32.set_ylim(-0.1, 5)
ObjLongTraceMeasured.FigureDuration.savefig(
    os.path.join(temp_dir, 'longtrace_dynamic_het_temp.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# k1:151.644731062
# [ 151.64473106    1.42107916  315.84260855]
# k1:4.0580816485
# [   4.05808165    0.99743546  376.1151668 ]

# %% [markdown]
# ## Molecule-8
# ### Trace By Parts

# %%
ObjLongTraceMeasured = LongTraceClass(FilePathHdf5_8)
# ObjLongTraceMeasured.TimeLimit = [0, 2800]
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=5e1,TimePeriod=5e1);
ObjLongTraceMeasured.PlotLongTraceByParts()
ObjLongTraceMeasured.axis21.set_ylim(0, 3.5)
ObjLongTraceMeasured.axis21.set_xlim(1e-5, 1e1)
# ObjLongTraceMeasured.axis10.set_xlim(100, 125)
ObjLongTraceMeasured.FigureByParts.savefig(
    os.path.join(temp_dir, os.path.basename(FilePathHdf5_1)[:-5]+'.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# Input file is Point_A1_075mV(9)_60.5_900s_22.pt3.hdf5
# looking for df_ts 59992

# %% [markdown]
# ### 2D FCS Time Vs G(0)

# %%
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=1e2, TimePeriod=2e1);
ObjLongTraceMeasured.StatsLongTraceByParts()
# Out:
# looking for df_ts 108192

# %%
FCSCorrTimeAmp2D(ObjLongTraceMeasured, ObjLongTraceSimulated,
                 RangeCorrTime = [0, .04],
                 RangeCorrAmplitude = [1.5, 5])

# %% [markdown]
# ### Bright-Dark trace-corr

# %%
ObjLongTraceMeasured.onoff_values();

# %%
# ObjLongTraceMeasured.TimeLimit = [0, 1200]
ObjLongTraceMeasured.RangeForBrightHist = [0, 0.1]
ObjLongTraceMeasured.InsetRangeBrightHist = [0, 0.05]
ObjLongTraceMeasured.RangeForDarkHist = [0, 5]
ObjLongTraceMeasured.InsetRangeDarkHist = [0,2]
ObjLongTraceMeasured.RangeForMidPotentialHist = [-60, 50]
ObjLongTraceMeasured.Range2DHistBright = [0, 0.05]

ObjLongTraceMeasured.PlotDurationsVsTime()
ObjLongTraceMeasured.axis01.set_ylim(0, 0.1)
ObjLongTraceMeasured.axis32.set_ylim(0, 0.5)
ObjLongTraceMeasured.FigureDuration.savefig(
    os.path.join(temp_dir, 'longtrace_dynamic_het_temp.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# k1:33.1219356243
# [ 33.12193562   1.36934488  58.61370136]
# k1:10.8698266866
# [  10.86982669    1.04830079  575.00954203]

# %% [markdown]
# ## Molecule-9
# ### Trace By Parts

# %%
ObjLongTraceMeasured = LongTraceClass(FilePathHdf5_9)
# ObjLongTraceMeasured.TimeLimit = [0, 2800]
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=1e2,TimePeriod=1e2);
ObjLongTraceMeasured.PlotLongTraceByParts()
ObjLongTraceMeasured.axis21.set_ylim(0, 3.5)
# ObjLongTraceMeasured.axis10.set_xlim(100, 125)
ObjLongTraceMeasured.FigureByParts.savefig(
    os.path.join(temp_dir, os.path.basename(FilePathHdf5_1)[:-5]+'.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# Input file is Point_A1_075mV(9)_60.5_360s_23.pt3.hdf5
# looking for df_ts 41727

# %% [markdown]
# ### 2D FCS Time Vs G(0)

# %%
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=1e2, TimePeriod=2e1);
ObjLongTraceMeasured.StatsLongTraceByParts()
# Out:
# looking for df_ts 62043

# %%
FCSCorrTimeAmp2D(ObjLongTraceMeasured, ObjLongTraceSimulated,
                 RangeCorrTime = [0, .03],
                 RangeCorrAmplitude = [2, 5])

# %% [markdown]
# ### Bright-Dark trace-corr

# %%
ObjLongTraceMeasured.onoff_values();

# %%
ObjLongTraceMeasured.TimeLimit = [0, 350]
ObjLongTraceMeasured.RangeForBrightHist = [0, 0.1]
ObjLongTraceMeasured.InsetRangeBrightHist = [0, 0.05]
ObjLongTraceMeasured.RangeForDarkHist = [0, 5]
ObjLongTraceMeasured.InsetRangeDarkHist = [0,2]
ObjLongTraceMeasured.RangeForMidPotentialHist = [-60, 50]
ObjLongTraceMeasured.Range2DHistBright = [0, 0.05]

ObjLongTraceMeasured.PlotDurationsVsTime()
ObjLongTraceMeasured.axis01.set_ylim(0, 0.05)
ObjLongTraceMeasured.axis32.set_ylim(0, 20)
ObjLongTraceMeasured.FigureDuration.savefig(
    os.path.join(temp_dir, 'longtrace_dynamic_het_temp.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# k1:109.147596959
# [ 109.14759696    2.07115637  294.80129921]
# k1:3.89405270041
# [   3.8940527     1.07182494  480.31943335]

# %% [markdown]
# ## Molecule-10
# ### Trace By Parts

# %%
ObjLongTraceMeasured = LongTraceClass(FilePathHdf5_10)
# ObjLongTraceMeasured.TimeLimit = [0, 2800]
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=1e2,TimePeriod=1e2);
ObjLongTraceMeasured.PlotLongTraceByParts()
ObjLongTraceMeasured.axis21.set_ylim(0, 3.5)
# ObjLongTraceMeasured.axis10.set_xlim(100, 125)
ObjLongTraceMeasured.FigureByParts.savefig(
    os.path.join(temp_dir, os.path.basename(FilePathHdf5_1)[:-5]+'.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# Input file is Point_A7_075mV(12)_60.5_420s_12.pt3.hdf5
# looking for df_ts 85401

# %% [markdown]
# ### 2D FCS Time Vs G(0)

# %%
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=1e2, TimePeriod=2e1);
ObjLongTraceMeasured.StatsLongTraceByParts()
# Out:
# looking for df_ts 103091

# %%
FCSCorrTimeAmp2D(ObjLongTraceMeasured, ObjLongTraceSimulated,
                 RangeCorrTime = [0, .2],
                 RangeCorrAmplitude = [1.5, 3.5])

# %% [markdown]
# ### Bright-Dark trace-corr

# %%
ObjLongTraceMeasured.onoff_values();

# %%
# ObjLongTraceMeasured.TimeLimit = [0, 1200]
ObjLongTraceMeasured.RangeForBrightHist = [0, 0.2]
ObjLongTraceMeasured.InsetRangeBrightHist = [0, 0.05]
ObjLongTraceMeasured.RangeForDarkHist = [0, 5]
ObjLongTraceMeasured.InsetRangeDarkHist = [0,2]
ObjLongTraceMeasured.RangeForMidPotentialHist = [-50, 100]
ObjLongTraceMeasured.Range2DHistBright = [0, 0.1]

ObjLongTraceMeasured.PlotDurationsVsTime()
ObjLongTraceMeasured.axis01.set_ylim(0, 0.2)
ObjLongTraceMeasured.axis32.set_ylim(0, 0.5)
ObjLongTraceMeasured.FigureDuration.savefig(
    os.path.join(temp_dir, 'longtrace_dynamic_het_temp.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# k1:28.7565001272
# [  28.75650013    1.33324969  218.21212183]
# k1:12.3227683822
# [  1.23227684e+01   6.93619339e-01   1.17100322e+03]

# %% [markdown]
# ## Molecule-11
# ### Trace By Parts

# %%
ObjLongTraceMeasured = LongTraceClass(FilePathHdf5_11)
# ObjLongTraceMeasured.TimeLimit = [0, 2800]
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=1e2,TimePeriod=1e2);
ObjLongTraceMeasured.PlotLongTraceByParts()
ObjLongTraceMeasured.axis21.set_ylim(0, 3.5)
# ObjLongTraceMeasured.axis10.set_xlim(100, 125)
ObjLongTraceMeasured.FigureByParts.savefig(
    os.path.join(temp_dir, os.path.basename(FilePathHdf5_1)[:-5]+'.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# Input file is Point_A7_075mV(12)_60.5_360s_13.pt3.hdf5
# looking for df_ts 44701

# %% [markdown]
# ### 2D FCS Time Vs G(0)

# %%
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=1e2, TimePeriod=2e1);
ObjLongTraceMeasured.StatsLongTraceByParts()
# Out:
# looking for df_ts 45475

# %%
FCSCorrTimeAmp2D(ObjLongTraceMeasured, ObjLongTraceSimulated,
                 RangeCorrTime = [0, .03],
                 RangeCorrAmplitude = [1.5, 5])

# %% [markdown]
# ### Bright-Dark trace-corr

# %%
ObjLongTraceMeasured.onoff_values();

# %%
# ObjLongTraceMeasured.TimeLimit = [0, 1200]
ObjLongTraceMeasured.RangeForBrightHist = [0, 0.1]
ObjLongTraceMeasured.InsetRangeBrightHist = [0, 0.05]
ObjLongTraceMeasured.RangeForDarkHist = [0, 5]
ObjLongTraceMeasured.InsetRangeDarkHist = [0,2]
ObjLongTraceMeasured.RangeForMidPotentialHist = [-60, 50]
ObjLongTraceMeasured.Range2DHistBright = [0, 0.05]

ObjLongTraceMeasured.PlotDurationsVsTime()
ObjLongTraceMeasured.axis01.set_ylim(0, 0.05)
ObjLongTraceMeasured.axis32.set_ylim(0, 0.2)
ObjLongTraceMeasured.FigureDuration.savefig(
    os.path.join(temp_dir, 'longtrace_dynamic_het_temp.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# k1:51.7731985817
# [  51.77319858    1.90214058  149.80461085]
# k1:4.26178796372
# [   4.26178796    1.04585787  507.92341862]

# %% [markdown]
# ## Molecule-12
# ### Trace By Parts

# %%
ObjLongTraceMeasured = LongTraceClass(FilePathHdf5_12)
# ObjLongTraceMeasured.TimeLimit = [0, 1500]
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=2e2,TimePeriod=2e2);
ObjLongTraceMeasured.PlotLongTraceByParts()
ObjLongTraceMeasured.axis21.set_ylim(0, 3)
# ObjLongTraceMeasured.axis10.set_xlim(100, 125)
ObjLongTraceMeasured.FigureByParts.savefig(
    os.path.join(temp_dir, os.path.basename(FilePathHdf5_1)[:-5]+'.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# Input file is Point_A7_075mV(12)_60.5_1160s_15.pt3.hdf5
# looking for df_ts 80040

# %% [markdown]
# ### 2D FCS Time Vs G(0)

# %%
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=2e2, TimePeriod=2e1);
ObjLongTraceMeasured.StatsLongTraceByParts()
# Out:
# looking for df_ts 80624

# %%
FCSCorrTimeAmp2D(ObjLongTraceMeasured, ObjLongTraceSimulated,
                 RangeCorrTime = [0, .05],
                 RangeCorrAmplitude = [1, 5])

# %% [markdown]
# ### Bright-Dark trace-corr

# %%
ObjLongTraceMeasured.onoff_values();

# %%
ObjLongTraceMeasured.TimeLimit = [0, 1130]
ObjLongTraceMeasured.RangeForBrightHist = [0, 0.1]
ObjLongTraceMeasured.InsetRangeBrightHist = [0, 0.05]
ObjLongTraceMeasured.RangeForDarkHist = [0, 5]
ObjLongTraceMeasured.InsetRangeDarkHist = [0,2]
ObjLongTraceMeasured.RangeForMidPotentialHist = [-60, 50]
ObjLongTraceMeasured.Range2DHistBright = [0, 0.05]

ObjLongTraceMeasured.PlotDurationsVsTime()
ObjLongTraceMeasured.axis01.set_ylim(0, 0.05)
ObjLongTraceMeasured.axis32.set_ylim(0, 0.1)
ObjLongTraceMeasured.FigureDuration.savefig(
    os.path.join(temp_dir, 'longtrace_dynamic_het_temp.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# k1:73.3826608646
# [  73.38266086    2.14475706  593.89307422]
# k1:3.35948066058
# [  3.35948066e+00   1.21731496e+00   1.23155925e+03]

# %% [markdown]
# ## Molecule-13
# ### Trace By Parts

# %%
ObjLongTraceMeasured = LongTraceClass(FilePathHdf5_13)
# ObjLongTraceMeasured.TimeLimit = [0, 2800]
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=2e2,TimePeriod=2e2);
ObjLongTraceMeasured.PlotLongTraceByParts()
ObjLongTraceMeasured.axis21.set_ylim(0, 3.5)
# ObjLongTraceMeasured.axis10.set_xlim(100, 125)
ObjLongTraceMeasured.FigureByParts.savefig(
    os.path.join(temp_dir, os.path.basename(FilePathHdf5_1)[:-5]+'.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# Input file is Point_A1_050mV(7)_60.5_1920s_16.pt3.hdf5
# looking for df_ts 108237

# %% [markdown]
# ### 2D FCS Time Vs G(0)

# %%
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=2e2, TimePeriod=2e1);
ObjLongTraceMeasured.StatsLongTraceByParts()
# Out:
# looking for df_ts 108779

# %%
FCSCorrTimeAmp2D(ObjLongTraceMeasured, ObjLongTraceSimulated,
                 RangeCorrTime = [0, .05],
                 RangeCorrAmplitude = [0, 3.5])

# %% [markdown]
# ### Bright-Dark trace-corr

# %%
ObjLongTraceMeasured.onoff_values();

# %%
ObjLongTraceMeasured.TimeLimit = [0, 1800]
ObjLongTraceMeasured.RangeForBrightHist = [0, 0.2]
ObjLongTraceMeasured.InsetRangeBrightHist = [0, 0.05]
ObjLongTraceMeasured.RangeForDarkHist = [0, 5]
ObjLongTraceMeasured.InsetRangeDarkHist = [0,2]
ObjLongTraceMeasured.RangeForMidPotentialHist = [-60, 60]
ObjLongTraceMeasured.Range2DHistBright = [0, 0.2]

ObjLongTraceMeasured.PlotDurationsVsTime()
ObjLongTraceMeasured.axis01.set_ylim(0, 0.2)
ObjLongTraceMeasured.axis32.set_ylim(0, 5)
ObjLongTraceMeasured.FigureDuration.savefig(
    os.path.join(temp_dir, 'longtrace_dynamic_het_temp.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# k1:23.9958539454
# [  23.99585395    1.79086387  507.76947123]
# k1:2.83499342197
# [  2.83499342e+00   1.40052556e+00   1.45594880e+03]

# %% [markdown]
# ## Molecule-14
# ### Trace By Parts

# %%
ObjLongTraceMeasured = LongTraceClass(FilePathHdf5_14)
# ObjLongTraceMeasured.TimeLimit = [0, 2800]
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=1e2,TimePeriod=1e2);
ObjLongTraceMeasured.PlotLongTraceByParts()
ObjLongTraceMeasured.axis21.set_ylim(0, 3.5)
# ObjLongTraceMeasured.axis10.set_xlim(100, 125)
ObjLongTraceMeasured.FigureByParts.savefig(
    os.path.join(temp_dir, os.path.basename(FilePathHdf5_1)[:-5]+'.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# Input file is Point_A8_050mV(15)_60.5_700s_23.pt3.hdf5
# looking for df_ts 42203

# %% [markdown]
# ### 2D FCS Time Vs G(0)

# %%
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=2e2, TimePeriod=2e1);
ObjLongTraceMeasured.StatsLongTraceByParts()
# Out:
# looking for df_ts 120527

# %%
FCSCorrTimeAmp2D(ObjLongTraceMeasured, ObjLongTraceSimulated,
                 RangeCorrTime = [0, .05],
                 RangeCorrAmplitude = [0, 3.5])

# %% [markdown]
# ### Bright-Dark trace-corr

# %%
ObjLongTraceMeasured.onoff_values();

# %%
ObjLongTraceMeasured.TimeLimit = [0, 570]
ObjLongTraceMeasured.RangeForBrightHist = [0, 0.1]
ObjLongTraceMeasured.InsetRangeBrightHist = [0, 0.05]
ObjLongTraceMeasured.RangeForDarkHist = [0, 5]
ObjLongTraceMeasured.InsetRangeDarkHist = [0,2]
ObjLongTraceMeasured.RangeForMidPotentialHist = [-80, 50]
ObjLongTraceMeasured.Range2DHistBright = [0, 0.1]

ObjLongTraceMeasured.PlotDurationsVsTime()
ObjLongTraceMeasured.axis01.set_ylim(0, 0.1)
ObjLongTraceMeasured.axis32.set_ylim(0, 2)
ObjLongTraceMeasured.FigureDuration.savefig(
    os.path.join(temp_dir, 'longtrace_dynamic_het_temp.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# k1:21.710897011
# [ 21.71089701   1.66561867  70.12709071]
# k1:2.77914622978
# [   2.77914623    1.15152439  405.0530502 ]

# %% [markdown]
# ## Molecule-2
# ### Trace By Parts

# %%
ObjLongTraceMeasured = LongTraceClass(FilePathHdf5_15)
# ObjLongTraceMeasured.TimeLimit = [0, 2800]
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=1e2,TimePeriod=1e2);
ObjLongTraceMeasured.PlotLongTraceByParts()
ObjLongTraceMeasured.axis21.set_ylim(0, 3.5)
# ObjLongTraceMeasured.axis10.set_xlim(100, 125)
ObjLongTraceMeasured.FigureByParts.savefig(
    os.path.join(temp_dir, os.path.basename(FilePathHdf5_1)[:-5]+'.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# Input file is Point_A8_050mV(15)_60.5_1980s_22.pt3.hdf5
# looking for df_ts 51156

# %% [markdown]
# ### 2D FCS Time Vs G(0)

# %%
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=2e2, TimePeriod=2e1);
ObjLongTraceMeasured.StatsLongTraceByParts()
# Out:
# looking for df_ts 101001

# %%
FCSCorrTimeAmp2D(ObjLongTraceMeasured, ObjLongTraceSimulated,
                 RangeCorrTime = [0, .05],
                 RangeCorrAmplitude = [0, 3.5])

# %% [markdown]
# ### Bright-Dark trace-corr

# %%
ObjLongTraceMeasured.onoff_values();

# %%
# ObjLongTraceMeasured.TimeLimit = [0, 1200]
ObjLongTraceMeasured.RangeForBrightHist = [0, 0.2]
ObjLongTraceMeasured.InsetRangeBrightHist = [0, 0.05]
ObjLongTraceMeasured.RangeForDarkHist = [0, 5]
ObjLongTraceMeasured.InsetRangeDarkHist = [0,1]
ObjLongTraceMeasured.RangeForMidPotentialHist = [-60, 50]
ObjLongTraceMeasured.Range2DHistBright = [0, 0.1]

ObjLongTraceMeasured.PlotDurationsVsTime()
ObjLongTraceMeasured.axis01.set_ylim(0, 0.5)
ObjLongTraceMeasured.axis32.set_ylim(0, 2)
ObjLongTraceMeasured.FigureDuration.savefig(
    os.path.join(temp_dir, 'longtrace_dynamic_het_temp.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# k1:28.506288927
# [  28.50628893    1.94550435  904.25006222]
# k1:4.2698416426
# [  4.26984164e+00   1.31545277e+00   2.88838024e+03]
