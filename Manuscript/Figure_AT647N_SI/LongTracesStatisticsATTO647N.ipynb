# %%
# toogle view
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %% [markdown]
# # Directories and modules

# %%
#list of folders and their directories CuAZUATTO647N % ZnAzuATTO647N
import os
Analysis_dir = '/home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/Azurin_SM_repo/Analysis'
data_dir = '/home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/data'#GIVE the PATH of this FOLDER.
# Checking or creating temp_dir
temp_dir = 'temp'
temp_dir = os.path.join(temp_dir)
if os.path.isdir(temp_dir):
    print('temp_dir exists')
else:
    os.makedirs(temp_dir)
    print('temp_dir created')
# Out:
# temp_dir exists

# %%
# import modules
import sys
sys.path.append(Analysis_dir)
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import numpy as np
from LongTraceAnalysis import LongTraceClass, FCSCorrTimeAmp2D
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from pylab import *
matplotlib.rcParams['svg.fonttype'] = 'none'
mpl.rcParams["font.family"] = "sans-serif"
mpl.rcParams["font.size"] = "10"
rc('axes', linewidth=1)
# plt.savefig('/home/biswajit/Downloads/test.svg', format='svg', transparent=True)

# %% [markdown]
# # Simulated Data

# %% [markdown]
# ### Trace By Parts

# %%
# Simulated data
simulated_hdf5 = os.path.join(data_dir, 'SimulatedData/20180423_1618_ton0.1toff0.5timelen3600bg150sig1500.hdf5')    
if os.path.isfile(simulated_hdf5):
    print('"simulated_hdf5" also file found')
ObjLongTraceSimulated = LongTraceClass(simulated_hdf5, Simulation=True)
ObjLongTraceSimulated.TimeLimit = [0, 2700]
ObjLongTraceSimulated.LongTraceByParts(TimeWindow=2e2,TimePeriod=2e2);
ObjLongTraceSimulated.PlotLongTraceByParts()
ObjLongTraceSimulated.axis20.set_ylim(0, 2.1)
ObjLongTraceSimulated.axis21.set_ylim(5e-2, 1.1)

# ObjLongTraceSimulated.axis10.set_xlim(100, 125)
# Out:
# "simulated_hdf5" also file found
# Input file is 20180423_1618_ton0.1toff0.5timelen3600bg150sig1500.hdf5
# looking for df_ts 82809
# (0.05, 1.1)

# %% [markdown]
# ### 2D FCS Time Vs G(0)

# %%
ObjLongTraceSimulated.LongTraceByParts(TimeWindow=2e2, TimePeriod=2e1);
ObjLongTraceSimulated.StatsLongTraceByParts()# To be used for comparision with Measured data
# Out:
# looking for df_ts 85810

# %%
FCSCorrTimeAmp2D(ObjLongTraceSimulated, ObjLongTraceSimulated,
                 RangeCorrTime = [0, .2],
                 RangeCorrAmplitude = [1.5, 3.5])

# %% [markdown]
# ### Bright-Dark trace-corr

# %%
ObjLongTraceSimulated.onoff_values();

# %%
ObjLongTraceSimulated.InsetRangeBrightHist = [0, 0.2]
ObjLongTraceSimulated.InsetRangeDarkHist = [0,2]
ObjLongTraceSimulated.AppliedPotential = 100
ObjLongTraceSimulated.PlotDurationsVsTime()
ObjLongTraceSimulated.FigureDuration.savefig(
    os.path.join(temp_dir, 'longtrace_dynamic_het_temp.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# k1:6.846328552
# [   6.84632855    1.30293162  546.40721863]
# k1:1.75097658914
# [  1.75097659e+00   1.11065311e+00   1.22367108e+03]

# %% [markdown]
# # CuAzurin ATTO647N

# %% [markdown]
# ### List of Molecules

# %%
# paths for the longazurin molecule
# 100 mV
FilePathHdf5_1 = os.path.join(data_dir, 'AzurinATTO647N/S130d02MAr18_590p_A3_100mV_longtimes/S103_550p_A3_100mV(35)_9.pt3.hdf5')
FilePathHdf5_2 = os.path.join(data_dir, 'AzurinATTO647N/20180223_longtime/Point_611p_N42CCuAzuATTO647N_A2_0100mV(29)_x.pt3.hdf5')
FilePathHdf5_3 = os.path.join(data_dir, 'AzurinATTO647N/20180223_longtime/Point_611p_N42CCuAzuATTO647N_A2_0100mV(27)_42.pt3.hdf5');
FilePathHdf5_4 = os.path.join(data_dir, 'AzurinATTO647N/S129d29Feb18_590p_A6_longtimes/Point_A6_longtime_0100mV(47)_1.pt3.hdf5')
FilePathHdf5_5 = os.path.join(data_dir, 'AzurinATTO647N/S129d29Feb18_590p_A6_longtimes/Point_A6_longtime_0100mV(47)_2.pt3.hdf5')
FilePathHdf5_6 = os.path.join(data_dir, 'AzurinATTO647N/S130d02MAr18_590p_A3_100mV_longtimes/S103_550p_A3_100mV(35)_11.pt3.hdf5')
FilePathHdf5_7 = os.path.join(data_dir, 'AzurinATTO647N/S130d02MAr18_590p_A3_100mV_longtimes/S103_550p_A3_100mV(35)_12.pt3.hdf5')
FilePathHdf5_8 = os.path.join(data_dir, 'AzurinATTO647N/S130d02MAr18_590p_A3_100mV_longtimes/S103_550p_A3_100mV(38)_16.pt3.hdf5')
# 150 mV
FilePathHdf5_9 = os.path.join(data_dir, 'AzurinATTO647N/S130d02MAr18_590p_A2_150mV_longtimes/S103_550p_A2_150mV(30)_2.pt3.hdf5')
FilePathHdf5_10 = os.path.join(data_dir, 'AzurinATTO647N/S130d02MAr18_590p_A2_150mV_longtimes/S103_550p_A2_150mV(31)_3.pt3.hdf5')
FilePathHdf5_11 = os.path.join(data_dir, 'AzurinATTO647N/S130d02MAr18_590p_A2_150mV_longtimes/S103_550p_A2_150mV(32)_5.pt3.hdf5')
FilePathHdf5_12 = os.path.join(data_dir, 'AzurinATTO647N/S130d02MAr18_590p_A2_150mV_longtimes/S103_550p_A2_150mV(32)_6.pt3.hdf5')
FilePathHdf5_13 = os.path.join(data_dir, 'AzurinATTO647N/S130d02MAr18_590p_A2_150mV_longtimes/S103_550p_A2_150mV(32)_7.pt3.hdf5')
# ZnAzurin
FilePathHdf5_Zn = os.path.join(data_dir, 'AzurinATTO655/ZnAzurin_Data/S107d1May17_635_ZnAzu655_longtime/S107d19May17_60.5_635_A5_ZnAzu655_000mV(30)/Point_A5_000mV(30)_60.5_240s_18.pt3.hdf5')
# Simulated
if os.path.isfile(FilePathHdf5_1):
    print('"FilePathHdf5" file found')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-310353c883d2> in <module>()
#       1 # paths for the longazurin molecule
#       2 # 100 mV
# ----> 3 FilePathHdf5_1 = os.path.join(data_dir, 'AzurinATTO647N/S130d02MAr18_590p_A3_100mV_longtimes/S103_550p_A3_100mV(35)_9.pt3.hdf5')
#       4 FilePathHdf5_2 = os.path.join(data_dir, 'AzurinATTO647N/20180223_longtime/Point_611p_N42CCuAzuATTO647N_A2_0100mV(29)_x.pt3.hdf5')
#       5 FilePathHdf5_3 = os.path.join(data_dir, 'AzurinATTO647N/20180223_longtime/Point_611p_N42CCuAzuATTO647N_A2_0100mV(27)_42.pt3.hdf5');
#
# NameError: name 'os' is not defined

# %% [markdown]
# ## Molecule-1

# %% [markdown]
# ### Trace By Parts

# %%
ObjLongTraceMeasured = LongTraceClass(FilePathHdf5_1)
ObjLongTraceMeasured.TimeLimit = [0, 2800]
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=2e2,TimePeriod=2e2);
ObjLongTraceMeasured.PlotLongTraceByParts()
ObjLongTraceMeasured.axis21.set_ylim(0, 3.5)
# ObjLongTraceMeasured.axis10.set_xlim(100, 125)
ObjLongTraceMeasured.FigureByParts.savefig(
    os.path.join(temp_dir, os.path.basename(FilePathHdf5_1)[:-5]+'.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# Input file is S103_550p_A3_100mV(35)_9.pt3.hdf5
# looking for df_ts 72377

# %% [markdown]
# ### 2D FCS Time Vs G(0)

# %%
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=2e2, TimePeriod=2e1);
ObjLongTraceMeasured.StatsLongTraceByParts()

# %%
FCSCorrTimeAmp2D(ObjLongTraceMeasured, ObjLongTraceSimulated,
                 RangeCorrTime = [0, .4],
                 RangeCorrAmplitude = [1.5, 3.5])

# %% [markdown]
# ### Bright-Dark trace-corr

# %%
ObjLongTraceMeasured.onoff_values();

# %%
ObjLongTraceMeasured.TimeLimit = [0, 2600]
ObjLongTraceMeasured.InsetRangeBrightHist = [0, 0.2]
ObjLongTraceMeasured.InsetRangeDarkHist = [0,2]
ObjLongTraceMeasured.PlotDurationsVsTime()
ObjLongTraceMeasured.axis01.set_ylim(0, 0.8)
ObjLongTraceMeasured.FigureDuration.savefig(
    os.path.join(temp_dir, 'longtrace_dynamic_het_temp.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# k1:6.13086891712
# [   6.13086892    1.0211612   191.05725437]
# k1:0.927324206974
# [   0.92732421    0.84014617  267.97933364]

# %% [markdown]
# ## Molecule-2

# %% [markdown]
# ###  Trace By Parts

# %%
ObjLongTraceMeasured = LongTraceClass(FilePathHdf5_2)
# ObjLongTraceMeasured.TimeLimit = [0, 2800]
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=2e2,TimePeriod=2e2);
ObjLongTraceMeasured.PlotLongTraceByParts()
ObjLongTraceMeasured.axis21.set_ylim(0, 3.5)
# ObjLongTraceMeasured.axis10.set_xlim(100, 125)
ObjLongTraceMeasured.FigureByParts.savefig(
    os.path.join(temp_dir, os.path.basename(FilePathHdf5_1)[:-5]+'.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# Input file is Point_611p_N42CCuAzuATTO647N_A2_0100mV(29)_x.pt3.hdf5
# looking for df_ts 105535

# %% [markdown]
# ### 2D FCS Time Vs G(0)

# %%
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=2e2, TimePeriod=2e1);
ObjLongTraceMeasured.StatsLongTraceByParts()
# Out:
# looking for df_ts 123346

# %%
FCSCorrTimeAmp2D(ObjLongTraceMeasured, ObjLongTraceSimulated,
                 RangeCorrTime = [0, .2],
                 RangeCorrAmplitude = [1.5, 3.5])

# %% [markdown]
# ### Bright-Dark trace-corr

# %%
ObjLongTraceMeasured.onoff_values();

# %%
ObjLongTraceMeasured.TimeLimit = [0, 1200]
ObjLongTraceMeasured.InsetRangeBrightHist = [0, 0.2]
ObjLongTraceMeasured.InsetRangeDarkHist = [0,2]
ObjLongTraceMeasured.PlotDurationsVsTime()
ObjLongTraceMeasured.axis01.set_ylim(0, 0.8)
ObjLongTraceMeasured.FigureDuration.savefig(
    os.path.join(temp_dir, 'longtrace_dynamic_het_temp.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# k1:13.0230786903
# [  13.02307869    0.70323608  241.71423438]
# k1:2.02585816012
# [   2.02585816    0.73904151  366.54213181]

# %% [markdown]
# ## Molecule-3

# %% [markdown]
# ### Trace By Parts

# %%
ObjLongTraceMeasured = LongTraceClass(FilePathHdf5_3)
# ObjLongTraceMeasured.TimeLimit = [0, 2800]
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=1e2,TimePeriod=1e2);
ObjLongTraceMeasured.PlotLongTraceByParts()
ObjLongTraceMeasured.axis21.set_ylim(0, 3.5)
# ObjLongTraceMeasured.axis10.set_xlim(100, 125)
ObjLongTraceMeasured.FigureByParts.savefig(
    os.path.join(temp_dir, os.path.basename(FilePathHdf5_1)[:-5]+'.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# Input file is Point_611p_N42CCuAzuATTO647N_A2_0100mV(27)_42.pt3.hdf5
# looking for df_ts 93439

# %% [markdown]
# ### 2D FCS Time Vs G(0)

# %%
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=2e2, TimePeriod=2e1);
ObjLongTraceMeasured.StatsLongTraceByParts()
# Out:
# looking for df_ts 179164

# %%
FCSCorrTimeAmp2D(ObjLongTraceMeasured, ObjLongTraceSimulated,
                 RangeCorrTime = [0, .25],
                 RangeCorrAmplitude = [1, 2.5])

# %% [markdown]
# ### Bright-Dark trace-corr

# %%
ObjLongTraceMeasured.onoff_values();

# %%
ObjLongTraceMeasured.TimeLimit = [0, 1000]
ObjLongTraceMeasured.InsetRangeBrightHist = [0, 0.2]
ObjLongTraceMeasured.InsetRangeDarkHist = [0,2]
# ObjLongTraceMeasured.LagTimeLimitCorrelation = [0.1, 1e2]
ObjLongTraceMeasured.ContrastLimitCorrelation = [-0.1, 0.3]

ObjLongTraceMeasured.PlotDurationsVsTime()
ObjLongTraceMeasured.axis01.set_ylim(0, 0.8)
ObjLongTraceMeasured.FigureDuration.savefig(
    os.path.join(temp_dir, 'longtrace_dynamic_het_temp.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# k1:6.11138286887
# [  6.11138287   0.86165859  99.49791613]
# k1:2.20682730998
# [   2.20682731    0.82072113  297.07899592]

# %% [markdown]
# ## Molecule-4

# %% [markdown]
# ### Trace By Parts

# %%
ObjLongTraceMeasured = LongTraceClass(FilePathHdf5_4)
ObjLongTraceMeasured.TimeLimit = [0, 810]
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=1e2,TimePeriod=1e2);
ObjLongTraceMeasured.PlotLongTraceByParts()
ObjLongTraceMeasured.axis21.set_xlim(1e-5, 1e1)
ObjLongTraceMeasured.axis21.set_ylim(0, 5)
# ObjLongTraceMeasured.axis10.set_xlim(100, 125)
ObjLongTraceMeasured.FigureByParts.savefig(
    os.path.join(temp_dir, os.path.basename(FilePathHdf5_1)[:-5]+'.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# Input file is Point_A6_longtime_0100mV(47)_1.pt3.hdf5
# looking for df_ts 44568

# %% [markdown]
# ### 2D FCS Time Vs G(0)

# %%
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=2e2, TimePeriod=2e1);
ObjLongTraceMeasured.StatsLongTraceByParts()
# Out:
# looking for df_ts 73322

# %%
FCSCorrTimeAmp2D(ObjLongTraceMeasured, ObjLongTraceSimulated,
                 RangeCorrTime = [0, 0.2],
                 RangeCorrAmplitude = [0, 5])

# %% [markdown]
# ### Bright-Dark trace-corr

# %%
ObjLongTraceMeasured.onoff_values();

ObjLongTraceMeasured.TimeLimit = [0, 780]
ObjLongTraceMeasured.InsetRangeBrightHist = [0, 0.2]
ObjLongTraceMeasured.InsetRangeDarkHist = [0,2]
ObjLongTraceMeasured.RangeForMidPotentialHist = (-15, 150)
ObjLongTraceMeasured.ContrastLimitCorrelation = [0, 5]

ObjLongTraceMeasured.PlotDurationsVsTime()
ObjLongTraceMeasured.axis01.set_ylim(0, 0.4)
ObjLongTraceMeasured.FigureDuration.savefig(
    os.path.join(temp_dir, 'longtrace_dynamic_het_temp.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# k1:30.8995848189
# [  30.89958482    0.69111594  240.061742  ]
# k1:9.36820990419
# [   9.3682099     0.58064209  385.47399889]

# %% [markdown]
# ## Molecule-5

# %% [markdown]
# ### Trace By Parts

# %%
ObjLongTraceMeasured = LongTraceClass(FilePathHdf5_5)
# ObjLongTraceMeasured.TimeLimit = [0, 2800]
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=1e2,TimePeriod=1e2);
ObjLongTraceMeasured.PlotLongTraceByParts()
ObjLongTraceMeasured.axis21.set_ylim(0, 5)
# ObjLongTraceMeasured.axis10.set_xlim(100, 125)
ObjLongTraceMeasured.FigureByParts.savefig(
    os.path.join(temp_dir, os.path.basename(FilePathHdf5_1)[:-5]+'.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# Input file is Point_A6_longtime_0100mV(47)_2.pt3.hdf5
# looking for df_ts 115466

# %% [markdown]
# ### 2D FCS Time Vs G(0)

# %%
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=2e2, TimePeriod=2e1);
ObjLongTraceMeasured.StatsLongTraceByParts()
# Out:
# looking for df_ts 141303

# %%
FCSCorrTimeAmp2D(ObjLongTraceMeasured, ObjLongTraceSimulated,
                 RangeCorrTime = [0, 0.3],
                 RangeCorrAmplitude = [1, 7])

# %% [markdown]
# ### Bright-Dark trace-corr

# %%
ObjLongTraceMeasured.onoff_values();

# %%
ObjLongTraceMeasured.TimeLimit = [0, 780]
ObjLongTraceMeasured.InsetRangeBrightHist = [0, 0.2]
ObjLongTraceMeasured.InsetRangeDarkHist = [0,2]
ObjLongTraceMeasured.RangeForMidPotentialHist = (-15, 150)
ObjLongTraceMeasured.ContrastLimitCorrelation = [0, 5]

ObjLongTraceMeasured.PlotDurationsVsTime()
ObjLongTraceMeasured.axis01.set_ylim(0, 1)
ObjLongTraceMeasured.FigureDuration.savefig(
    os.path.join(temp_dir, 'longtrace_dynamic_het_temp.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# k1:17.5800217846
# [  17.58002178    0.6251684   226.0918753 ]
# k1:5.70107944705
# [   5.70107945    0.58755195  568.52210966]

# %% [markdown]
# ## Molecule-6

# %% [markdown]
# ### Trace By Parts

# %%
ObjLongTraceMeasured = LongTraceClass(FilePathHdf5_6)
ObjLongTraceMeasured.TimeLimit = [0, 600]
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=1e2,TimePeriod=1e2);
ObjLongTraceMeasured.PlotLongTraceByParts()
ObjLongTraceMeasured.axis21.set_ylim(0, 3.5)
# ObjLongTraceMeasured.axis10.set_xlim(100, 125)
ObjLongTraceMeasured.FigureByParts.savefig(
    os.path.join(temp_dir, os.path.basename(FilePathHdf5_1)[:-5]+'.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# Input file is S103_550p_A3_100mV(35)_11.pt3.hdf5
# looking for df_ts 33790

# %% [markdown]
# ### 2D FCS Time Vs G(0)

# %%
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=2e2, TimePeriod=2e1);
ObjLongTraceMeasured.StatsLongTraceByParts()
# Out:
# looking for df_ts 191995

# %%
FCSCorrTimeAmp2D(ObjLongTraceMeasured, ObjLongTraceSimulated,
                 RangeCorrTime = [0, .2],
                 RangeCorrAmplitude = [1.5, 2])

# %% [markdown]
# ### Bright-Dark trace-corr

# %%
ObjLongTraceMeasured.onoff_values();

# %%
ObjLongTraceMeasured.TimeLimit = [0, 500]
ObjLongTraceMeasured.InsetRangeBrightHist = [0, 0.2]
ObjLongTraceMeasured.InsetRangeDarkHist = [0,2]
ObjLongTraceMeasured.RangeForMidPotentialHist = (-15, 150)
ObjLongTraceMeasured.ContrastLimitCorrelation = [0, 1]

ObjLongTraceMeasured.PlotDurationsVsTime()
ObjLongTraceMeasured.axis01.set_ylim(0, 0.4)
ObjLongTraceMeasured.FigureDuration.savefig(
    os.path.join(temp_dir, 'longtrace_dynamic_het_temp.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# k1:8.94076613622
# [  8.94076614   1.07309745  64.11752059]
# k1:0.892889792172
# [  0.89288979   1.09746854  67.17783507]

# %% [markdown]
# ## Molecule-7
# ### Trace By Parts

# %%
ObjLongTraceMeasured = LongTraceClass(FilePathHdf5_7)
# ObjLongTraceMeasured.TimeLimit = [0, 2800]
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=5e1,TimePeriod=5e1);
ObjLongTraceMeasured.PlotLongTraceByParts()
ObjLongTraceMeasured.axis21.set_ylim(0, 2.5)
# ObjLongTraceMeasured.axis10.set_xlim(100, 125)
ObjLongTraceMeasured.FigureByParts.savefig(
    os.path.join(temp_dir, os.path.basename(FilePathHdf5_1)[:-5]+'.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# Input file is S103_550p_A3_100mV(35)_12.pt3.hdf5
# looking for df_ts 47369

# %% [markdown]
# ### 2D FCS Time Vs G(0)

# %%
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=1e2, TimePeriod=1e1);
ObjLongTraceMeasured.StatsLongTraceByParts()
# Out:
# looking for df_ts 69158

# %%
FCSCorrTimeAmp2D(ObjLongTraceMeasured, ObjLongTraceSimulated,
                 RangeCorrTime = [0, .2],
                 RangeCorrAmplitude = [0.5, 2])

# %% [markdown]
# ### Bright-Dark trace-corr

# %%
ObjLongTraceMeasured.onoff_values();

# %%
# ObjLongTraceMeasured.TimeLimit = [0, 780]
ObjLongTraceMeasured.InsetRangeBrightHist = [0, 0.2]
ObjLongTraceMeasured.InsetRangeDarkHist = [0,2]
ObjLongTraceMeasured.RangeForMidPotentialHist = (0, 150)
ObjLongTraceMeasured.ContrastLimitCorrelation = [0, 0.5]

ObjLongTraceMeasured.PlotDurationsVsTime()
ObjLongTraceMeasured.axis01.set_ylim(0, 0.4)
ObjLongTraceMeasured.FigureDuration.savefig(
    os.path.join(temp_dir, 'longtrace_dynamic_het_temp.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# k1:7.78656461429
# [  7.78656461   1.27934022  88.05510156]
# k1:9.71220030736
# [   9.71220031    0.61752012  478.14400478]

# %% [markdown]
# ## Molecule-8
# ### Trace By Parts

# %%
ObjLongTraceMeasured = LongTraceClass(FilePathHdf5_8)
# ObjLongTraceMeasured.TimeLimit = [0, 2800]
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=1e2,TimePeriod=1e2);
ObjLongTraceMeasured.PlotLongTraceByParts()
ObjLongTraceMeasured.axis21.set_ylim(0, 3.5)
ObjLongTraceMeasured.axis21.set_xlim(1e-5, 1e1)
# ObjLongTraceMeasured.axis10.set_xlim(100, 125)
ObjLongTraceMeasured.FigureByParts.savefig(
    os.path.join(temp_dir, os.path.basename(FilePathHdf5_1)[:-5]+'.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# Input file is S103_550p_A3_100mV(38)_16.pt3.hdf5
# looking for df_ts 32986

# %% [markdown]
# ### 2D FCS Time Vs G(0)

# %%
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=2e2, TimePeriod=2e1);
ObjLongTraceMeasured.StatsLongTraceByParts()
# Out:
# looking for df_ts 60319

# %%
FCSCorrTimeAmp2D(ObjLongTraceMeasured, ObjLongTraceSimulated,
                 RangeCorrTime = [0, .4],
                 RangeCorrAmplitude = [1.5, 3])

# %% [markdown]
# ### Bright-Dark trace-corr

# %%
ObjLongTraceMeasured.onoff_values();

# %%
ObjLongTraceMeasured.TimeLimit = [0, 780]
ObjLongTraceMeasured.InsetRangeBrightHist = [0, 0.2]
ObjLongTraceMeasured.InsetRangeDarkHist = [0,2]
# ObjLongTraceMeasured.RangeForMidPotentialHist = (-15, 150)
ObjLongTraceMeasured.ContrastLimitCorrelation = [0, 0.5]

ObjLongTraceMeasured.PlotDurationsVsTime()
ObjLongTraceMeasured.axis01.set_ylim(0, 1)
ObjLongTraceMeasured.FigureDuration.savefig(
    os.path.join(temp_dir, 'longtrace_dynamic_het_temp.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# k1:4.41196636789
# [  4.41196637   1.00681866  21.74353683]
# k1:1768.83745157
# [  1.76883745e+03   1.74612619e-01   3.20071895e+02]

# %% [markdown]
# ## Molecule-9
# ### Trace By Parts

# %%
ObjLongTraceMeasured = LongTraceClass(FilePathHdf5_9)
# ObjLongTraceMeasured.TimeLimit = [0, 2800]
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=2e2,TimePeriod=2e2);
ObjLongTraceMeasured.PlotLongTraceByParts()
ObjLongTraceMeasured.axis21.set_ylim(0, 3.5)
# ObjLongTraceMeasured.axis10.set_xlim(100, 125)
ObjLongTraceMeasured.FigureByParts.savefig(
    os.path.join(temp_dir, os.path.basename(FilePathHdf5_1)[:-5]+'.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# Input file is S103_550p_A2_150mV(30)_2.pt3.hdf5
# looking for df_ts 53130

# %% [markdown]
# ### 2D FCS Time Vs G(0)

# %%
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=2e2, TimePeriod=2e1);
ObjLongTraceMeasured.StatsLongTraceByParts()
# Out:
# looking for df_ts 57751

# %%
FCSCorrTimeAmp2D(ObjLongTraceMeasured, ObjLongTraceSimulated,
                 RangeCorrTime = [0, .2],
                 RangeCorrAmplitude = [1.5, 2.5])

# %% [markdown]
# ### Bright-Dark trace-corr

# %%
ObjLongTraceMeasured.onoff_values();

# %%
# ObjLongTraceMeasured.TimeLimit = [0, 780]
ObjLongTraceMeasured.InsetRangeBrightHist = [0, 0.2]
ObjLongTraceMeasured.InsetRangeDarkHist = [0,2]
ObjLongTraceMeasured.RangeForMidPotentialHist = (-15, 150)
ObjLongTraceMeasured.ContrastLimitCorrelation = [0, 0.5]

ObjLongTraceMeasured.PlotDurationsVsTime()
ObjLongTraceMeasured.axis01.set_ylim(0, 0.2)
ObjLongTraceMeasured.FigureDuration.savefig(
    os.path.join(temp_dir, 'longtrace_dynamic_het_temp.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# k1:11.526179719
# [  11.52617972    1.44699826  629.57600719]
# k1:1.50712688306
# [   1.50712688    1.08144442  761.78496217]

# %% [markdown]
# ## Molecule-10
# ### Trace By Parts

# %%
ObjLongTraceMeasured = LongTraceClass(FilePathHdf5_10)
# ObjLongTraceMeasured.TimeLimit = [0, 2800]
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=2e2,TimePeriod=2e2);
ObjLongTraceMeasured.PlotLongTraceByParts()
ObjLongTraceMeasured.axis21.set_ylim(0, 3.5)
# ObjLongTraceMeasured.axis10.set_xlim(100, 125)
ObjLongTraceMeasured.FigureByParts.savefig(
    os.path.join(temp_dir, os.path.basename(FilePathHdf5_1)[:-5]+'.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# Input file is S103_550p_A2_150mV(31)_3.pt3.hdf5
# looking for df_ts 48924

# %% [markdown]
# ### 2D FCS Time Vs G(0)

# %%
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=2e2, TimePeriod=2e1);
ObjLongTraceMeasured.StatsLongTraceByParts()
# Out:
# looking for df_ts 48937

# %%
FCSCorrTimeAmp2D(ObjLongTraceMeasured, ObjLongTraceSimulated,
                 RangeCorrTime = [0, .2],
                 RangeCorrAmplitude = [1.5, 3.5])

# %% [markdown]
# ### Bright-Dark trace-corr

# %%
ObjLongTraceMeasured.onoff_values();

# %%
# ObjLongTraceMeasured.TimeLimit = [0, 780]
ObjLongTraceMeasured.InsetRangeBrightHist = [0, 0.2]
ObjLongTraceMeasured.InsetRangeDarkHist = [0,2]
ObjLongTraceMeasured.RangeForMidPotentialHist = (-15, 150)
ObjLongTraceMeasured.ContrastLimitCorrelation = [0, 0.5]

ObjLongTraceMeasured.PlotDurationsVsTime()
ObjLongTraceMeasured.axis01.set_ylim(0, 0.2)
ObjLongTraceMeasured.FigureDuration.savefig(
    os.path.join(temp_dir, 'longtrace_dynamic_het_temp.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# k1:15.8182089786
# [  15.81820898    1.18906033  605.9174946 ]
# k1:2.03306003615
# [   2.03306004    1.21587992  767.24440565]

# %% [markdown]
# ## Molecule-11
# ### Trace By Parts

# %%
ObjLongTraceMeasured = LongTraceClass(FilePathHdf5_11)
# ObjLongTraceMeasured.TimeLimit = [0, 2800]
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=1e2,TimePeriod=1e2);
ObjLongTraceMeasured.PlotLongTraceByParts()
ObjLongTraceMeasured.axis21.set_ylim(0, 3.5)
# ObjLongTraceMeasured.axis10.set_xlim(100, 125)
ObjLongTraceMeasured.FigureByParts.savefig(
    os.path.join(temp_dir, os.path.basename(FilePathHdf5_1)[:-5]+'.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# Input file is S103_550p_A2_150mV(32)_5.pt3.hdf5
# looking for df_ts 14089

# %% [markdown]
# ### 2D FCS Time Vs G(0)

# %%
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=2e2, TimePeriod=2e1);
ObjLongTraceMeasured.StatsLongTraceByParts()
# Out:
# looking for df_ts 26551

# %%
FCSCorrTimeAmp2D(ObjLongTraceMeasured, ObjLongTraceSimulated,
                 RangeCorrTime = [0, .2],
                 RangeCorrAmplitude = [1.5, 2.75])

# %% [markdown]
# ### Bright-Dark trace-corr

# %%
ObjLongTraceMeasured.onoff_values();

# %%
# ObjLongTraceMeasured.TimeLimit = [0, 780]
ObjLongTraceMeasured.InsetRangeBrightHist = [0, 0.2]
ObjLongTraceMeasured.InsetRangeDarkHist = [0,2]
ObjLongTraceMeasured.RangeForMidPotentialHist = (-15, 150)
ObjLongTraceMeasured.ContrastLimitCorrelation = [0, 0.5]

ObjLongTraceMeasured.PlotDurationsVsTime()
ObjLongTraceMeasured.axis01.set_ylim(0, 0.1)
ObjLongTraceMeasured.FigureDuration.savefig(
    os.path.join(temp_dir, 'longtrace_dynamic_het_temp.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# k1:29.1797329589
# [  29.17973296    1.1923464   234.25696392]
# k1:1.02728809386
# [  1.02728809   1.37112628  94.16481051]

# %% [markdown]
# ## Molecule-12
# ### Trace By Parts

# %%
ObjLongTraceMeasured = LongTraceClass(FilePathHdf5_12)
ObjLongTraceMeasured.TimeLimit = [0, 1500]
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=2e2,TimePeriod=2e2);
ObjLongTraceMeasured.PlotLongTraceByParts()
ObjLongTraceMeasured.axis21.set_ylim(0, 5)
# ObjLongTraceMeasured.axis10.set_xlim(100, 125)
ObjLongTraceMeasured.FigureByParts.savefig(
    os.path.join(temp_dir, os.path.basename(FilePathHdf5_1)[:-5]+'.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# Input file is S103_550p_A2_150mV(32)_6.pt3.hdf5
# looking for df_ts 31914

# %% [markdown]
# ### 2D FCS Time Vs G(0)

# %%
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=2e2, TimePeriod=2e1);
ObjLongTraceMeasured.StatsLongTraceByParts()
# Out:
# looking for df_ts 33324

# %%
FCSCorrTimeAmp2D(ObjLongTraceMeasured, ObjLongTraceSimulated,
                 RangeCorrTime = [0, .35],
                 RangeCorrAmplitude = [0, 6])

# %% [markdown]
# ### Bright-Dark trace-corr

# %%
ObjLongTraceMeasured.onoff_values();

# %%
ObjLongTraceMeasured.TimeLimit = [0, 1200]
ObjLongTraceMeasured.InsetRangeBrightHist = [0, 0.2]
ObjLongTraceMeasured.InsetRangeDarkHist = [0,2]
ObjLongTraceMeasured.RangeForMidPotentialHist = (-15, 150)
ObjLongTraceMeasured.ContrastLimitCorrelation = [0, 1]

ObjLongTraceMeasured.PlotDurationsVsTime()
ObjLongTraceMeasured.axis01.set_ylim(0, 0.6)
ObjLongTraceMeasured.FigureDuration.savefig(
    os.path.join(temp_dir, 'longtrace_dynamic_het_temp.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# k1:7.17543375097
# [  7.17543375   0.634815    10.44328531]
# k1:5894.26463888
# [  5.89426464e+03   1.12058369e-01   2.48615584e+01]

# %% [markdown]
# ## Molecule-13
# ### Trace By Parts

# %%
ObjLongTraceMeasured = LongTraceClass(FilePathHdf5_13)
# ObjLongTraceMeasured.TimeLimit = [0, 2800]
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=1e2,TimePeriod=1e2);
ObjLongTraceMeasured.PlotLongTraceByParts()
ObjLongTraceMeasured.axis21.set_ylim(0, 3.5)
# ObjLongTraceMeasured.axis10.set_xlim(100, 125)
ObjLongTraceMeasured.FigureByParts.savefig(
    os.path.join(temp_dir, os.path.basename(FilePathHdf5_1)[:-5]+'.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# Input file is S103_550p_A2_150mV(32)_7.pt3.hdf5
# looking for df_ts 27689

# %% [markdown]
# ### 2D FCS Time Vs G(0)

# %%
ObjLongTraceMeasured.LongTraceByParts(TimeWindow=2e2, TimePeriod=2e1);
ObjLongTraceMeasured.StatsLongTraceByParts()
# Out:
# looking for df_ts 51505

# %%
FCSCorrTimeAmp2D(ObjLongTraceMeasured, ObjLongTraceSimulated,
                 RangeCorrTime = [0, .2],
                 RangeCorrAmplitude = [1, 2.5])

# %% [markdown]
# ### Bright-Dark trace-corr

# %%
ObjLongTraceMeasured.onoff_values();

# %%
# ObjLongTraceMeasured.TimeLimit = [0, 780]
ObjLongTraceMeasured.InsetRangeBrightHist = [0, 0.2]
ObjLongTraceMeasured.InsetRangeDarkHist = [0,2]
ObjLongTraceMeasured.RangeForMidPotentialHist = (-15, 150)
ObjLongTraceMeasured.ContrastLimitCorrelation = [0, 0.5]

ObjLongTraceMeasured.PlotDurationsVsTime()
ObjLongTraceMeasured.axis01.set_ylim(0, 0.4)
ObjLongTraceMeasured.FigureDuration.savefig(
    os.path.join(temp_dir, 'longtrace_dynamic_het_temp.svg'),
    format='svg', dpi=300, transparent=True)
# Out:
# k1:9.74452996686
# [   9.74452997    1.23181243  112.79794343]
# k1:0.994207171249
# [   0.99420717    0.87260749  101.86788004]
