# %%
# toogle view
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
#Import modules #Run this once
# %run Analysis.py
# %run changepoint_process.py
# %run autocorrelate.py
# %run longtrace_stat.py
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
#convert all pt3 to hdf5 in data folder
# %run pt3_to_hdf5.py
pt3t3r_to_hdf5_folder(folderpath='/home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/data/')#printed files are corrupted

# %% [markdown]
# # Folders

# %% [markdown]
# ## List of folders

# %%
#list of folders and their directories CuAZUATTO655
data_dir = '/home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/data'#GIVE the PATH of this FOLDER.
S129d28Feb18_590p_A1 = os.path.join(data_dir, 'AzurinATTO647N/S129d28Feb18_590p_A1')
S129d28Feb18_590p_A2 = os.path.join(data_dir, 'AzurinATTO647N/S129d28Feb18_590p_A2')
S129d29Feb18_590p_A3 = os.path.join(data_dir, 'AzurinATTO647N/S129d29Feb18_590p_A3')
S129d29Feb18_590p_A4 = os.path.join(data_dir, 'AzurinATTO647N/S129d29Feb18_590p_A4')
S129d29Feb18_590p_A5 = os.path.join(data_dir, 'AzurinATTO647N/S129d29Feb18_590p_A5')
S130d02MAr18_590p_A1 = os.path.join(data_dir, 'AzurinATTO647N/S130d02MAr18_590p_A1')
S130d02MAr18_590p_A1_2nd = os.path.join(data_dir, 'AzurinATTO647N/S130d02MAr18_590p_A1_2nd')
S130d02MAr18_590p_A1_3rd = os.path.join(data_dir, 'AzurinATTO647N/S130d02MAr18_590p_A1_3rd')
S130d02MAr18_590p_A1_4th = os.path.join(data_dir, 'AzurinATTO647N/S130d02MAr18_590p_A1_4th')
# Long time traces
S125d26Feb18_longtime = os.path.join(data_dir, 'AzurinATTO647N/20180223_longtime')
S130d02MAr18_590p_A2_150mV_longtimes = os.path.join(data_dir, 'AzurinATTO647N/S130d02MAr18_590p_A2_150mV_longtimes')
S130d02MAr18_590p_A3_100mV_longtimes = os.path.join(data_dir, 'AzurinATTO647N/S130d02MAr18_590p_A3_100mV_longtimes')

allfolders = [
             S129d28Feb18_590p_A1, S129d28Feb18_590p_A2, S129d29Feb18_590p_A3,
             S129d29Feb18_590p_A4, S129d29Feb18_590p_A5,
             S130d02MAr18_590p_A1, S130d02MAr18_590p_A1_2nd, S130d02MAr18_590p_A1_3rd, S130d02MAr18_590p_A1_4th,
             S125d26Feb18_longtime, S130d02MAr18_590p_A2_150mV_longtimes, S130d02MAr18_590p_A3_100mV_longtimes,
             ]
S130d02MAr18_A1_all = [S130d02MAr18_590p_A1, S130d02MAr18_590p_A1_2nd, S130d02MAr18_590p_A1_3rd, S130d02MAr18_590p_A1_4th]
S130d02MAr18_all = [S130d02MAr18_590p_A1, S130d02MAr18_590p_A1_2nd, S130d02MAr18_590p_A1_3rd, S130d02MAr18_590p_A1_4th,
                S125d26Feb18_longtime, S130d02MAr18_590p_A2_150mV_longtimes, S130d02MAr18_590p_A3_100mV_longtimes]

# %% [markdown]
# ## folder "temp\"
#
# Figures (other generated files) will be temporarily saved in this folder. temp folders are not tracked in git.

# %%
# Checking or creating temp_dir
temp_dir = 'temp'
temp_dir = os.path.join(temp_dir)
if os.path.isdir(temp_dir):
    print('temp_dir exists')
else:
    os.makedirs(temp_dir)
    print('temp_dir created')
# Out:
# temp_dir exists

# %% [markdown]
# # Time trace with changepoint

# %%
file_path_hdf5 = '/home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/data/AzurinATTO647N/20180223_longtime/data/Point_611p_N42CCuAzuATTO647N_A2_0100mV(29)_x.hdf5';
file_path_hdf5 = os.path.abspath(file_path_hdf5);
hdf5_anal, timestamps, cp_out = changepoint_photonhdf5(file_path_hdf5, time_sect=100,
                                                     pars=(1, 0.1, 0.9, 2), overwrite=False)
plt.close('all')
fig = plt.figure(figsize=(20, 4))
nrows=1;ncols=1;
ax00 = plt.subplot2grid((nrows, ncols),(0,0))

plot_changepoint_trace(ax00, timestamps, cp_out, bintime=10e-3,
               x_lim_min=0, y_lim_min=0, x_lim_max=1000, y_lim_max=5,
               show_changepoint=True);

# df_dig = digitize_photonstamps(file_path_hdf5)
# ax00.plot(df_dig['timestamps'], 1e-3*df_dig['countrate_cp'], 'r')
# ax00.set_xlim(0, 20)

# %%
plt.close('all')
fig = plt.figure(figsize=(20, 4))
nrows=1;ncols=1;
ax00 = plt.subplot2grid((nrows, ncols),(0,0))
plot_changepoint_trace(ax00, timestamps, cp_out, bintime=5e-3,
               x_lim_min=0, y_lim_min=0, x_lim_max=1000, y_lim_max=6,
               show_changepoint=False);

# %% [markdown]
# # Digitize photons

# %%
# %run changepoint_process.py
df_dig = digitize_photonstamps(file_path_hdf5, pars=(1, 0.01, 0.99, 2),time_sect=100,
                      bintime=5e-3, int_photon=True,
                      nano_time=True,
                      duration_cp=False)
df_dig.tail()
# Out:
#             timestamps  cp_no  state     nanotimes   int_photon
# 547907  1340.515314720   2551    1.0  21.871999913  0.008654605
# 547908  1340.522781494   2551    1.0  13.127999948  0.007466774
# 547909  1340.527214087   2551    1.0   7.495999970  0.004432593
# 547910  1340.537871821   2551    1.0   6.799999973  0.010657734
# 547911  1340.547378199   2551    1.0  20.407999918  0.009506378

# %%
# interphoton and lifetime histogram of different states
df_on = df_dig[df_dig['state']==2].reset_index(drop=True)
df_off = df_dig[df_dig['state']==1].reset_index(drop=True)

#
fig = plt.figure(figsize=[16, 4])
nrows=1;ncols=2
ax00 = plt.subplot2grid((nrows,ncols), (0,0))
ax01 = plt.subplot2grid((nrows,ncols), (0,1))
# lifetime histogram
n, t = np.histogram(df_on['nanotimes'], bins=200)
ax00.plot(t[:-1], n/max(n), label='ontime');
n, t = np.histogram(df_off['nanotimes'], bins=200)
ax00.plot(t[:-1], n/max(n), label='offtime');
#interphoton
hist, bin_edges = np.histogram(df_on['int_photon'], bins=300);
ax01.plot(bin_edges[:-1], hist, label='ontimes')
hist, bin_edges = np.histogram(df_off['int_photon'], bins=300);
ax01.plot(bin_edges[:-1], hist, label='offtimes')
hist, bin_edges = np.histogram(df_dig['int_photon'], bins=300);
ax01.plot(bin_edges[:-1], hist, label='total')
ax00.legend()
ax01.legend()
ax00.set_yscale('log')
# ax01.set_xscale('log')
ax01.set_yscale('log')
ax01.set_xlim(0, None)
# Out:
# (0, 0.13804296079382891)

# %%
# file_path_hdf5 = '/home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/data/AzurinATTO647N/S130d02MAr18_590p_A3_100mV_longtimes/data/S103_550p_A3_100mV(35)_9.hdf5'
# file_path_hdf5 = '/home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/data/AzurinATTO647N/20180223_longtime/data/Point_611p_N42CCuAzuATTO647N_A2_0100mV(29)_x.hdf5';
# file_path_hdf5 = '/home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/data/AzurinATTO647N/20180223_longtime/data/Point_611p_N42CCuAzuATTO647N_A2_0100mV(27)_42.hdf5';
# file_path_hdf5 = '/home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/data/AzurinATTO647N/S130d02MAr18_590p_A2_150mV_longtimes/data/S103_550p_A2_150mV(30)_2.hdf5'
# file_path_hdf5 = '/home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/data/AzurinATTO647N/S130d02MAr18_590p_A2_150mV_longtimes/data/S103_550p_A2_150mV(32)_6.hdf5'
file_path_hdf5 = '/home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/data/AzurinATTO647N/S130d02MAr18_590p_A2_150mV_longtimes/data/S103_550p_A2_150mV(32)_7.hdf5'
# file_path_hdf5 = '/home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/data/AzurinATTO647N/S129d29Feb18_590p_A6_longtimes/data/Point_A6_longtime_0100mV(47)_1.hdf5'
# file_path_hdf5 = '/home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/data/AzurinATTO647N/S129d29Feb18_590p_A6_longtimes/data/Point_A6_longtime_0100mV(47)_2.hdf5'

# %% [markdown]
# # On-off trace

# %%
file_path_hdf5 = '/home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/data/AzurinATTO647N/20180223_longtime/data/Point_611p_N42CCuAzuATTO647N_A2_0100mV(29)_x.hdf5';
def onoff_values(file_path_hdf5, time_lim=(0, 1e5)):
    df_dig = digitize_photonstamps(file_path_hdf5, pars=(1, 0.1, 0.9, 2),
                                   time_sect=100, time_lim=time_lim, bintime=5e-3,
                                   int_photon=False, nano_time=False, duration_cp=False)
    df_dig = df_dig[df_dig['timestamps'] < time_lim[1]]
    df_dig = df_dig[df_dig['timestamps'] > time_lim[0]]
    df_on = df_dig[df_dig['state']==2].reset_index(drop=True)
    df_off = df_dig[df_dig['state']==1].reset_index(drop=True)
    time_left = df_on.groupby('cp_no').timestamps.min();
    time_right = df_on.groupby('cp_no').timestamps.max();
    abstime_on = df_on.groupby('cp_no').timestamps.mean();
    ontimes = time_right - time_left
    
    time_left = df_off.groupby('cp_no').timestamps.min();
    time_right = df_off.groupby('cp_no').timestamps.max();    
    abstime_off = df_off.groupby('cp_no').timestamps.mean();
    offtimes = time_right - time_left
    l = len(abstime_on) - 2
    df = pd.DataFrame()
    df['abstime_on'] = abstime_on.values[:l]
    df['ontimes'] = ontimes.values[:l]
    df['abstime_off'] = abstime_off.values[:l]
    df['offtimes'] = offtimes.values[:l]
    return df
df = onoff_values(file_path_hdf5, time_lim=(0, 2.5e3))
df.head()
# Out:
#     abstime_on      ontimes  abstime_off     offtimes
# 0  0.156662920  0.100373772  0.059766505  0.088834715
# 1  0.358497920  0.071260997  0.275769523  0.110987755
# 2  0.536112669  0.074163275  0.455762303  0.104480407
# 3  2.474409488  0.136899295  1.446502859  1.822720530
# 4  3.190164928  0.525812225  2.721089412  0.377485451

# %%
df_mean = df.groupby(np.arange(len(df))//10).mean().dropna().reset_index(drop=True)
df_roll_mean = df.rolling(10).mean().dropna().reset_index(drop=True)
df_select = df

fig = plt.figure(figsize=[16, 8])
nrows=3;ncols=2
ax00 = plt.subplot2grid((nrows,ncols), (0,0))
ax01 = plt.subplot2grid((nrows,ncols), (0,1))
ax10 = plt.subplot2grid((nrows,ncols), (1,0), colspan=2)
ax20 = plt.subplot2grid((nrows,ncols), (2,0), colspan=2)


ax00.hist(df_select['ontimes'], bins=100, label='on times')
ax00.set_yscale('log')
ax00.legend()

ax01.hist(df_select['offtimes'], bins=100, range=(0, 10), label='off times')
ax01.set_yscale('log')
ax01.legend()

ax10.plot(df_select['abstime_on'], df_select['ontimes'], 'b')#1e5*ontimes
ax20.plot(df_select['abstime_off'], df_select['offtimes'], 'r')#1e5*ontimes
ax10.set_xlim(0, 2550)
ax10.set_ylim(0, 0.5)
ax20.set_xlim(0, 2550)
ax20.set_ylim(0, 5)
# Out:
# (0, 5)

# %%
# %run longtrace_stat.py
fig = plt.figure(figsize=[8, 6])
nrows=1;ncols=1
ax00 = plt.subplot2grid((nrows,ncols), (0,0))
corr_onoff_av(ax00, df_select['offtimes'], df_select['ontimes'],
              G_lim=[-0.01, 0.4], tlag_lim=[0, 1000]);

# %%
hdf5_anal, timestamps, cp_out = changepoint_photonhdf5(file_path_hdf5, time_sect=100,
                                                     pars=(1, 0.01, 0.99, 2), overwrite=False)
plt.close('all')
fig = plt.figure(figsize=(20, 4))
nrows=1;ncols=1;
ax00 = plt.subplot2grid((nrows, ncols),(0,0))

plot_changepoint_trace(ax00, timestamps, cp_out, bintime=10e-3,
               x_lim_min=0, y_lim_min=0, x_lim_max=3200, y_lim_max=5,
               show_changepoint=False);

# %%
def hist_2d_from_t_values(t_ons, t_offs,input_potential=100, x_shift=10, bins_on=40, range_on=[0, 0.01], bins_off=50, range_off=[0, 1], plots = True):
    t_ons=pd.Series(t_ons);t_offs=pd.Series(t_offs)
    t_on_shifted_1 = t_ons.shift(+1) ## shift up
    t_on_delay_1 = pd.DataFrame([t_on_shifted_1, t_ons]); t_on_delay_1=t_on_delay_1.T
    t_on_delay_1 = t_on_delay_1.dropna();
    t_off_shifted_1 = t_offs.shift(+1) ## shift up

    t_on_shifted_x = t_ons.shift(+x_shift) ## shift up
    t_off_shifted_x = t_offs.shift(+x_shift) ## shift up
    print('Number of on events: %d' %len(t_ons))
    print('Number of off events: %d' %len(t_offs))
    if plots==True:
        import matplotlib as mpl
        colormap=mpl.cm.RdBu_r
        fig = plt.figure(figsize=(16,8))

        ax1 = fig.add_subplot(2,3,1)#2,2,1
        C_on_1,Ex_on_1,Ey_on_1, figu = hist2d(t_on_shifted_1[1:], t_ons[1:], range=[range_on, range_on], bins=bins_on, norm=mpl.colors.LogNorm(), cmap=colormap)
        Ex_on_1,Ey_on_1 = meshgrid(Ex_on_1,Ey_on_1)
        #ax1.pcolormesh(Ex_on_1, Ey_on_1, C_on_1, cmap=colormap)#,norm=mpl.colors.LogNorm()
        colorbar()
        ax1.set_title('ON time Cu-Azu %smV' %input_potential)
        ax1.set_xlabel(r'$\tau_{on}/s$')
        ax1.set_ylabel(r'$\tau_{on}+1/s$')

        ax2 = fig.add_subplot(2,3,2)#2,2,1
        C_on_x,Ex_on_x,Ey_on_x, figu = hist2d(t_on_shifted_x[x_shift:], t_ons[x_shift:], range=[range_on, range_on], bins=bins_on, norm=mpl.colors.LogNorm(), cmap=colormap)
        Ex_on_x,Ey_on_x = meshgrid(Ex_on_x,Ey_on_x)
        #ax2.pcolormesh(Ex_on_x, Ey_on_x, C_on_x, cmap=colormap)#,norm=mpl.colors.LogNorm()
        colorbar()
        ax2.set_title('ON time Cu-Azu %smV' %input_potential)
        ax2.set_xlabel(r'$\tau_{on}/s$')
        ax2.set_ylabel(r'$\tau_{on}+%s/s$'%x_shift)

        ax3 = fig.add_subplot(2,3,3)
        C_on_diff = C_on_1-C_on_x;
        pcm=ax3.pcolormesh(Ex_on_x, Ey_on_x, C_on_diff,
                       norm=mpl.colors.SymLogNorm(linthresh=0.03, linscale=0.03,vmin=C_on_diff.min(), vmax=C_on_diff.max()), cmap=colormap)
        fig.colorbar(pcm, ax=ax3, extend='max')

        ax4 = fig.add_subplot(2,3,4)
        C_off_1, Ex_off_1, Ey_off_1, figu= hist2d(t_off_shifted_1[1:], t_offs[1:], range=[range_off, range_off],bins=bins_off, norm=mpl.colors.LogNorm(), cmap=colormap);#, norm=mpl.colors.LogNorm()
        Ex_off_1, Ey_off_1 = meshgrid(Ex_off_1, Ey_off_1)
        colorbar()
        ax4.set_title('OFF time Cu-Azu %smV' %input_potential)
        ax4.set_xlabel(r'$\tau_{off}/s$')
        ax4.set_ylabel(r'$\tau_{off}+1/s$')

        ax5 = fig.add_subplot(2,3,5)
        C_off_x,Ex_off_x,Ey_off_x, figu = hist2d(t_off_shifted_x[x_shift:], t_offs[x_shift:], range=[range_off, range_off],bins=bins_off, norm=mpl.colors.LogNorm(), cmap=colormap);#, norm=mpl.colors.LogNorm()
        Ex_off_x,Ey_off_x = meshgrid(Ex_off_x,Ey_off_x)
        colorbar()
        ax5.set_title('OFF time Cu-Azu %smV' %input_potential)
        ax5.set_xlabel(r'$\tau_{off}/s$')
        ax5.set_ylabel(r'$\tau_{off}+%s/s$'%x_shift)

        ax6 = fig.add_subplot(2,3,6)
        C_off_diff=C_off_1-C_off_x
        pcm=ax6.pcolormesh(Ex_off_x, Ey_off_x, C_off_diff, norm=mpl.colors.SymLogNorm(linthresh=0.03, linscale=0.03,vmin=C_off_diff.min(), vmax=C_off_diff.max()), cmap=colormap)
        fig.colorbar(pcm, ax=ax6, extend='max')
        plt.tight_layout()
        return()
hist_2d_from_t_values(df['ontimes'], df['offtimes'],
                      input_potential=100, x_shift=10, bins_on=10, range_on=[0, 2],
                      bins_off=10, range_off=[0, 10], plots = True)
# Out:
# Number of on events: 1330
# Number of off events: 1330
# ()

# %% [markdown]
# # Potential vs on-off ratio

# %%
folder=r'/home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/data/CuazuATTO647N/S129d28Feb18_590%_A1'
# E0_list, E0_m_list = Mid_potentials_slopem(folderpath=folder, pointnumbers=range(5), plotting=True, min_pot=0, min_pot_num=1)
E0_list, E0_m_list = Mid_potentials_slopem_lmfit(folderpath=folder, pointnumbers=range(0,50,1),
                                                 process='cp', plotting=True,
                                                 min_pot=40, min_pot_num=5)
plt.legend()

# %%
E0_list, E0_m_list = Mid_potentials_slopem_lmfit(folderpath=S130d02MAr18_590p_A1_4th,
                                                 pointnumbers=range(0,30,1),
                                                 process='cp', plotting=True,
                                                 min_pot=40, min_pot_num=1)
plt.legend()

# %%
# %run Analysis.py
E0_list, E0_m_list = Mid_potentials_slopem_lmfit(folderpath=S130d02MAr18_590p_A1_4th,
                                                 pointnumbers=[4, 22, 23],
                                                 process='cp', plotting=True,
                                                 min_pot=0, max_pot=130, min_pot_num=1)
plt.legend()

# %%
fig = timetraceplot_potentials(foldername=S130d02MAr18_590p_A1_4th, input_potential=[50, 100, 150, 200],
                             pointnumbers=[26], x_lim_min=0, x_lim_max=10,
                             y_lim_min=0, y_lim_max=7, bintime=5e-3,
                             show_changepoint=True, figsize=(10, 8))

# %%
fig = timetraceplot_potentials(foldername=S130d02MAr18_590p_A1_4th, input_potential=[0, 50, 100, 150, 200],
                             pointnumbers=[22], x_lim_min=0, x_lim_max=10,
                             y_lim_min=0, y_lim_max=7, bintime=5e-3,
                             show_changepoint=True, figsize=(10, 8))

# %% [markdown]
# # Histogram of E0

# %%
#Calculate midpoint potential of all points in all folders
E0_array = pd.DataFrame(index=None, columns=['Point number', 'E0_fit', 'E0_err'])
E0_m_array = pd.DataFrame(index=None, columns=['Point number', 'E0_fit', 'E0_err', 'slope', 'slope_error'])
for folder in allfolders:
    E0_list, E0_m_list = Mid_potentials_slopem_lmfit(folderpath=folder, pointnumbers=range(50),
                              process='cp', plotting=False,
                              min_pot=25, max_pot=200, min_pot_num=1)    
    E0_array = E0_array.append(E0_list, ignore_index=True)
    E0_m_array = E0_m_array.append(E0_m_list, ignore_index=True)

# %%
#MIDPOTENTIAL HISTGRAM FITTING
def plot_midpoint_hist(E0_array, E0_m_array,
                      min_range = 0, max_range = 0.175):
    # Figure parameters
    fig = plt.figure(figsize=(15, 5))
    nrows=1; ncols=3;
    ax00 = plt.subplot2grid((nrows, ncols), (0,0))
    ax01 = plt.subplot2grid((nrows, ncols), (0,1))
    ax02 = plt.subplot2grid((nrows, ncols), (0,2))
    mpl.rcParams["font.family"] = "sans-serif"
    mpl.rcParams["font.size"] = "14"
    
    range_fit = [min_range, max_range]
    bins = 20
    bin_centers_on = linspace(range_fit[0], range_fit[1], bins)
    x=linspace(range_fit[0], range_fit[1], 100)# for a smooth fitting plot include more points

    from scipy.interpolate import interp1d
    from lmfit.models import GaussianModel
    mod = GaussianModel()
    n,bins_on1,patches = ax00.hist(E0_array['E0_fit'], bins = bins, range=range_fit, color='b', label='Change Point')#E0_list from running all folder
    y=n; x=bin_centers_on;
    result1 = mod.fit(y, center=0.01, amplitude=10, sigma=0.02, x=x)
    temp =result1.best_values
    FWHM = 2*temp['sigma']*1000 #V
    cent = temp['center']*1000#eV
    amp = temp['amplitude']

    ax00.plot(x, result1.best_fit, '-ko', lw=4, label='Center: %.3f mV \n FWHM: %.2f mV' %(cent, FWHM))
    amp = temp['amplitude']
    height = 0.3989423*amp/max(1.e-15, temp['sigma'])
    ax00.plot([cent*0.001, cent*0.001], [0, height+0.2*height], '--ok', lw=4)

    ax00.set_xlim(0, 0.2)
    ax00.set_ylim(0,height+0.2*height)
    ax00.set_ylabel('P', fontsize=16)
    ax00.set_xlabel('Potential[V]', fontsize=16)
    ax00.legend(fontsize=16)
    #-----
    ax01 = fig.add_subplot(1,3,2)
    n,bins_on1,patches = ax01.hist(E0_m_array['E0_fit'], bins = bins, range=range_fit, color='b', label='Change Point')#E0_list from running all folder

    y=n; x=bin_centers_on;
    result1 = mod.fit(y, center=0.01, amplitude=10, sigma=0.02, x=x)
    temp =result1.best_values
    FWHM = 2*temp['sigma']*1000 #V
    cent = temp['center']*1000#eV
    amp = temp['amplitude']

    ax01.plot(x, result1.best_fit, '-ko', lw=4, label='Center: %.3f mV \n FWHM: %.2f mV' %(cent, FWHM))
    amp = temp['amplitude']
    height = 0.3989423*amp/max(1.e-15, temp['sigma'])
    ax01.plot([cent*0.001, cent*0.001], [0, height+0.2*height], '--ok', lw=4)

    ax01.set_xlim(0, 0.2)
    ax01.set_ylim(0,height+0.2*height)
    ax01.set_ylabel('P', fontsize=16)
    ax01.set_xlabel('Potential[V]', fontsize=16)
    ax01.legend(fontsize=16)
    #-----
    ax02 = fig.add_subplot(1,3,3)
    n,bins_on1,patches = ax02.hist(E0_m_array['slope'], bins = 20, range=(0, 0.2))#, range=range_fit, color='b', label='Change Point'
    ax02.set_ylabel('P', fontsize=16)
    ax02.set_xlabel('Slope[V]', fontsize=16)
    # ax02.legend(fontsize=16)

    fig.tight_layout()
    return()
plot_midpoint_hist(E0_array, E0_m_array)
# Out:
# ()

# %% [markdown]
# # Potential vs on-off time

# %%
def on_off_all_folder(folderlist, input_potential=[100], pointnumbers=range(100)):
    t_ons = []; t_offs = []; n_on = []; n_off = [];
    for folder in folderlist:
        df_datn_emplot = dir_mV_molNo(folder)
        df_specific = df_datn_emplot[df_datn_emplot['Point number'].isin(pointnumbers)]#keep all the points that exist
        df_specific = df_specific[df_specific['Potential'].isin(input_potential)]; df_specific.reset_index(drop=True, inplace=True)
        for i in range(len(df_specific)):
            Point_number = df_specific['Point number'][i]
            f_datn_path = df_specific['filepath[.datn]'].values[i]
            file_path_hdf5 = df_specific['filepath[.hdf5]'][i]
            if os.path.isfile(f_datn_path):
                try:
                    out = changepoint_photonhdf5(file_path_hdf5, time_sect=25,
                                                 pars=(1, 0.1, 0.9, 2),
                                                 overwrite=False)
                    [hdf5_anal, timestamps, cp_out] = out
                    onoff_out = onoff_fromCP(cp_out, timestamps)
                    df_ton = onoff_out['ontimes']
                    df_toff = onoff_out['offtimes']
                except:
                    print('em.plot file: %s doesn''t contain proper data' %df_emplot_filename)
                    df_ton=[]; df_toff=[]
                    pass
            else:
                print('em.plot file of %s with potential %s doesn''t exist' %(Point_number, input_potential))
                df_ton=[]; df_toff=[]
            t_ons = np.concatenate((t_ons, df_ton), axis=0);
            t_offs = np.concatenate((t_offs, df_toff));
    return t_ons, t_offs

# %%
#hist all rates
def risetime_fit(t, k1, k2, A):
    return ((A*k1*k2/(k2-k1)) * (exp(-k1*t) - exp(-k2*t)))
def mono_exp(t, k1, A):
    return A*exp(-k1*t)
def hist_fit_rates(potential_list=[100, 90], folderlist=allfolders):
    pot_update = []; tonav_update=[]; toffav_update = [];tonstd_update = [];toffstd_update = []
    for i in range(len(potential_list)):
        potential=[potential_list[i]]
        t_ons, t_offs = on_off_all_folder(folderlist= folderlist, input_potential=potential, 
                                          pointnumbers=range(100), pars=(1, 0.1, 0.9, 2))
        t_ons = t_ons[t_ons < 10]
        t_ons = t_ons[t_ons > 0]
        t_offs = t_offs[t_offs < 10]
        t_offs = t_offs[t_offs > 0]
        pot_update.append(potential[0])
        tonav_update.append(np.average(t_ons))
        toffav_update.append(np.average(t_offs))
        tonstd_update.append(np.std(t_ons))
        toffstd_update.append(np.std(t_offs))
    return pot_update, tonav_update, toffav_update, tonstd_update, toffstd_update
potential_list = [200, 175, 150, 125, 100, 75, 50]
out = hist_fit_rates(potential_list=potential_list, folderlist=S130d02MAr18_all)
[pot_update, tonav_update, toffav_update, tonstd_update, toffstd_update] = out

# %%
plt.close('all')
fig = plt.figure(figsize=(12, 10))
nrows=1;ncols=2;
ax00 = plt.subplot2grid((nrows, ncols),(0,0))
ax01 = plt.subplot2grid((nrows, ncols),(0,1))
ax00.errorbar(pot_update, tonav_update, yerr=tonstd_update,
              fmt='o')#plot raw outputs
# ax00.plot(pot_update, tonav_update, '-*',  label='average ontimes')
ax01.errorbar(pot_update, toffav_update, yerr=toffstd_update,
              fmt='o')#plot raw outputs
# ax01.plot(pot_update, toffav_update, '-*', label='average offtimes')
# ax00.legend()
# ax01.legend()
# Out:
# <Container object of 3 artists>

# %% [markdown]
# ## one potential

# %%
t_ons, t_offs = on_off_all_folder(folderlist= S130d02MAr18_all, input_potential=[100], pointnumbers=range(100), pars=(1, 0.1, 0.9, 2))
t_ons = t_ons[t_ons < 10]
t_ons = t_ons[t_ons > 0]
t_offs = t_offs[t_offs < 10]
t_offs = t_offs[t_offs > 0]

plt.close('all')
fig = plt.figure(figsize=(20, 4))
nrows=1;ncols=2;
ax00 = plt.subplot2grid((nrows, ncols),(0,0))
ax01 = plt.subplot2grid((nrows, ncols),(0,1))
ax00.hist(t_ons, bins=100, range=(0,0.1));
ax01.hist(t_offs, bins=100, range=(0,0.1));

# %% [markdown]
# # 1 azurin: different time

# %%
def Mid_potentials_pointwise(ax, folderpath, pointnumbers=range(5),
                          process='cp', plotting=True,
                          min_pot=40, max_pot=150, min_pot_num=1):
    '''
    Argument: 
    process: 'fcs' or 'cp'
    '''
    if process == 'cp':
        out = cp_outputs_folderwise(folderpath=folderpath,
                                    pointnumbers=pointnumbers,
                                    potentialist=potentialist)
    if process == 'fcs':
        out = fcs_outputs_folderwise(folderpath=folderpath,
                                     pointnumbers=pointnumbers,
                                     potentialist=potentialist)
    # Nernst Equation definition        
    def nernst(x, a):
        '''x is potential
        a: E0/midpoint potential(parameter)
        returns ratio(t_oxd/t_red)'''
        return(10**((x-a) / 0.059))
    nernst_mod = Model(nernst)
    params_nernst = nernst_mod.make_params(a=0.02)
    def nernst_slopem(x, a, m):
        return(10**((x-a) / m))
    nernst_slopem_mod = Model(nernst_slopem)
    params_ner_slop = nernst_slopem_mod.make_params(a=0.02, m=0.059)
    columns_E0 = ['Point number', 'E0_fit', 'E0_err']
    columns_E0_m = ['Point number', 'E0_fit', 'E0_err', 'slope', 'slope_error']
    E0_list = pd.DataFrame(index=None, columns=columns_E0)
    E0_m_list = pd.DataFrame(index=None, columns=columns_E0_m)
    #--figure initiation----
    cmap = plt.get_cmap('jet')#jet_r
    N=len(out.columns.levels[0])
    for i in range(len(out.columns.levels[0])):
        point = out.columns.levels[0][i]
        point_output_tot = out[point].dropna()
        point_output = point_output_tot[point_output_tot['Potential'] >= min_pot] #select a potential threshold
        point_output = point_output_tot[point_output_tot['Potential'] <= max_pot] #select a potential threshold
        point_output.reset_index(drop=True, inplace=True)
        if len(point_output)>min_pot_num:
            potential = point_output['Potential']
            t_onav = point_output['t_onav']
            t_onaverr = point_output['t_onaverr']
            t_offav = point_output['t_offav']
            t_offaverr = point_output['t_offaverr']
            t_ratio = point_output['t_ratio']
            t_ratioerr = point_output['t_ratioerr']
            E = potential*0.001 #converting to mV
            #--------fitting nernst----------------
            res_nernst = nernst_mod.fit(t_ratio, params_nernst, x=E)
            out_params = str((res_nernst.params['a'],'value'));
            E0 = res_nernst.best_values['a']
            E0_err = float(out_params.split('+/- ')[1].split(', bounds')[0]);
            #---------append to list---------
            E0_list_temp = pd.DataFrame([[point, E0, E0_err]], columns=columns_E0)
            E0_list=E0_list.append(E0_list_temp, ignore_index=True)
            #--------fitting nernst_slopem------
            res_nernst_slop = nernst_slopem_mod.fit(t_ratio, params_ner_slop, x=E)
            E0_m = res_nernst_slop.best_values['a']
            out_params = str((res_nernst_slop.params['a'],'value'));
            E0_m_err = float(out_params.split('+/- ')[1].split(', bounds')[0]);
            slope_m = res_nernst_slop.best_values['m']
            out_params_m = str((res_nernst_slop.params['m'],'value'));
            slope_m_err = float(out_params_m.split('+/- ')[1].split(', bounds')[0]);
            E0_m_list_temp = pd.DataFrame([[point, E0_m, E0_m_err, slope_m, slope_m_err]], columns=columns_E0_m)
            E0_m_list = E0_m_list.append(E0_m_list_temp, ignore_index=True)
            #-----plot------
            if plotting == True:
                color = cmap(float(i)/N)
#                 ax.errorbar(point_output_tot['Potential'], point_output_tot['t_ratio'],
#                          yerr=point_output_tot['t_ratioerr'], fmt='o', color=color, label=point)#plot raw outputs
                ax.plot(point_output_tot['Potential'], point_output_tot['t_ratio'],
                        'o', label=point)#plot raw outputs                
                ax.plot(linspace(min(potential)-10, max(potential)+10), nernst(0.001*linspace(min(potential)-10, max(potential)+10), E0), linewidth=2.0)#color
                #plot(E*1000, nernst(E, *E0_fit), color=color, linewidth=2.0)
                ax.set_yscale('log')
                ax.set_xlabel('$Potential [V]$', fontsize=20)
                ax.set_ylabel('$T_{OFF}/T_{ON}$', fontsize=20)
                ax.tick_params(axis='both', which='major', labelsize=16)
                ax.set_title(r'$E=E_0 + 0.059log(\frac{t_{off}}{t_{on}})$')
                tight_layout()
    return(E0_list, E0_m_list)

# %%
plt.close('all')
fig = plt.figure(figsize=(6, 6))
nrows=1;ncols=1;
ax00 = plt.subplot2grid((nrows, ncols),(0,0))

E0_list, E0_m_list = Mid_potentials_pointwise(ax=ax00, folderpath=S130d02MAr18_590p_A1_4th,
                                                 pointnumbers=[4, 22, 23],
                                                 process='cp', plotting=True,
                                                 min_pot=0, max_pot=200, min_pot_num=1)
ax00.legend()

# %%
# Point 22
plt.close('all')
fig = plt.figure(figsize=(6, 6))
nrows=1;ncols=1;
ax00 = plt.subplot2grid((nrows, ncols),(0,0))

E0_list, E0_m_list = Mid_potentials_slopem_lmfit(ax=ax00, folderpath=S130d02MAr18_590p_A1,
                                                 pointnumbers=[22],
                                                 process='cp', plotting=True,
                                                 min_pot=0, max_pot=200, min_pot_num=1)
E0_list, E0_m_list = Mid_potentials_slopem_lmfit(ax=ax00, folderpath=S130d02MAr18_590p_A1_2nd,
                                                 pointnumbers=[22],
                                                 process='cp', plotting=True,
                                                 min_pot=0, max_pot=200, min_pot_num=1)
E0_list, E0_m_list = Mid_potentials_slopem_lmfit(ax=ax00, folderpath=S130d02MAr18_590p_A1_3rd,
                                                 pointnumbers=[22],
                                                 process='cp', plotting=True,
                                                 min_pot=0, max_pot=200, min_pot_num=1)
E0_list, E0_m_list = Mid_potentials_slopem_lmfit(ax=ax00, folderpath=S130d02MAr18_590p_A1_4th,
                                                 pointnumbers=[22],
                                                 process='cp', plotting=True,
                                                 min_pot=0, max_pot=200, min_pot_num=1)

ax00.legend(['0 hours', '',
             '1 hours', '',
             '2 hour', '',
             '3 hour', ''])

# %%
#Point 23
plt.close('all')
fig = plt.figure(figsize=(6, 6))
nrows=1;ncols=1;
ax00 = plt.subplot2grid((nrows, ncols),(0,0))

E0_list, E0_m_list = Mid_potentials_slopem_lmfit(ax=ax00, folderpath=S130d02MAr18_590p_A1,
                                                 pointnumbers=[23],
                                                 process='cp', plotting=True,
                                                 min_pot=0, max_pot=200, min_pot_num=1)
E0_list, E0_m_list = Mid_potentials_slopem_lmfit(ax=ax00, folderpath=S130d02MAr18_590p_A1_2nd,
                                                 pointnumbers=[23],
                                                 process='cp', plotting=True,
                                                 min_pot=0, max_pot=200, min_pot_num=1)
E0_list, E0_m_list = Mid_potentials_slopem_lmfit(ax=ax00, folderpath=S130d02MAr18_590p_A1_3rd,
                                                 pointnumbers=[23],
                                                 process='cp', plotting=True,
                                                 min_pot=0, max_pot=200, min_pot_num=1)
E0_list, E0_m_list = Mid_potentials_slopem_lmfit(ax=ax00, folderpath=S130d02MAr18_590p_A1_4th,
                                                 pointnumbers=[23],
                                                 process='cp', plotting=True,
                                                 min_pot=0, max_pot=200, min_pot_num=1)

ax00.legend(['0 hours', '',
             '1 hours', '',
             '2 hour', '',
             '3 hour', ''])

# %%
#Point 4
plt.close('all')
fig = plt.figure(figsize=(6, 6))
nrows=1;ncols=1;
ax00 = plt.subplot2grid((nrows, ncols),(0,0))

E0_list, E0_m_list = Mid_potentials_slopem_lmfit(ax=ax00, folderpath=S130d02MAr18_590p_A1,
                                                 pointnumbers=[4],
                                                 process='cp', plotting=True,
                                                 min_pot=0, max_pot=200, min_pot_num=1)
E0_list, E0_m_list = Mid_potentials_slopem_lmfit(ax=ax00, folderpath=S130d02MAr18_590p_A1_2nd,
                                                 pointnumbers=[4],
                                                 process='cp', plotting=True,
                                                 min_pot=0, max_pot=200, min_pot_num=1)
E0_list, E0_m_list = Mid_potentials_slopem_lmfit(ax=ax00, folderpath=S130d02MAr18_590p_A1_3rd,
                                                 pointnumbers=[4],
                                                 process='cp', plotting=True,
                                                 min_pot=0, max_pot=200, min_pot_num=1)
E0_list, E0_m_list = Mid_potentials_slopem_lmfit(ax=ax00, folderpath=S130d02MAr18_590p_A1_4th,
                                                 pointnumbers=[4],
                                                 process='cp', plotting=True,
                                                 min_pot=0, max_pot=200, min_pot_num=1)

ax00.legend(['0 hours', '',
             '1 hours', '',
             '2 hour', '',
             '3 hour', ''])

# %% [markdown]
# #

# %% [markdown]
# # Long time trace

# %%
file_path_hdf5 = '/home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/data/AzurinATTO647N/20180223_longtime/data/Point_611p_N42CCuAzuATTO647N_A2_0100mV(29)_x.hdf5';

# %%
def longtrace_byparts_color(timestamps, nanotimes, save_folder,
                      window=1e4, period=1e3, by_photon=False, plotting=False):
    '''
    Arguments:
    timestamps and nanotimes should be of equal length and
    both in the units of seconds
    window and period in number of photons
    by_photon: by defaul it is false and it devides the trace by time. If true, it will devide the trace by the number of photons
    '''
    df_fcs = pd.DataFrame()
    df_lt = pd.DataFrame()  # lifetiem
    df_ip = pd.DataFrame()  # interphoton
    df_ts = pd.DataFrame()
    if by_photon:
        length = len(timestamps)
        index_left = 0
        length_update = length - index_left

        while length_update > window:
            tleft = int(index_left)
            tright = int(index_left + window)
            # change "period" to "window" to avoid rolling
            index_left = int(index_left + period)
            length_update = int(length - index_left)

            t_mac_temp = timestamps[tleft:tright]
            t_mic_temp = 1e9 * nanotimes[tleft:tright]
            
            df_ts['t'] = t_mac_temp
            df_ts[str(tleft)] = t_mac_temp

            # interphoton histogram
            t_diff = np.diff(t_mac_temp)
            binned_trace = np.histogram(t_diff, bins=500, range=(1e-5, 1e-1))
            t = binned_trace[1][:-1]
            n = binned_trace[0]
            df_ip['t'] = t
            df_ip[str(tleft)] = n / max(n)
            # lifetime histogram
            binned_trace = np.histogram(t_mic_temp, bins=50, range=(0, 8))
            t = binned_trace[1][:-1]
            n = binned_trace[0]
            df_lt['t'] = t
            df_lt[str(tleft)] = n / max(n)
            # FCS
            bin_lags = make_loglags(-6, 0, 10)
            Gn = normalize_G(t_mac_temp, t_mac_temp, bin_lags)
            Gn = np.hstack((Gn[:1], Gn)) - 1
            df_fcs['t'] = bin_lags
            df_fcs[str(tleft)] = Gn
    else:
        length = max(timestamps)
        index_left = min(timestamps)
        length_update = length - index_left
        col_names = []
        while length_update > window:
            tleft = int(index_left)
            tright = int(index_left + window)
            # change "period" to "window" to avoid rolling
            index_left = int(index_left + period)
            length_update = int(length - index_left)
            
            mask = np.logical_and(timestamps >= tleft, timestamps <= tright)
            t_mac_temp = timestamps[mask]
            t_mic_temp = 1e9 * nanotimes[mask]
#             df_ts['t'] = t_mac_temp
#             df_ts[str(tleft)] = t_mac_temp
            df_ts_temp = pd.DataFrame({str(tleft):t_mac_temp})
#             print(len(df_ts_temp))
            df_ts = pd.concat([df_ts, df_ts_temp], ignore_index=True, axis=1)
            # interphoton histogram
            t_diff = np.diff(t_mac_temp)
            binned_trace = np.histogram(t_diff, bins=500, range=(1e-5, 1e-1))
            t = binned_trace[1][:-1]
            n = binned_trace[0]
            df_ip['t'] = t
            df_ip[str(tleft)] = n / max(n)
            # lifetime histogram
            binned_trace = np.histogram(t_mic_temp, bins=50, range=(0, 8))
            t = binned_trace[1][:-1]
            n = binned_trace[0]
            df_lt['t'] = t
            df_lt[str(tleft)] = n / max(n)
            # FCS
            bin_lags = make_loglags(-6, 1, 10)
            Gn = normalize_G(t_mac_temp, t_mac_temp, bin_lags)
            Gn = np.hstack((Gn[:1], Gn)) - 1
            df_fcs['t'] = bin_lags
            df_fcs[str(tleft)] = Gn
            col_names.append(str(tleft))

        df_ts_temp = pd.DataFrame({str(tleft):t_mac_temp})
        df_ts = pd.concat([df_ts_temp, df_ts], ignore_index=True, axis=1)
        col_names.append(col_names[0])
        df_ts.columns = col_names        
    if plotting:
        plt.close('all')
        nrows = 3
        ncols = 2
        fig = plt.figure(figsize=(10, 8))
        ax00 = plt.subplot2grid((nrows, ncols), (0, 0), colspan=2)
        ax10 = plt.subplot2grid((nrows, ncols), (1, 0))
        ax11 = plt.subplot2grid((nrows, ncols), (1, 1))
        ax20 = plt.subplot2grid((nrows, ncols), (2, 0))
        ax21 = plt.subplot2grid((nrows, ncols), (2, 1))        
        cmap = plt.get_cmap('jet')#jet_r
        N=len(df_ts.columns)
        i=1
        for column in df_ts.iloc[:, 1:]:
            color = cmap(float(i)/N)
            i=i+1
            #plot all
            plot_timetrace(ax00, df_ts[column], bintime=5e-3, color=color)#timestamps
            #plot individual
            ax11.plot(df_lt.iloc[:, 0], df_lt[column],color=color)
            ax20.plot(df_ip.iloc[:, 0], df_ip[column],color=color)
            ax21.plot(df_fcs.iloc[:, 0], df_fcs[column],color=color)
        ax00.axvspan(min(df_ts[column]), max(df_ts[column]),color=color
                     , alpha=0.3, lw=0)            
        # axis properties
        plot_timetrace(ax10, df_ts[column], bintime=5e-3, color=color)
        ax00.set_ylim(0, None)
        ax00.set_xlim(min(timestamps), max(df_ts[column]))
        ax10.set_ylim(0, None)
        ax10.set_xlim(min(df_ts[column]), max(df_ts[column]))
        ax10.legend(['Highlighted part of the trace'])
        ax11.set_xlim(2, 8)
        ax11.set_ylim(1e-1, None)
        ax11.set_yscale('log')
        ax11.set_xlabel('Lifetime/ns')
        ax11.set_ylabel('#')
        ax20.set_xlim(1e-5, 1e-1)
        ax20.set_xscale('log')
        ax20.set_yscale('log')
        ax20.set_xlabel('Interphoton time/s')
        ax20.set_ylabel('#')
        ax21.set_xlim(1e-5, 1)
        ax21.set_ylim(0, 4)
        ax21.set_xscale('log')
        ax21.set_xlabel('lag time/s')
        ax21.set_ylabel('G(t)-1')
#         ax11.legend('Life time')
#         ax20.legend('Inter photon times')
#         ax21.legend('FCS')
        # fig.tight_layout()
        # save figure
        date = datetime.datetime.today().strftime('%Y%m%d_%H%M')
        savename = date+'_'+str(column) + '.png'
        savename = os.path.join(save_folder, savename)
        fig.savefig(savename, dpi=300)
    return df_ts, df_lt, df_fcs, df_ip

# %%
# file_path_hdf5 = '/home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/data/AzurinATTO647N/20180223_longtime/data/Point_611p_N42CCuAzuATTO647N_A2_0100mV(29)_x.hdf5';
file_path_datn = file_path_hdf5[:-4] + 'pt3.datn'
df_datn = pd.read_csv(file_path_datn, header=None)
tmin = min(df_datn[0])
tmax = max(df_datn[0])
# tmin=0
# tmax=2600
h5 = h5py.File(file_path_hdf5)
unit = h5['photon_data']['timestamps_specs']['timestamps_unit'][...]
tcspc_unit = h5['photon_data']['nanotimes_specs']['tcspc_unit'][...]
timestamps = unit * h5['photon_data']['timestamps'][...]
nanotimes = tcspc_unit * h5['photon_data']['nanotimes'][...]
mask = np.logical_and(timestamps >= tmin, timestamps <= tmax)
timestamps = timestamps[mask]
nanotimes = nanotimes[mask]
h5.close()

# %%
save_folder = temp_dir
out = longtrace_byparts_color(timestamps, nanotimes, save_folder,
                      window=2e4, period=2e4, plotting=True)
[df_ts, df_lt, df_fcs, df_ip] = out
