# %% [markdown]
# ## Import and directories

# %%
#directories
import os
try:
    parentdir
except NameError:
    parentdir=os.getcwd()
else:
    parentdir = parentdir
homedir=r'/home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/data/201609/20160907_CuAzu655_Ferri_Asc_analysis/S81d7Sept16_0.11uW_0.2mMFerri_0.1mM Asc_A3_ON/';#data directory
print('The working directory is parentdir: %s' %parentdir)
print('The data directory is homedir: %s' %homedir)
homedir_A5=r'/home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/data/201609/20160907_CuAzu655_Ferri_Asc_analysis/S81d7Sept16_0.11uW_0.2mMFerri_0.1mM Asc_A5_ON/'

# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
# Out:
# The working directory is parentdir: /home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/Azurin_SM_repo/Analysis
# The data directory is homedir: /home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/data/201609/20160907_CuAzu655_Ferri_Asc_analysis/S81d7Sept16_0.11uW_0.2mMFerri_0.1mM Asc_A3_ON/

# %%
#Run this once to run the .py file.
os.chdir(parentdir)
# !python Analysis_bis.py
# %run Analysis_bis.py

# %%
os.chdir(parentdir)
# !python Analysis_CuAz_April2017.py
# %run Analysis_CuAz_April2017.py

# %% [markdown]
# ### Figure Parameters

# %%
mpl.rcParams["font.family"] = "sans-serif"
mpl.rcParams["font.size"] = "14"

# %% [markdown]
# ## List of Points

# %% [markdown]
# ### A3

# %%
point_list(foldername=homedir)
# Out:
#    Point_2 Point_5 Point_6  Point_8 Point_10 Point_11 Point_15 Point_16  \
# 0     -300    -300    -300   -300.0     -300     -300     -300     -250
# 1     -200    -250    -250   -250.0     -250     -250     -250      -50
# 2      -50    -200     -50   -200.0     -200     -200     -200       25
# 3        0     -50       0    -50.0      -50      -50      -50      150
# 4        0       0      25    -25.0      -25      -25        0
# 5       50      50      50      0.0        0        0       25
# 6      200     100     100     25.0       25       25       50
# 7              150     150     50.0       50       50      100
# 8              200             50.0      100      100      150
# 9                             100.0      150      150      200
# 10                            150.0      200      200
# 11                            200.0
#
#    Point_17
# 0      -300
# 1      -250
# 2      -200
# 3       -50
# 4       -25
# 5         0
# 6        25
# 7        50
# 8       100
# ...

# %% [markdown]
# ### A5

# %%
point_list(foldername=homedir_A5)
# Out:
#    Point_1 Point_2 Point_3  Point_4 Point_5 Point_7  Point_8  Point_10  \
# 0   -300.0    -200    -200   -300.0    -200    -300   -300.0    -300.0
# 1   -200.0     100      50   -200.0      50    -100   -200.0    -200.0
# 2   -100.0             100   -100.0     100       0   -100.0    -100.0
# 3      0.0                      0.0              50      0.0       0.0
# 4     50.0                     50.0             100     50.0      50.0
# 5    100.0                    100.0             150    100.0     100.0
# 6    150.0                    150.0                    150.0     150.0
#
#    Point_11 Point_12 Point_13 Point_14  Point_15  Point_16 Point_17  Point_19
# 0    -300.0     -200     -200     -200    -300.0    -300.0     -200    -300.0
# 1    -200.0       50      100       50    -200.0    -200.0      100    -200.0
# 2    -100.0      100               100    -100.0    -100.0             -100.0
# 3       0.0                                  0.0       0.0                0.0
# ...

# %%
#*************Analysis for a specific potential********************

titel = 'average_on_and_off_time_specific_mV_Cu.xls' #name excell output file
pointnumbers = 31 #Change this to the minimal amount of points
pot = 18 #number of potentials
specific_potential = 100 #the specific potential you want the plots for
onMax=0.25;offMax=0.25;
rnge_on = [[0,onMax], [0,onMax]] #range on histograms, form: [[0,0.25], [0,0.25]] --> [xrange], [yrange]
rnge_off = [[0,offMax], [0,offMax]] #range off histograms
bins_on = 100  #bins for the on histograms
bins_off = 100 #bins for the off histograms
proteins = 'Cu' #change this to 'Zn' or 'Cu' depending on which files you are analysing. Changes title of plots.
current_dir = directory#'S101d14Feb17_60.5_635_A2_CuAzu655' #foldername you want to work in.
max_his_on = onMax
max_his_off = offMax
x_shift = 10 # t vs  t + x_shift 

histograms(titel, pot, pointnumbers, specific_potential, rnge_on, rnge_off, bins_on, bins_off, proteins, current_dir, max_his_on, max_his_off, x_shift)
# Out:
# Fit ON time histogram: 1730.13829977 * e^{-131.11870687 t}
# Fit OFF time histogram: -76.4477222412 * e^{-109.549051539 t} - -62.3571346686 * e^{-5.23661538522 t}
# ()

# %% [markdown]
# ## Individual molecules

# %%
os.chdir(parentdir)
# !python analysis_version_9.py
# %run analysis_version_9.py

# %% [markdown]
# ## Point_7

# %% [markdown]
# ### 0 mV

# %%
#************* data and changepoint plot********************
os.chdir(directory);os.chdir("Point_7/")
file1 = 'Point_0.11uW_A3_0mV(15)_30s_7.pt3.datn'
file2 = 'Point_0.11uW_A3_0mV(15)_30s_7.pt3.datn.em.plot'
time_trace_plot(file1, file2, bintime=5,xlimit=[0,30],ylimit=[0,None])
# Out:
# Total length of the time trace is 30.0
# C:\Users\Pradhan\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\lib\function_base.py:564: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   n = np.zeros(bins, ntype)
# C:\Users\Pradhan\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\lib\function_base.py:611: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   n += np.bincount(indices, weights=tmp_w, minlength=bins).astype(ntype)
# ()

# %% [markdown]
# ### 25 mV

# %%
#************* data and changepoint plot********************
os.chdir(directory);os.chdir("Point_7/")
file1 = 'Point_0.11uW_A3_25mV(19)_30s_7.pt3.datn'
file2 = 'Point_0.11uW_A3_25mV(19)_30s_7.pt3.datn.em.plot'
time_trace_plot(file1, file2, bintime=10,xlimit=[0,30],ylimit=[0,None])
# Out:
# Total length of the time trace is 30.0
# C:\Users\Pradhan\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\lib\function_base.py:564: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   n = np.zeros(bins, ntype)
# C:\Users\Pradhan\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\lib\function_base.py:611: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   n += np.bincount(indices, weights=tmp_w, minlength=bins).astype(ntype)
# ()

# %% [markdown]
# ### 50 mV

# %%
#************* data and changepoint plot********************
os.chdir(directory);os.chdir("Point_7/")
file1 = 'Point_0.11uW_A3_50mV(14)_30s_7.pt3.datn'
file2 = 'Point_0.11uW_A3_50mV(14)_30s_7.pt3.datn.em.plot'
time_trace_plot(file1, file2, bintime=10,xlimit=[0,30],ylimit=[0,None])
# Out:
# Total length of the time trace is 30.0
# C:\Users\Pradhan\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\lib\function_base.py:564: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   n = np.zeros(bins, ntype)
# C:\Users\Pradhan\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\lib\function_base.py:611: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   n += np.bincount(indices, weights=tmp_w, minlength=bins).astype(ntype)
# ()

# %% [markdown]
# ### 75 mV

# %%
#************* data and changepoint plot********************
os.chdir(directory);os.chdir("Point_7/")
file1 = 'Point_0.11uW_A3_75mV(18)_30s_7.pt3.datn'
file2 = 'Point_0.11uW_A3_75mV(18)_30s_7.pt3.datn.em.plot'
time_trace_plot(file1, file2, bintime=10,xlimit=[10,15],ylimit=[0,None])
# Out:
# Total length of the time trace is 30.0
# C:\Users\Pradhan\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\lib\function_base.py:564: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   n = np.zeros(bins, ntype)
# C:\Users\Pradhan\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\lib\function_base.py:611: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   n += np.bincount(indices, weights=tmp_w, minlength=bins).astype(ntype)
# ()

# %% [markdown]
# ### 100 mV

# %%
#************* data and changepoint plot********************
os.chdir(directory);os.chdir("Point_7/")
file1 = 'Point_0.11uW_A3_100mV(13)_30s_7.pt3.datn'
file2 = 'Point_0.11uW_A3_100mV(13)_30s_7.pt3.datn.em.plot'
time_trace_plot(file1, file2, bintime=10,xlimit=[0,1],ylimit=[0,None])
# Out:
# Total length of the time trace is 30.0
# C:\Users\Pradhan\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\lib\function_base.py:564: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   n = np.zeros(bins, ntype)
# C:\Users\Pradhan\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\lib\function_base.py:611: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   n += np.bincount(indices, weights=tmp_w, minlength=bins).astype(ntype)
# ()

# %% [markdown]
# ### -50 mV

# %%
#************* data and changepoint plot********************
os.chdir(directory);os.chdir("Point_7/")
file1 = 'Point_0.11uW_A3_-50mV(16)_30s_7.pt3.datn'
file2 = 'Point_0.11uW_A3_-50mV(16)_30s_7.pt3.datn.em.plot'
time_trace_plot(file1, file2, bintime=10,xlimit=[0,30],ylimit=[0,None])
# Out:
# Total length of the time trace is 30.0
# C:\Users\Pradhan\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\lib\function_base.py:564: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   n = np.zeros(bins, ntype)
# C:\Users\Pradhan\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\lib\function_base.py:611: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   n += np.bincount(indices, weights=tmp_w, minlength=bins).astype(ntype)
# ()

# %% [markdown]
# ### -100 mV

# %%
#************* data and changepoint plot********************
os.chdir(directory);os.chdir("Point_7/")
file1 = 'Point_0.11uW_A3_-100mV(17)_30s_7.pt3.datn'
file2 = 'Point_0.11uW_A3_-100mV(17)_30s_7.pt3.datn.em.plot'
time_trace_plot(file1, file2, bintime=10,xlimit=[0,30],ylimit=[0,None])
# Out:
# Total length of the time trace is 30.0
# C:\Users\Pradhan\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\lib\function_base.py:564: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   n = np.zeros(bins, ntype)
# C:\Users\Pradhan\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\lib\function_base.py:611: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   n += np.bincount(indices, weights=tmp_w, minlength=bins).astype(ntype)
# ()

# %% [markdown]
# ## Timetrace_comparision

# %% [markdown]
# ### Point_1

# %%
mpl.rcParams["font.family"] = "sans-serif"
mpl.rcParams["font.size"] = "14"

os.chdir(homedir)
fig = time_trace_plot(foldername='all data', input_potential=[0, 50, 100], 
                    input_number=1, x_lim_min=0, y_lim_min=0, x_lim_max=3, y_lim_max=6, bin=4)
os.chdir(parentdir)
savefig('tt_compare.pdf', dpi=300, transparent=True)
# Out:
# C:\Users\Pradhan\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\lib\function_base.py:564: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   n = np.zeros(bins, ntype)
# C:\Users\Pradhan\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\lib\function_base.py:611: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   n += np.bincount(indices, weights=tmp_w, minlength=bins).astype(ntype)

# %%
# fig = time_trace_plot(foldername=homedir_A5, input_potential=[0, 50, 100], 
#                     pointnumbers=7, x_lim_min=0, y_lim_min=0, x_lim_max=3, y_lim_max=6, bin=4)
fig = time_trace_plot(foldername= homedir_A5, input_potential=[0, 50, 100], pointnumbers=[7], x_lim_min=0, y_lim_min=0, x_lim_max=15, y_lim_max=6, bin=5, show_changepoint=True)
# Out:
# 50.0
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-8-9f17a0abd1b5> in <module>()
#       1 # fig = time_trace_plot(foldername=homedir_A5, input_potential=[0, 50, 100],
#       2 #                     pointnumbers=7, x_lim_min=0, y_lim_min=0, x_lim_max=3, y_lim_max=6, bin=4)
# ----> 3 fig = time_trace_plot(foldername= homedir_A5, input_potential=[0, 50, 100,], pointnumbers=[7,], x_lim_min=0, y_lim_min=0, x_lim_max=15, y_lim_max=6, bin=5, show_changepoint=True)
#
# /home/biswajit/Research/Reports_ppt/reports/AzurinSM-MS4/Azurin_SM_repo/Analysis/Analysis_bis.py in time_trace_plot(foldername, input_potential, pointnumbers, x_lim_min, y_lim_min, x_lim_max, y_lim_max, bin, show_changepoint)
#     146
#     147         ax = subplot(len(df_specific),1,i+1)
# --> 148         df = pd.read_csv(f_datn, header=None)#Original data
# ...
